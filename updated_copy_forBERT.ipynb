# %% [markdown]
# <a href="https://colab.research.google.com/github/dona-frj/semantic/blob/master/updated_copy_forBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip /content/drive/MyDrive/aquaint.zip -d'/content/data'
# Out:
# Archive:  /content/drive/MyDrive/aquaint.zip
#    creating: /content/data/aquaint/
#    creating: /content/data/aquaint/RawText/
#   inflating: /content/data/aquaint/RawText/APW19980603_0791.htm
#   inflating: /content/data/aquaint/RawText/APW19980603_1617.htm
#   inflating: /content/data/aquaint/RawText/APW19980604_0787.htm
#   inflating: /content/data/aquaint/RawText/APW19980610_0111.htm
#   inflating: /content/data/aquaint/RawText/APW19980611_0774.htm
#   inflating: /content/data/aquaint/RawText/APW19980614_0031.htm
#   inflating: /content/data/aquaint/RawText/APW19980615_0417.htm
#   inflating: /content/data/aquaint/RawText/APW19980620_0458.htm
#   inflating: /content/data/aquaint/RawText/APW19980624_0436.htm
#   inflating: /content/data/aquaint/RawText/APW19980624_0607.htm
#   inflating: /content/data/aquaint/RawText/APW19980625_1136.htm
#   inflating: /content/data/aquaint/RawText/APW19980627_0596.htm
#   inflating: /content/data/aquaint/RawText/APW19980709_0263.htm
#   inflating: /content/data/aquaint/RawText/APW19980713_0449.htm
#   inflating: /content/data/aquaint/RawText/APW19980808_0196.htm
#   inflating: /content/data/aquaint/RawText/APW19980811_0512.htm
#   inflating: /content/data/aquaint/RawText/APW19980816_0994.htm
#   inflating: /content/data/aquaint/RawText/APW19980824_0827.htm
#   inflating: /content/data/aquaint/RawText/APW19980903_1073.htm
#   inflating: /content/data/aquaint/RawText/APW19980917_0818.htm
#   inflating: /content/data/aquaint/RawText/APW19980930_0284.htm
#   inflating: /content/data/aquaint/RawText/APW19980930_0522.htm
#   inflating: /content/data/aquaint/RawText/APW19981001_0866.htm
#   inflating: /content/data/aquaint/RawText/APW19981010_0354.htm
#   inflating: /content/data/aquaint/RawText/APW19981020_1367.htm
#   inflating: /content/data/aquaint/RawText/APW19981022_0630.htm
#   inflating: /content/data/aquaint/RawText/APW19981022_0710.htm
#   inflating: /content/data/aquaint/RawText/APW19981026_0096.htm
#   inflating: /content/data/aquaint/RawText/APW19981106_0920.htm
#   inflating: /content/data/aquaint/RawText/APW19981109_0140.htm
#   inflating: /content/data/aquaint/RawText/APW19981109_0152.htm
#   inflating: /content/data/aquaint/RawText/APW19981109_0440.htm
#   inflating: /content/data/aquaint/RawText/APW19981109_0464.htm
#   inflating: /content/data/aquaint/RawText/APW19981109_1089.htm
#   inflating: /content/data/aquaint/RawText/APW19981109_1172.htm
#   inflating: /content/data/aquaint/RawText/APW19981113_0500.htm
#   inflating: /content/data/aquaint/RawText/APW19981113_0729.htm
#   inflating: /content/data/aquaint/RawText/APW19981119_0585.htm
#   inflating: /content/data/aquaint/RawText/APW19981120_1056.htm
#   inflating: /content/data/aquaint/RawText/APW19981130_0743.htm
#   inflating: /content/data/aquaint/RawText/APW19981210_0433.htm
#   inflating: /content/data/aquaint/RawText/APW19981215_1083.htm
#   inflating: /content/data/aquaint/RawText/APW19990120_0179.htm
#   inflating: /content/data/aquaint/RawText/APW19990203_0315.htm
#   inflating: /content/data/aquaint/RawText/APW19990519_0141.htm
#   inflating: /content/data/aquaint/RawText/APW19990526_0131.htm
#   inflating: /content/data/aquaint/RawText/APW19990827_0137.htm
#   inflating: /content/data/aquaint/RawText/APW19990827_0184.htm
#   inflating: /content/data/aquaint/RawText/APW20000303_0067.htm
#   inflating: /content/data/aquaint/RawText/APW20000312_0050.htm

# %%
# !unzip aquaint.zip
# Out:
# unzip:  cannot find or open aquaint.zip, aquaint.zip.zip or aquaint.zip.ZIP.

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize , sent_tokenize
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
from gensim.parsing.preprocessing import strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_non_alphanum ,strip_short
from gensim.parsing.preprocessing import preprocess_documents
from gensim.parsing.preprocessing import remove_stopwords, preprocess_string
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.2)

# %% [markdown]
# /////////////////////////// creat data to list

# %%
import os
from tqdm import tqdm
path = '/content/data/aquaint/RawText/'
list_txt=[]
tokenized_sent = [] #من اجل تخزين الجمل الماخوذة من النصوص
for txt  in os.listdir(path):
  f = open(os.path.join(path,txt), "r")         
  _txt= f.read()
  _txt=strip_multiple_whitespaces(_txt)
  _txt= remove_stopwords(_txt)
  _txt= sent_tokenize(_txt) 
  for i in _txt:
    t1=strip_non_alphanum(i) 
    t1=strip_short(t1,minsize=3)
    t2=remove_stopwords(t1)
    
  
    list_txt.append(t2)
list_txt
# Out:
# ['LONDON Nov',
#  'The apparent settlement came days talks involving West Indies players officials West Indies South Africa cricket boards',
#  'The crisis came head Wednesday West Indies Cricket Board fired superstar batsman Brian Lara captain Carl Hooper vice captain',
#  'The refused travel South Africa demanding better pay conditions tour',
#  'Team members insisted Lara Hooper reinstated settlement',
#  'Jimmy Adams treasurer players assocation negotiated behalf players Monday Pat Rousseau president West Indies Cricket Board',
#  'Ali Bacher head South African cricket directly involved Monday talks sitting sidelines Sunday',
#  'West Indies tour manager Clive Lloyd WICB member Joel Garner involved talks began Friday',
#  'Progress reported weekend announcement sponsorship deal offered South African wicketkeeper David Richardson runs sports marketing firm Johannesburg',
#  'Earnings sponsorship proposal apparently help meet players demands better pay reported range dlrs 000 000 South African tour',
#  '',
#  'Spirited bidders snap art seized failed finance firms Paintings art objects displayed elegant offices snapped weekend Thailand auction assets collapsed financial firms Thai media reported Sunday',
#  'The day auction 000 items ended Sunday expected bring initial estimate million baht dlrs 697 000',
#  'The paintings sculptures art related objects seized Thailand Financial Restructuring Authority government agency set liquidate assets finance companies shut year',
#  'The closings required International Monetary Fund dlrs billion bailout program depressed Thai economy',
#  'The proceeds auction pay debts failed companies',
#  'The going prices high higher expected art gallery owner Hongjorn Samae ngamjaroen quoted saying Bangkok Post',
#  'untitled painting lotus pond late Thawee Nandakwang sold million baht dlrs 000 way starting bid 400 000 baht dlrs 300',
#  'Prime Minister Chuan Leekpai donated sketches auction handled Christies British auction house',
#  'held Bangkok Queen Sirikit Natoinal Convention Center',
#  'REPEATING Protectively Iran protest International Court Justice Hague global bodies funded Radio Free Europe Iran Daily reported Monday',
#  'quoted Foreign Minister Kamal Kharrazi saying radio set interfere Iran internal affairs',
#  'complaints filed',
#  'The English language daily organizations Iran approach ICJ Netherlands',
#  'Tuesday Iran recalled ambassador Prague protest Czech government assistance radio said reduce level economic political cooperation Prague',
#  'The American sponsored station began broadcasts directed Iraq Friday',
#  'trial period weeks station broadcast minute program day Iran Iraq',
#  'The Farsi language service Iran approved Czech government August',
#  'Radio Free Europe began transmitting Munich Germany 1951 spreading uncensored news Soviet controlled countries Iron Curtain Cold War West Communist East',
#  'moved headquarters Prague 1995 following collapse communism years earlier',
#  '',
#  'Vietnam prime minister demands improvements state monopoly Prime Minister Phan Van Khai taken state electricity monopoly task abuse power excessive bureaucracy accusing overcharging newspaper Dau Investment reported Thursday',
#  'blunt assessment ordered Electricity Vietnam help cut waste driving costs spark public discontent',
#  'EVN work corrective measures based instructions individual leaders self criticisms',
#  'Khai said utility plenty problems particularly tender process project accounting led complaints affect Vietnam reputation foreign investors',
#  'March President Duc Anh article Army newspaper criticized irregularities bidding process country largest thermal electric plant',
#  'Local media reported company overblown costs construction repair work number projects justify overcharging electricity',
#  'Vietnam chronically short power projects raise output bogged bureaucracy',
#  'EVN imposed rotating power cuts earlier year worst drought century dropped water levels critical levels reservoir feed key hydroelectric plants',
#  'Swiss government eyes shutting nuclear power plants The Swiss government Thursday announced planning country eventual exit nuclear power saying wants support instead hydroelectric plants',
#  'But environmental campaigners criticized lack timeframe closing country nuclear power plants',
#  'Government officials work representatives power industry environmental groups local governments discuss timetable removal nuclear waste government statement said',
#  'unrealistic build power stations environmental concerns government said',
#  'Should discussions concerned parties fail produce agreed timetable federal cabinet decision said statement',
#  'set new course said Federal Energy Minister Moritz Leuenberger',
#  'Details decided',
#  'related federal cabinet ordered energy officials draw discussion paper changing laws governing domestic electricity market',
#  'The government envisages creation national company power infrastructure',
#  'timeframe carrying liberalization electricity market remains determined cabinet said',
#  'The cabinet said wants support hydroelectric plants',
#  'ordered study possibility tax breaks hydroelectric plants encourage upgrades plants',
#  'LONDON Nov',
#  'Word agreement leaked captain Courtney Walsh head West Indies players association told Caribbean News Agency Lara Hooper reinstated tour going ahead',
#  'The crisis came head Wednesday West Indies Cricket Board fired superstar batsman Lara captain Hooper vice captain',
#  'The refused travel South Africa demanding better pay conditions tour',
#  'Team members insisted Lara Hooper reinstated settlement',
#  'Jimmy Adams treasurer players assocation negotiated behalf players Monday Rousseau',
#  'Ali Bacher head South African cricket directly involved Monday talks sitting sidelines Sunday',
#  'West Indies tour manager Clive Lloyd WICB member Joel Garner involved talks began Friday',
#  'Progress reported weekend announcement sponsorship deal offered South African wicketkeeper David Richardson runs sports marketing firm Johannesburg',
#  'Earnings sponsorship proposal apparently help meet players demands better pay reported range dlrs 000 000 South African tour',
#  '',
#  'Airport ready operation Palestinians await word Israel The new Palestinian airport powerful symbol fledgling independence ready open head Palestinian Civil Aviation Authority said Friday operations drill Israeli officials',
#  'Yasser Arafat International Airport southern Gaza Strip opened week Israeli Palestinian peace agreement',
#  'However Israel fell schedule held Cabinet ratification accord weeks',
#  'Prime Minister Benjamin Netanyahu said airport start operating week set date',
#  'Thursday Israeli Palestinian officials staged hour drill said Fayez Zeidan head Palestinian Civil Aviation Authority',
#  'About 100 Palestinian airport employees Israelis share security duties played roles passengers airport personnel',
#  'For lack plane passengers arrived bus',
#  'Zeidan said exercise covered arrival departure procedures including passport checks customs luggage inspection',
#  'said airport ready operation',
#  'need hear Israelis Zeidan said',
#  'Stolen painting New Zealand recovered man arrested 19th century painting worth dlrs million stolen Auckland Art Gallery days ago recovered police said Monday',
#  'Senior Sgt',
#  'Gary Allcock said understood person arrested theft 1874 oil Still Top French born artist Jacques Joseph James Tissot New Zealand expensive popular European works',
#  'said details disclosed later',
#  'The painting valued dlrs million stolen Aug man armed shotgun daring robbery Auckland Art Gallery',
#  'The man clad black wearing motorcycle helmet dark visor gloves burst main door sawed shotgun crowbar',
#  'Museum official Kate Darrow said man ran Grey Gallery waving firearm yelling staff patrons',
#  'She said man appeared know going went Lower Wellesley Gallery painting displayed',
#  'The gunman grabbed painting wall dropped ground',
#  'crowbar remove canvas frame backing board',
#  'The robber left main entrance skirted gallery Albert Park pursued member public',
#  'believed climbed motorcycle escaped nearby highway',
#  'ENGLISH Viravaidya plan set watchdog company monitor SET listed companies expose possible abuses corporate ethics',
#  'agree heartedly like know mail checks subscribe company shares',
#  'Could advise',
#  'Also fully support request media report lifestyle executives failed banks finance companies',
#  'know people punished legally inefficiency Bank Thailand collecting evidence justice delivering timely justice',
#  'media job discover guys better destroying country Thai people job socially punish',
#  'like propose newspapers stations play issue continued luxurious lifestyle executives attract public attention Bt20 000 hard earned salary blessing',
#  'Artit Krichphiphat ordinary Thai citizen wants right things Editor note Khun Mechai organise seminar plan June Telephone Organisation Thailand',
#  'The media duty cover issues additional financial reward',
#  'Iran complain radio Hague tribunal Iran protest International Court Justice Hague global bodies funded Radio Free Europe Iran Daily reported Monday',
#  'quoted Foreign Minister Kamal Kharrazi saying radio set interfere Iran internal affairs',
#  'complaints filed',
#  'The English language daily organizations Iran approach ICJ Netherlands',
#  'Tuesday Iran recalled ambassador Prague protest Czech government assistance radio said reduce level economic political cooperation Prague',
#  'The American sponsored station began broadcasts directed Iraq Friday',
#  'trial period weeks station broadcast minute program day Iran Iraq',
#  'The Farsi language service Iran approved Czech government August',
#  'Radio Free Europe began transmitting Munich Germany 1951 spreading uncensored news Soviet controlled countries Iron Curtain Cold War West Communist East',
#  'moved headquarters Prague 1995 following collapse communism years earlier',
#  'Museum Return Stolen Works LOS ANGELES The Paul Getty Museum returning ancient works art Italy determining stolen',
#  'One sculpture sat collection years',
#  'The objects flown Italy week pieces loaned museum antiquities exhibit according statement issued Getty Monday',
#  'The stolen items terra cotta drinking cup 480',
#  'illegally excavated archaeological site torso god Mithras 2nd century stolen private Italian collection sculpted head victorious athlete 2nd century Roman copy earlier Greek work apparently taken storeroom scientific excavation',
#  'For security reasons museum pieces worth',
#  'Although claimed works Getty decided return based information supplied experts field consultation Italian officials',
#  'International concern growing rampant thefts priceless art collections looting archaeological sites',
#  'The billion dollar museum located hill Brentwood area opened 1997',
#  'Iraq Iran sign pact resolve POW issue Iraq Iran signed deal Iraq says resolve longstanding dispute prisoners war',
#  'The agreement reached following week talks Baghdad senior Iraqi officials visiting Iranian delegation headed Abdullah Najafi head Iran POW commission official Iraqi News Agency reported Wednesday',
#  'But agency gave details Najafi left Baghdad Wednesday declined comment',
#  'Najafi arrived Baghdad week list thousands Iranian POWs Tehran claims held Iraq',
#  'Iraq long maintained released Iranian prisoners reportedly angered new list',
#  'April Iran released 584 Iraqi POWs Iraq freed POWs 316 Iranians classified civil law detainees',
#  'largest repatriation Iranian Iraqi POWs 1990 said International Committee Red Cross supervised swap',
#  'The Red Cross says knows thousand Iraqis Iran aware Iranian POWs Iraq',
#  'The Iran Iraq war million people killed wounded ended 1988',
#  'The issue POWs long stood way better ties',
#  '',
#  'Hare Closes Terminal Security CHICAGO United Airlines shut terminal hours authorities search passenger ran past security checkpoint disappeared crowd Hare International Airport',
#  'United spokeswoman Kristina Price said 131 flights canceled Thursday 100 delayed nationwide incident',
#  'About 000 passengers cleared terminal search airline officials said',
#  'Eighty flights canceled today numerous delayed effects shutdown lingered Price said adding carrier hoped normal schedule afternoon',
#  'The man Chicago police said officers turned suspicious',
#  'leaving concourse heading baggage claim area turned ran way staircase leading concourse United spokesman Matthew Triaca said',
#  'Guards stationed staircase man ran past',
#  'United flights left terminal search landed United gates',
#  'Some flights resumed early evening',
#  'Iraqi minister arrives Iran attend trade fair Iraq trade minister arrived Wednesday attend international trade fair hold discussions Iranian counterpart Islamic Republic News Agency reported',
#  'Mohammed Mehdi Saleh seven member delegation traveled land crossed Iran Khosrawi border point western Kermanshah province official news agency said',
#  'quoted Saleh saying discuss Iran Trade Minister Mohammad Shariat Madari ways expanding commercial ties countries',
#  'The fair scheduled Oct',
#  'This second consecutive year Iraq attending Tehran International Trade Fair points need neighbors business despite traditional animosity',
#  'Iran Iraq fought year war ended brokered cease',
#  'Iran claims Iraq holds 000 prisoners war Iraq says Iran holding 000 prisoners',
#  'More million people killed wounded sides 1980 war',
#  'Tehran accuses Baghdad helping Iranian opposition groups sides accuse allowing infiltrators sneak borders acts sabotage',
#  'December Iraqi Vice President Taha Yassin Ramadan highest ranking Iraqi visit Tehran 1991 Gulf War attended Organization Islamic Conference meeting',
#  '',
#  'Actress Brooke Shields accepts libel damages apology false Actress Brooke Shields Monday accepted substantial libel damages public apology newspaper article alleging questioned police hours connection drug offenses left Cannes Film Festival',
#  'The Mail Sunday reported May exclusive began page continued page Miss Shields luggage searched flight Nice Airport delayed French police quizzed',
#  'After actress filed suit Associated Newspapers Ltd publisher Mail Sunday paper editor Mail journalists Mail Sunday published page apology retraction May',
#  'The retraction said story totally false conceded Miss Shields stopped airport',
#  'The defendants recognize Miss Shields staunch committed anti drug campaigner spent considerable amounts time supporting substance abuse programs raising needed money anti drug abuse programs said Claire Shields defendants attorney',
#  'The newspaper page article especially hurtful family attorney said',
#  'The Sunday paper editor Jonathan Holborow written actress present court Monday personal letter apology',
#  'The damages disclosed',
#  '',
#  'Hungarian government Jewish communities agree compensation The Hungarian government Federation Hungarian Jewish Communities signed agreement Thursday collective compensation communist era confiscations state news agency MTI reported',
#  'The financial basis funding real estate belonged Jewish communities fell victim nationalization communists',
#  'Instead getting actual property 152 schools buildings assessed value 511 000 000 forints dlrs million Jewish community collectively percentage annually starting current year 608 million forints dlrs million paid',
#  'The money mainly education religious services social welfare health service charity ends Gusztav Zoltai executive director Federation said',
#  'There 000 100 000 Jews Hungary',
#  'Some 600 000 killed Holocaust',
#  'When communists assumed power 1948 started wave nationalizations spared including Jewish community',
#  'June 1997 similar agreement kind signed Hungarian government Vatican',
#  '',
#  'THAILAND MORE people dying suffering fatal diseases brain tumours mammarian breast cancer brain haemorrhage lack proper medical care However things change Srisiam Hospital Bangkok established Radio Surgery Institute Thailand presently 100 radio surgery centres world',
#  'Radio surgery modern technique require surgery order remove cancerous growth tissues',
#  'involves dimensional method known Stereotaxic Surgery conjunction radiation equipment known Linear Accelerator',
#  'With new technology doctors able removal cancerous tissues embedded deep inside brain near sensitive organs makes normal surgery difficult risky',
#  'With radio surgery step controlled computers patients conscious undergo treatment',
#  'This new technique capable treating diseases Artero Venous Malformation clotting veins blood capillaries brain far ninety cent radio surgery treatments successful patients remain hospital days',
#  'Additionally need patients shave heads radio surgery causes scar little blood loss expensive For information contact hospital srisiam ksc com',
#  'Iranian POW negotiator holds talks Iraqi ministers The head Iran prisoner war commission met Iraqi Cabinet ministers Saturday bid glean information thousands Iranian POWs allegedly Iraq official Iraqi News Agency reported',
#  'Iraqi Foreign Minister Mohammed Saeed Sahhaf told Abdullah Najafi states needed speed closure remains POW Missing Action file INA said',
#  'The issue POWs missing persons remains stumbling block normalizing relations neighbors',
#  'Iraq long maintained released Iranian prisoners captured 1980 Iran Iraq War',
#  'The countries accuse hiding POWs preventing visits International Committee Red Cross prisoner camps',
#  'The ICRC representative Baghdad Manuel Bessler told The Associated Press organization difficulty visiting POWs sides regular basis',
#  'April Iran released 584 Iraqi POWs Iraq freed POWs 316 Iranians classified civil law detainees largest exchange 1990',
#  'More million people killed wounded Iran Iraq War',
#  'German zoo hopes court allow accept baby elephants The Dresden Zoo went court Tuesday challenge Environment Minister Juergen Trittin order forbidding import baby elephants taken wild Africa abused',
#  'Zoo director Hubert Luecker said complaint filed administrative court Cologne',
#  'The elephants sent month Dresden Erfurt zoos eastern Germany group young elephants captured August herds Botswana taken South African farm',
#  'South African judge ruled early month animals abused deprived water farm',
#  'granted temporary custody National Society Prevention Cruelty Animals',
#  'But judge approved export baby elephants Germany Switzerland Trittin week said Germany protest abuse animals accepting zoos',
#  'Others argue elephants face worse fate come Germany',
#  'Norbert Otto federal lawmaker Erfurt demanded parliament Tuesday Trittin steps prevent animals sleep South Africa',
#  'addition cultural minister Saxony Dresden capital asked state 740 000 school children write letters protest urging Tritten allow elephants Germany',
#  'aet pfg',
#  'MALAYSIA PORT DICKSON Tues Federal State Government agencies given task undertake economic projects Development Programme Hardcore Poor PPRT ensure successful implementation',
#  'Rural Development Minister Datuk Annuar Musa said yesterday responsible closely monitor implementation projects ensure allocation provided ministry benefit hardcore poor participants',
#  'said responsible including district officers personally check progress projects carried',
#  'want projects success paper inspection desired results added',
#  'According ministry policy minister deputy minister parliamentary secretary director general senior ministry officials visit PPRT projects happening allocation given Government',
#  'Annuar said visiting mussel rearing project Kuala Lukut today day long visit PPRT projects Negri Sembilan',
#  'Present Chembong Assemblyman Firdaus Harun Port Dickson district officer Hassan Nawawi Abdul Rahman',
#  'Annuar added implementing agencies conduct depth studies projects proposed ensure viability',
#  'Interpol needs revamp strategy abreast crime Interpol modernize wants effectively fight increasingly sophisticated crime syndicates century police organization president said Thursday',
#  'The criminal environment changed greater pace Interpol Toshinori Kanemoto told opening session 67th general assembly International Criminal Police Organization',
#  'failure modernize Interpol mean organization risks displaced backdrop international organized crime said',
#  'Kanemoto said new Interpol strategy discussed day assembly adopted effect January',
#  'The Japanese police official said assembly discuss terrorism called new forms criminality illegal drug trade money laundering',
#  'With crime increasingly sophisticated Kanemoto said harder police officials gather evidence prosecution',
#  'said new challenges require increased cooperation particularly Interpol',
#  'The police officials expected discuss strategic development plan aimed making Interpol proactive examining needs group 177 member states Kanemoto said',
#  'Details graf pvs',
#  'Austrian president tells Albright effort identify stolen art Austria president told Secretary State Madeleine Albright Thursday government establishing commission identify art stolen Holocaust victims Nazis',
#  'Austrian officials said President Thomas Klestil told Albright paid day visit Vienna Moscow summit commission determine origin art works owned Federal Museum',
#  'There statement art issue officials',
#  'Albright left United States meetings Klestil Chancellor Viktor Klima Foreign Minister Wolfgang Schuessel',
#  'Austria United States nations launched drive identify billions dollars worth art stolen Holocaust victims Europe',
#  'The World Jewish Congress estimates current value stolen art dlrs billion dlrs 140 billion',
#  'June Association Art Museum Directors United States recommended American art museums check collections determine works stolen war set worldwide database tracking',
#  'Austria absorbed Adolf Hitler Germany 1938 restored independent nation following World War',
#  '',
#  'Lufthansa German railway pledge closer cooperation Seeking shift domestic travel planes trains Germany flag carrier Lufthansa German railway signed letter intent Monday work coordinating services schedules',
#  'The goal easier travel train Lufthansa main hub Frankfurt instead flying',
#  'Starting 2001 Lufthansa boss Juergen Weber hopes eliminate short hops Frankfurt Cologne example freeing takeoff landing slots lucrative international flights',
#  'Lufthansa Deutsche Bahn deal passengers check luggage train station Lufthansa flight catch Frankfurt',
#  'The service place Saarbruecken travelers drop bags day',
#  'Starting September service extended cities Duesseldorf Cologne Bonn Wuerzburg Nuremberg',
#  'Passengers flying Lufthansa partners United SAS able use service said',
#  'The airline railway said form working group resolve problems security checks luggage making sure bags airport train station time',
#  'Deutsche Bahn chief Johannes Ludewig said railway work coordinate schedules better Lufthansa flights connections easier allow combined train plane tickets',
#  'pfg aet',
#  'REPEATING Protectively Iran protest International Court Justice Hague global bodies funded Radio Free Europe Iran Daily reported Monday',
#  'quoted Foreign Minister Kamal Kharrazi saying radio set interfere Iran internal affairs',
#  'complaints filed',
#  'The English language daily organizations Iran approach ICJ Netherlands',
#  'Tuesday Iran recalled ambassador Prague protest Czech government assistance radio said reduce level economic political cooperation Prague',
#  'The American sponsored station began broadcast directed Iraq Friday',
#  'trial period weeks station broadcast minute program day Iran Iraq',
#  'The Farsi language service Iran approved Czech government August',
#  'Radio Free Europe began transmitting Munich Germany 1951 spreading uncensored news Soviet controlled countries Iron Curtain Cold War West Communist East',
#  'moved headquarters Prague 1995 following collapse communism years earlier',
#  '',
#  'This Dracula kills cattle deer giant black bear peasants nicknamed Dracula creating anxiety western Romania taste cattle sheep official said Thursday',
#  'Peasants livestock devoured hungry bear lodged seven complaints past weeks said Nicolae Onetiu head state hunting fishing reserves western Romania',
#  'Dracula named Transylvania vampire count legend bloody appetite said Onetiu',
#  'The male bruin weighs 300 kilograms 660 pounds moved closer inhabited areas forested regions onset cold weather apparently ready hibernate',
#  'Dracula killed cows seven sheep past weeks',
#  'Most bears omnivorous Romania bears weaned meat said Onetiu',
#  'Nicolae Ceausescu communist dictator toppled executed decade ago avid hunter hunting reserve cubs fed meat grow bigger quicker leaving generations partial meat',
#  'State rangers count 135 bears living Apuseni Mountains western Romania protected law',
#  'str',
#  'Norwegian company moves ahead clean power plant The Norsk Hydro ASA concern announced plans Friday build hydrogen burning power plant says produce electricity virtually climate damaging emissions',
#  'The percent state owned company notified Norwegian Water Resources Energy Directorate plans build plant called HydroKraft pending approval government agencies',
#  'The company said receives proper approvals 1999 construction plant completed 2002 production startup occur early 2003',
#  'Earlier year company announced new technology allow use clean burning hydrogen generate electricity',
#  'The hydrogen plant extracted natural gas',
#  'Norsk Hydro major petroleum producer says studies shown proposal economically viable',
#  'said plant carbon dioxide emissions percent lower plants natural gas',
#  'Norway world second largest oil exporter produces vast amounts natural gas offshore fields',
#  'Virtually country electricity comes hydroelectric plants',
#  'Under company plans natural gas air water mixed produce hydrogen nitrogen carbon dioxide',
#  'Norsk Hydro wants build plant Karmoey island 500 kilometers 300 miles west Oslo',
#  'Alaska Hiker Killed Bear ANCHORAGE Alaska man day hike rural area killed bear bit head Alaska State Troopers said Wednesday',
#  'Kenneth Cates Wednesday morning horse trail heavily wooded area Kenai National Wildlife Refuge near hometown Soldotna',
#  'The attack happened miles busy road',
#  'The area miles southwest Anchorage',
#  'The fatal mauling thought happened Tuesday',
#  'His visible wound single bite head said Bruce Bartley spokesman state Division Wildlife Conservation',
#  'State federal wildlife officials looking bear involved attack',
#  'bear judged pose continuing threat humans killed',
#  'Troopers said Cates 280 caliber rifle spent shell casings near body traces blood suggest Cates wounded animal',
#  'know warning shot real real shots Bartley said',
#  'Cates death fatal bear mauling Alaska Feb 1998 Audelio Luis Cortes killed working seismic crew Swanson River oil field near Kenai',
#  'Cortes died single head bite',
#  'Syria opposes attempt overthrow Saddam Hussein Syria opposes attempts United States Britain overthrow Iraqi leader Saddam Hussein Syrian Vice President Abdul Halim Khaddam said Thursday',
#  'Such moves serve Israel design disintegrate Arab Islamic world Khaddam said receiving Iranian counterpart Hassan Habibi Damascus airport',
#  'The United States granted dlrs million Iraqi opposition groups',
#  'British American officials hosted meetings London month Iraqi dissident groups bid promote cooperation',
#  'This dangerous issue state world right interfere internal affairs country Khaddam said',
#  'Habibi said Iraqi Palestinian questions great concern Iran Syria There coordination countries issues',
#  'The official Iranian news agency IRMA said Iraqi Palestinian issues focus talks Habibi Khaddam meeting Syrian Iranian Supreme Committee',
#  'The committee meets biannually promote cooperation foreign affairs trade technology',
#  'Habibi accompanied Iranian Foreign Minister Kamal Kharrazi expected meet Syrian President Hafez Assad day visit',
#  'Syria Iran closest Arab ally supported Persian state 1980 Iran Iraq war',
#  'str jbm',
#  'Portugal Spain reach agreement common water supplies Portugal Spain Monday reached agreement shared water resources Iberian peninsula wrapping day summit premiers called historic',
#  'ambitious modern wide ranging efficient agreement Portugal Prime Minister Antonio Guterres said end summit Albufeira 200 kilometers 125 miles south Lisbon',
#  'Both governments worked shared management plan monitor water volume rivers supply countries',
#  'Spanish Premier Jose Maria Aznar said agreement reflected exceptional moment relations Iberian countries',
#  'Water supply southwest European peninsula sticking points countries strong trade links close political ties',
#  'Spanish plans develop hydroelectric projects border constant threat Portugal supply comes mainly rivers sources neighboring country',
#  'Both governments reiterated decision jointly campaign continued development funds provided wealthier European Union nations',
#  'Cabinet Members agreed build new road railway links countries',
#  'The Albufeira summit produced plan increase cooperation police border order curb illegal immigration drug trafficking',
#  'Bank Fires Seven Mail Misuse CHARLOTTE First Union Corp says fired seven employees week sending pornographic inappropriate mail',
#  'First Union nation sixth largest bank confirmed firings Friday company spokeswoman Sandy Deem release details',
#  'The bank tolerate conduct interferes person work performance creates intimidating offensive hostile environment Deem said',
#  'The Charlotte Observer reported Friday employees University Research Park office circulated mail included videos people having sex material sexual nature',
#  'The company stumbled mail volume messages heavy slowed server',
#  'One employee fired past week bank home equity division called office shown stack mail fired spot employee told newspaper',
#  'First Union Fortune 100 corporation joins number companies taking swift severe action violations company mail policy',
#  'Companies seeking protect legal claims work environment hostile',
#  'increasing number lawsuits alleging sexual harassment based claims mails taken company systems',
#  'Impressionist paintings recovered curator central suspect Police recovered valuable Impressionist paintings stolen days ago appears staged heist arrested museum curator alleged armed robbery police sources said Wednesday',
#  'Two people described small time thugs arrested connection Sept theft Monet Sisley Fine Arts Museum Nice according sources judicial police',
#  'They spoke customary condition anonymity',
#  'The art works Claude Monet 1897 painting The Cliffs Dieppe Alfred Sisley 1890 work The Alley Poplars sail boat anchored small Riviera port Saint Laurent Var police said',
#  'The police sources said curator Jean Forneris suspected having ordered theft',
#  'The paintings stolen masked men took Forneris home drove museum bound gagged caretaker employee shut museum library',
#  'The museum alarm turned allegedly caretaker duty',
#  'The men sped curator car paintings',
#  'Forneris later expressed shock thefts',
#  'parf',
#  'Iraq Iran sign pact resolve POW issue Iraq Iran signed deal Iraq says resolve longstanding dispute prisoners war',
#  'The agreement reached following week talks Baghdad senior Iraqi officials visiting Iranian delegation headed Abdullah Najafi head Iran POW commission official Iraqi News Agency reported Wednesday',
#  'But agency gave details Najafi left Baghdad Wednesday declined comment',
#  'Najafi arrived Baghdad week list thousands Iranian POWs Tehran claims held Iraq',
#  'Iraq long maintained released Iranian prisoners reportedly angered new list',
#  'April Iran released 584 Iraqi POWs Iraq freed POWs 316 Iranians classified civil law detainees',
#  'largest repatriation Iranian Iraqi POWs 1990 said International Committee Red Cross supervised swap',
#  'The Red Cross says knows thousand Iraqis Iran aware Iranian POWs Iraq',
#  'The Iran Iraq war million people killed wounded ended 1988',
#  'The issue POWs long stood way better ties',
#  'Iran complain radio Hague tribunal Iran protest International Court Justice Hague global bodies funded Radio Free Europe Iran Daily reported Monday',
#  'quoted Foreign Minister Kamal Kharrazi saying radio set interfere Iran internal affairs',
#  'complaints filed',
#  'The English language daily organizations Iran approach ICJ Netherlands',
#  'Tuesday Iran recalled ambassador Prague protest Czech government assistance radio said reduce level economic political cooperation Prague',
#  'The American sponsored station began broadcasts directed Iraq Friday',
#  'trial period weeks station broadcast minute program day Iran Iraq',
#  'The Farsi language service Iran approved Czech government August',
#  'Radio Free Europe began transmitting Munich Germany 1951 spreading censored news Soviet controlled countries Iron Curtain Cold War West Communist East',
#  'moved headquarters Prague 1995 following collapse communism years earlier',
#  '',
#  'Nicaragua Reporter Garcia Dies MANAGUA Nicaragua Rodolfo Garcia Associated Press reporter helped chronicle Nicaragua emergence civil war papal visit volcanoes floods died Managua long illness',
#  '',
#  'Garcia joined The Associated Press office Managua 1986 working Radio Nicaragua director short wave broadcasts helping local news agency Agencia Noticias Nueva Nicaragua',
#  'For covered war Sandinista government Contra rebels Sandinistas loss power ballot box country turbulent effort years war',
#  'reported volcanic eruptions 1996 visit Pope John Paul ravages Hurricane Mitch 1998',
#  'worked difficult conditions created civil war managed maintain total objectivity fair vision pressure reporting The Associated Press said Eloy Aguilar bureau chief Mexico Central America',
#  'Garcia born Nandasmo town miles south Managua',
#  'attended National Autonomous University Nicaragua',
#  'Garcia suffered series illnesses year including diabetes cancer',
#  'died Saturday night',
#  'buried Nandasmo Sunday',
#  'survived wife Ana Leonor Hernandez daughters',
#  'Nikhil Chakravarty Indian political columnist dead Nikhil Chakravarty India best known journalist died',
#  '',
#  'Chakravarty suffering brain cancer died hospital Saturday family said',
#  'Politics forte columns appeared leading Indian newspapers magazines',
#  'Chakravarty started weekly news magazine Mainstream 1962 edited decades',
#  'Last year government appointed chief Prasar Bharati autonomous corporation set end government control radio television',
#  'Chakravarty declined government award 1990 saying journalist identified governing establishment',
#  'graduated Calcutta University studied Oxford University Merton College England',
#  'Chakravarty taught history Calcutta University 1930s taking journalism correspondent weekly brought Communist Party India',
#  'later joined CPI remained member 1978',
#  'closed Mainstream weekly Prime Minister Indira Gandhi imposed emergency rule India 1975 jailing political opponents imposing censorship newspapers magazines',
#  'Chakravarty born November 1913 India northeastern state Assam',
#  'Police identify substance tea poisoning case The poison sickened Japanese company employees drank tea brewed water pot toxic sodium compound affects central nervous police said Tuesday',
#  'Police clues chemical pot filled water Friday night Monday added',
#  'The workers Xyence wood preservative company Niigata 256 kilometers 159 miles northwest Tokyo hospitalized Monday suffering nausea numbness morning tea break',
#  'The case gave Japan shock weeks curry laced cyanide arsenic killed people festival southwestern Japan',
#  'raised fears copycat attacks',
#  'Lab tests tea revealed traces sodium azide chemical industrial products including air bag mechanisms said police spokesman Masashi Toma',
#  'The victims poisoning stable condition suffered mild liver disorders Tuesday said Yasuo Hirose official Niigata City Hospital',
#  'The March 1995 nerve gas attack Tokyo subways carried Aum Shinri Kyo religious cult Japan particularly wary poisoning incidents',
#  'The subway gassing killed people',
#  '',
#  'Israel increases security airports following threats Israel adding security personnel international airport response threats Islamic militants attack Israeli targets including airlines officials said Monday',
#  'Prime Minister Benjamin Netanyahu senior adviser David Bar Illan said Israel use measures deemed necessary fight terrorism',
#  'Asked included pre emptive strikes Bar Illan told The Associated Press want specific obviously ruling',
#  'Threats Israeli targets emerged week air strikes Sudan Afghanistan aimed Osama bin Laden Saudi millionaire Islamic militant linked bombings embassies East Africa month',
#  'Sunday leading Muslim activist close bin Laden said Islamic militants preparing retaliate air strikes targeting Israeli strategic sites airliners',
#  'basketball team University Connecticut arrived Monday day tour friendly games hired private security guards accompany Israel',
#  'The administration University Connecticut demanded bodyguards readily agreed said teams tour operator Nels Hawkinson',
#  'Had bombings Afghanistan Sudan seen need said',
#  'Pini Shis 6th graf pvs',
#  'Airport ready operation Palestinians await word Israel The new Palestinian airport powerful symbol fledgling independence ready open head Palestinian Civil Aviation Authority said Friday operations drill Israeli officials',
#  'Yasser Arafat International Airport southern Gaza Strip opened week Israeli Palestinian peace agreement',
#  'However Israel fell schedule held Cabinet ratification accord weeks',
#  'Prime Minister Benjamin Netanyahu said airport start operating week set date',
#  'Thursday Israeli Palestinian officials staged hour drill said Fayez Zeidan head Palestinian Civil Aviation Authority',
#  'About 100 Palestinian airport employees Israelis share security duties played roles passengers airport personnel',
#  'For lack plane passengers arrived bus',
#  'Zeidan said exercise covered arrival departure procedures including passport checks customs luggage inspection',
#  'said airport ready operation',
#  'need hear Israelis Zeidan said',
#  '',
#  'Sotheby Announces Internet Site NEW YORK Home shoppers buy airline tickets Beanie Babies garden tools',
#  'Why million Rembrandt painting',
#  'Sotheby New York auction house said Tuesday spend million launch sothebys com Internet site public able bid antiques art jewelry sports memorabilia collectibles',
#  'The value items virtual auction block initially capped 000',
#  'More expensive items posted imaging technology improves clear views items multiple angles',
#  'There point having fuzzy image 100 000 item said Susan Solomon head new venture',
#  'Sotheby major online auction planned July feature baseball memorabilia',
#  'While online auction sites extremely popular consumer groups sites produced consumer complaints Internet category shoddy merchandise fraud',
#  'Sotheby said sell merchandise auction house reputable art dealers',
#  'And bids accepted customers registered charge card numbers advance',
#  'Officials Christie leading New York auction house said considering online auction site',
#  'Prosecutor Botha stand trial prosecutor Friday left open possibility apartheid President',
#  'Botha trial abuses committed white rule',
#  'Prosecutor Jan Oliveira said currently insufficient evidence prosecute Botha information collected Truth Reconciliation Commission South Africa investigated apartheid era abuses evaluated ascertain charges ultimately brought',
#  'Last month Truth Comission issued landmark report findings',
#  'said Botha ordered 1987 bombing African National Congress London headquarters 1988 bombing Johannesburg building housing anti apartheid group',
#  'When Botha head state 1980s thousands people detained trial',
#  'Many tortured killed',
#  'The commission grant amnesty fully confess politically motivated abuses committed apartheid',
#  'Botha said confess sought amnesty',
#  'Earlier year Botha convicted contempt court refusing testify commission',
#  'handed suspended year jail sentence 000 rand dlrs 700 fine',
#  'appealed decision',
#  'sapa aos',
#  'Cult guru lawyers lash prosecutors court Attorneys cult guru accused murder nerve gas attack Tokyo subways denounced trial Thursday unfair prosecutors charges contradicted testimony witnesses',
#  'Shoko Asahara leader Aum Shinri Kyo cult trial charges March 1995 sarin attack killed people sickened thousands',
#  'Other cult leaders charged gassing slayings',
#  'Osamu Watanabe Asahara chief defense lawyer said trial allowed',
#  'wonder abnormal unfair proceedings tolerated',
#  'The court negligent Watanabe told Tokyo District Court',
#  'The prosecutors Asahara accused masterminding subway gassing decided attack March 1995 riding car followers',
#  'But Watanabe pointed cultist Yoshihiro Inoue key witness prosecution told court Asahara undecided timing attack time',
#  'Inoue quoted Asahara saying needed meditate',
#  'Last April defense raised similar objections prosecutors refused change statement',
#  '',
#  'Report Plane robbed gunmen Nigerian airport Air Afrique Boeing 727 jet passenger liner looted past month armed robbers awaiting takeoff Nigeria largest international airport Lagos Guardian newspaper reported Thursday',
#  'The thieves broke aircraft luggage compartment escaped large quantity baggage plane awaiting permission Lagos international airport control tower Tuesday night Guardian said',
#  'clear airliner destined',
#  'There immediate confirmation report',
#  'The plane captain noticed theft sent distress went unanswered airport officials',
#  'Security personnel duty later said said unable capture culprits security vehicle taken away routine maintenance',
#  'incident week involving unidentified passenger jet landing gear worth dlrs million stripped plane waiting newspaper said',
#  'May Cameroon Airlines plane robbed luggage armed thieves blocked plane tarmac large log',
#  'The robberies came despite orders airport security officials shoot suspected thieves sight',
#  'Nigeria Africa populous country notoriously high rate violent crime accompanied breakdown law order years military rule',
#  'gam',
#  'Businessman killed Siberian town Russian businessman killed way work Wednesday unidentified gunman appeared organized crime killing according news reports',
#  'Yuri Zinin head Sibneft Company shot walked apartment building town Leninsk Kuzntesky Kemerovo region central Siberia Russian news agencies quoted local police saying',
#  'Zinin company Russia largest oil producers Sibneft controlled controversial business mogul Boris Berezovsky',
#  'But companies separate',
#  'Zinin Sibneft locally based involved selling oil products coal',
#  'Kemerovo Russia main coal mining regions',
#  'Police launched search killer fled',
#  'Officials wouldn comment possible motives murder',
#  'There hundreds contract murder Russia year mobsters fight control profitable businesses',
#  'Only small number killings solved',
#  'The small town Leninsk Kuznetsky known nationwide year city mayor arrested tax fraud embezzlement charges',
#  'Mayor Gennady Konyakhin accused linked mob custody awaiting trial',
#  'ren',
#  'Astronomers Spot Storm Mars WASHINGTON cyclone times size Texas raged northern polar region planet Mars month according space telescope views red planet',
#  'The Space Telescope Science Institute announced today Hubble Space Telescope April spotted immense Martian storm cloud water ice 100 miles long 900 wide',
#  'Bands clouds spiraled counterclockwise motion 200 mile wide eye center storm taking shape resembled hurricanes Earth astronomers said',
#  'The storm occurred summer Mars northern hemisphere',
#  'came seasonal warming evaporated carbon dioxide ice sheet caps Martian north pole year',
#  'Officials said storm times larger storm spotted years ago Viking Orbiter spacecraft',
#  'Astronomers wide field planetary camera Hubble photograph Mars planet closest approach Earth nearly years',
#  'Two pictures taken hours apart April showed storm moved slightly eastward',
#  'second picture storm appeared process breaking',
#  'Later pictures Hubble camera failed storm astronomers said short lived phenomenon',
#  'Shepard Glenn set milestones May 1961 Alan Shepard American space',
#  'Feb 1962 John Glenn American orbit',
#  'Jan 1967 Gus Grissom Edward White Roger Chaffee die Apollo spacecraft launch pad',
#  'July 1969 Apollo Neil Armstrong Buzz Aldrin land moon',
#  'July 1975 American Apollo Soviet Soyuz spacecraft link orbit',
#  'April 1981 Columbia soars space shuttle flight',
#  'June 1983 Sally Ride American woman space',
#  'Jan 1986 Challenger explodes killing seven board',
#  'April 1990 Hubble Space Telescope released orbit',
#  'Dec 1993 First Hubble repair mission launched',
#  'March 1995 Norman Thagard American launched Russian rocket',
#  'Two days later American visit Mir',
#  'June 1995 Atlantis docks Mir shuttle station hookup',
#  'Sept 1996 Shannon Lucid returns Earth 188 day Mir mission space endurance record world record women',
#  'Nov 1996 Story Musgrave age oldest man space',
#  'Oct 1998 Discovery scheduled blast carrying year old John Glenn orbit making oldest man space',
#  'The Nation Weather Severe thunderstorms forecast Gulf Coast Louisiana Georgia northward Tennessee',
#  'Rain forecast Carolinas tonight',
#  'Lightning large hail wind mph inches rain possible',
#  'Lighter amounts expected Ohio Valley',
#  'The storm roared Texas Oklahoma Thursday hitting areas wind hail heavy rain',
#  'Some flights Dallas Fort Worth International Airport delayed seven hours',
#  'Northeast inches sunnyow possible Adirondack Green Mountains',
#  'sunnyow forecast northwesterain Pennsylvania Maine',
#  'Gusty winds expected wind chill readings freezing',
#  'Mostly quiet conditions forecast West Rockies Southeast northerain Plains today',
#  'Showers possible Southerain Califorainia coasts Washington Oregon',
#  'Highs today forecast reach 30s New England 40s Northeast Midwest Great Lakes northerain Rockies 50s Northwest mid Atlantic states northerain Plains 60s 70s 80s Southeast Southwest southerain Plains',
#  'The highest temperature reported continental United States Thursday degrees Texas communities Cotulla Alice',
#  'The low minus Grand Marais Minn',
#  'Report South Africa truth panel condemn ANC panel probing apartheid era abuses accused African National Congress human rights violations including torture bomb attacks state broadcaster said Monday',
#  'The ANC led struggle white rule power previously acknowledged told expect implication right violations',
#  'The Truth Reconciliation Commission release final report years investigation Thursday',
#  'The report expected place overwhelming blame era abuses white governments brutal security services',
#  'South African Broadcasting Corp radio said leaked preliminary document condemns ANC politically morally responsible gross human rights violations fall apartheid',
#  'ANC spokesman Thabo Masebe said believed news report referred commission letter sent advance informing intention implicate ANC gross human rights violations',
#  'Commission officials immediately reached comment',
#  'The ANC nervous report request meeting commissioners earlier month',
#  'The panel refused avoid appearing embarrassed',
#  'The party says accusations likely center planting land mines border farms abuses military camps Angola bombings',
#  'djw',
#  'Saddam says reap urges Iran normalize ties President Saddam Hussein said Saturday United States reap harvest thorns campaign Iraq',
#  'Addressing nation television mark anniversary end 1980 Iran Iraq war Saddam urged Iran normalize relations Iraq',
#  'Saddam refer decision Wednesday freeze cooperation arms inspectors said United States allies misled thought bring Iraq knees',
#  'This exactly Iranian government late Ayatollah Ruhollah Khomeini thought war failed Saddam said',
#  'Those imposing aggression Iraq unfair embargo neglect fact today Saddam said referring sweeping sanctions United Nations imposed Iraq 1990 invasion Kuwait',
#  'They making mistake',
#  'Their harvest thorns outcome taste bitterness',
#  'The president delivered speech black suit',
#  'decreed Saturday celebrated day victory Iran artillery salute 101 guns boomed Baghdad early morning',
#  'National radio television played patriotic songs occasion',
#  'Saddam spoke 7th graf pvs',
#  'International police seek stymie illegal art traffic king Police officers countries met Budapest seek efficient ways combat illegal traffic art treasures police official said Thursday',
#  'Held auspices Interpol International Police Organization day closed meeting allowed officers personal contact help East European counterparts catch',
#  'member team working illegal art traffic group set April France policemen years experience Hungarian police Col Tamas Simon said',
#  'Illegal art traffic growth industry',
#  '1990 year communism collapsed 702 registered cases Hungary total value stolen treasures million forints dlrs 340 000 present terms',
#  '1993 1996 025 cases involving 430 million forints dlrs million worth stolen treasures',
#  'This special area police work stolen art appear years market said Jean Pierre Jouanny director French national bureau Interpol',
#  'Hungary largely transit country stolen art line traffic moving east west',
#  'Work underway cataloging country art treasures establishing data base network contacts art dealers auctioneers museums',
#  '',
#  'Cohen Missile defense Gulf imperative Defense Secretary William Cohen said Saturday imperative allies Gulf acquire ballistic missile defense counter long range weapons hands countries Iran Iraq',
#  'Cohen said United States defense systems research development hope hope share technology Bahrain Gulf countries',
#  'speaking reporters leaving Qatar second stop nation Gulf tour includes United Arab Emirates Oman Kuwait Saudi Arabia',
#  'Because proliferation missile technology globally especially Gulf region believe important look ways cooperate allies said Cohen',
#  'think imperative countries cooperate develop theater missile protection people forces said Cohen citing threats Iran Iraq',
#  'The United States sees Iraq Iran recently tested long range missile major threats Gulf region',
#  'Cohen said Iraq sanctions continues efforts acquire missile technology longer permissible range']

# %%
for s in list_txt:
    tokenized_sent.append(word_tokenize(s.lower()))
# len(tokenized_sent)
tokenized_sent
# Out:
# [['london', 'nov'],
#  ['the',
#   'apparent',
#   'settlement',
#   'came',
#   'days',
#   'talks',
#   'involving',
#   'west',
#   'indies',
#   'players',
#   'officials',
#   'west',
#   'indies',
#   'south',
#   'africa',
#   'cricket',
#   'boards'],
#  ['the',
#   'crisis',
#   'came',
#   'head',
#   'wednesday',
#   'west',
#   'indies',
#   'cricket',
#   'board',
#   'fired',
#   'superstar',
#   'batsman',
#   'brian',
#   'lara',
#   'captain',
#   'carl',
#   'hooper',
#   'vice',
#   'captain'],
#  ['the',
#   'refused',
#   'travel',
#   'south',
#   'africa',
#   'demanding',
#   'better',
#   'pay',
#   'conditions',
#   'tour'],
#  ['team', 'members', 'insisted', 'lara', 'hooper', 'reinstated', 'settlement'],
#  ['jimmy',
#   'adams',
#   'treasurer',
#   'players',
#   'assocation',
#   'negotiated',
#   'behalf',
#   'players',
#   'monday',
#   'pat',
#   'rousseau',
#   'president',
#   'west',
#   'indies',
#   'cricket',
#   'board'],
#  ['ali',
#   'bacher',
#   'head',
#   'south',
#   'african',
#   'cricket',
#   'directly',
#   'involved',
#   'monday',
#   'talks',
#   'sitting',
#   'sidelines',
#   'sunday'],
#  ['west',
#   'indies',
#   'tour',
#   'manager',
#   'clive',
#   'lloyd',
#   'wicb',
#   'member',
#   'joel',
#   'garner',
#   'involved',
#   'talks',
#   'began',
#   'friday'],
#  ['progress',
#   'reported',
#   'weekend',
#   'announcement',
#   'sponsorship',
#   'deal',
#   'offered',
#   'south',
#   'african',
#   'wicketkeeper',
#   'david',
#   'richardson',
#   'runs',
#   'sports',
#   'marketing',
#   'firm',
#   'johannesburg'],
#  ['earnings',
#   'sponsorship',
#   'proposal',
#   'apparently',
#   'help',
#   'meet',
#   'players',
#   'demands',
#   'better',
#   'pay',
#   'reported',
#   'range',
#   'dlrs',
#   '000',
#   '000',
#   'south',
#   'african',
#   'tour'],
#  [],
#  ['spirited',
#   'bidders',
#   'snap',
#   'art',
#   'seized',
#   'failed',
#   'finance',
#   'firms',
#   'paintings',
#   'art',
#   'objects',
#   'displayed',
#   'elegant',
#   'offices',
#   'snapped',
#   'weekend',
#   'thailand',
#   'auction',
#   'assets',
#   'collapsed',
#   'financial',
#   'firms',
#   'thai',
#   'media',
#   'reported',
#   'sunday'],
#  ['the',
#   'day',
#   'auction',
#   '000',
#   'items',
#   'ended',
#   'sunday',
#   'expected',
#   'bring',
#   'initial',
#   'estimate',
#   'million',
#   'baht',
#   'dlrs',
#   '697',
#   '000'],
#  ['the',
#   'paintings',
#   'sculptures',
#   'art',
#   'related',
#   'objects',
#   'seized',
#   'thailand',
#   'financial',
#   'restructuring',
#   'authority',
#   'government',
#   'agency',
#   'set',
#   'liquidate',
#   'assets',
#   'finance',
#   'companies',
#   'shut',
#   'year'],
#  ['the',
#   'closings',
#   'required',
#   'international',
#   'monetary',
#   'fund',
#   'dlrs',
#   'billion',
#   'bailout',
#   'program',
#   'depressed',
#   'thai',
#   'economy'],
#  ['the', 'proceeds', 'auction', 'pay', 'debts', 'failed', 'companies'],
#  ['the',
#   'going',
#   'prices',
#   'high',
#   'higher',
#   'expected',
#   'art',
#   'gallery',
#   'owner',
#   'hongjorn',
#   'samae',
#   'ngamjaroen',
#   'quoted',
#   'saying',
#   'bangkok',
#   'post'],
#  ['untitled',
#   'painting',
#   'lotus',
#   'pond',
#   'late',
#   'thawee',
#   'nandakwang',
#   'sold',
#   'million',
#   'baht',
#   'dlrs',
#   '000',
#   'way',
#   'starting',
#   'bid',
#   '400',
#   '000',
#   'baht',
#   'dlrs',
#   '300'],
#  ['prime',
#   'minister',
#   'chuan',
#   'leekpai',
#   'donated',
#   'sketches',
#   'auction',
#   'handled',
#   'christies',
#   'british',
#   'auction',
#   'house'],
#  ['held', 'bangkok', 'queen', 'sirikit', 'natoinal', 'convention', 'center'],
#  ['repeating',
#   'protectively',
#   'iran',
#   'protest',
#   'international',
#   'court',
#   'justice',
#   'hague',
#   'global',
#   'bodies',
#   'funded',
#   'radio',
#   'free',
#   'europe',
#   'iran',
#   'daily',
#   'reported',
#   'monday'],
#  ['quoted',
#   'foreign',
#   'minister',
#   'kamal',
#   'kharrazi',
#   'saying',
#   'radio',
#   'set',
#   'interfere',
#   'iran',
#   'internal',
#   'affairs'],
#  ['complaints', 'filed'],
#  ['the',
#   'english',
#   'language',
#   'daily',
#   'organizations',
#   'iran',
#   'approach',
#   'icj',
#   'netherlands'],
#  ['tuesday',
#   'iran',
#   'recalled',
#   'ambassador',
#   'prague',
#   'protest',
#   'czech',
#   'government',
#   'assistance',
#   'radio',
#   'said',
#   'reduce',
#   'level',
#   'economic',
#   'political',
#   'cooperation',
#   'prague'],
#  ['the',
#   'american',
#   'sponsored',
#   'station',
#   'began',
#   'broadcasts',
#   'directed',
#   'iraq',
#   'friday'],
#  ['trial',
#   'period',
#   'weeks',
#   'station',
#   'broadcast',
#   'minute',
#   'program',
#   'day',
#   'iran',
#   'iraq'],
#  ['the',
#   'farsi',
#   'language',
#   'service',
#   'iran',
#   'approved',
#   'czech',
#   'government',
#   'august'],
#  ['radio',
#   'free',
#   'europe',
#   'began',
#   'transmitting',
#   'munich',
#   'germany',
#   '1951',
#   'spreading',
#   'uncensored',
#   'news',
#   'soviet',
#   'controlled',
#   'countries',
#   'iron',
#   'curtain',
#   'cold',
#   'war',
#   'west',
#   'communist',
#   'east'],
#  ['moved',
#   'headquarters',
#   'prague',
#   '1995',
#   'following',
#   'collapse',
#   'communism',
#   'years',
#   'earlier'],
#  [],
#  ['vietnam',
#   'prime',
#   'minister',
#   'demands',
#   'improvements',
#   'state',
#   'monopoly',
#   'prime',
#   'minister',
#   'phan',
#   'van',
#   'khai',
#   'taken',
#   'state',
#   'electricity',
#   'monopoly',
#   'task',
#   'abuse',
#   'power',
#   'excessive',
#   'bureaucracy',
#   'accusing',
#   'overcharging',
#   'newspaper',
#   'dau',
#   'investment',
#   'reported',
#   'thursday'],
#  ['blunt',
#   'assessment',
#   'ordered',
#   'electricity',
#   'vietnam',
#   'help',
#   'cut',
#   'waste',
#   'driving',
#   'costs',
#   'spark',
#   'public',
#   'discontent'],
#  ['evn',
#   'work',
#   'corrective',
#   'measures',
#   'based',
#   'instructions',
#   'individual',
#   'leaders',
#   'self',
#   'criticisms'],
#  ['khai',
#   'said',
#   'utility',
#   'plenty',
#   'problems',
#   'particularly',
#   'tender',
#   'process',
#   'project',
#   'accounting',
#   'led',
#   'complaints',
#   'affect',
#   'vietnam',
#   'reputation',
#   'foreign',
#   'investors'],
#  ['march',
#   'president',
#   'duc',
#   'anh',
#   'article',
#   'army',
#   'newspaper',
#   'criticized',
#   'irregularities',
#   'bidding',
#   'process',
#   'country',
#   'largest',
#   'thermal',
#   'electric',
#   'plant'],
#  ['local',
#   'media',
#   'reported',
#   'company',
#   'overblown',
#   'costs',
#   'construction',
#   'repair',
#   'work',
#   'number',
#   'projects',
#   'justify',
#   'overcharging',
#   'electricity'],
#  ['vietnam',
#   'chronically',
#   'short',
#   'power',
#   'projects',
#   'raise',
#   'output',
#   'bogged',
#   'bureaucracy'],
#  ['evn',
#   'imposed',
#   'rotating',
#   'power',
#   'cuts',
#   'earlier',
#   'year',
#   'worst',
#   'drought',
#   'century',
#   'dropped',
#   'water',
#   'levels',
#   'critical',
#   'levels',
#   'reservoir',
#   'feed',
#   'key',
#   'hydroelectric',
#   'plants'],
#  ['swiss',
#   'government',
#   'eyes',
#   'shutting',
#   'nuclear',
#   'power',
#   'plants',
#   'the',
#   'swiss',
#   'government',
#   'thursday',
#   'announced',
#   'planning',
#   'country',
#   'eventual',
#   'exit',
#   'nuclear',
#   'power',
#   'saying',
#   'wants',
#   'support',
#   'instead',
#   'hydroelectric',
#   'plants'],
#  ['but',
#   'environmental',
#   'campaigners',
#   'criticized',
#   'lack',
#   'timeframe',
#   'closing',
#   'country',
#   'nuclear',
#   'power',
#   'plants'],
#  ['government',
#   'officials',
#   'work',
#   'representatives',
#   'power',
#   'industry',
#   'environmental',
#   'groups',
#   'local',
#   'governments',
#   'discuss',
#   'timetable',
#   'removal',
#   'nuclear',
#   'waste',
#   'government',
#   'statement',
#   'said'],
#  ['unrealistic',
#   'build',
#   'power',
#   'stations',
#   'environmental',
#   'concerns',
#   'government',
#   'said'],
#  ['should',
#   'discussions',
#   'concerned',
#   'parties',
#   'fail',
#   'produce',
#   'agreed',
#   'timetable',
#   'federal',
#   'cabinet',
#   'decision',
#   'said',
#   'statement'],
#  ['set',
#   'new',
#   'course',
#   'said',
#   'federal',
#   'energy',
#   'minister',
#   'moritz',
#   'leuenberger'],
#  ['details', 'decided'],
#  ['related',
#   'federal',
#   'cabinet',
#   'ordered',
#   'energy',
#   'officials',
#   'draw',
#   'discussion',
#   'paper',
#   'changing',
#   'laws',
#   'governing',
#   'domestic',
#   'electricity',
#   'market'],
#  ['the',
#   'government',
#   'envisages',
#   'creation',
#   'national',
#   'company',
#   'power',
#   'infrastructure'],
#  ['timeframe',
#   'carrying',
#   'liberalization',
#   'electricity',
#   'market',
#   'remains',
#   'determined',
#   'cabinet',
#   'said'],
#  ['the', 'cabinet', 'said', 'wants', 'support', 'hydroelectric', 'plants'],
#  ['ordered',
#   'study',
#   'possibility',
#   'tax',
#   'breaks',
#   'hydroelectric',
#   'plants',
#   'encourage',
#   'upgrades',
#   'plants'],
#  ['london', 'nov'],
#  ['word',
#   'agreement',
#   'leaked',
#   'captain',
#   'courtney',
#   'walsh',
#   'head',
#   'west',
#   'indies',
#   'players',
#   'association',
#   'told',
#   'caribbean',
#   'news',
#   'agency',
#   'lara',
#   'hooper',
#   'reinstated',
#   'tour',
#   'going',
#   'ahead'],
#  ['the',
#   'crisis',
#   'came',
#   'head',
#   'wednesday',
#   'west',
#   'indies',
#   'cricket',
#   'board',
#   'fired',
#   'superstar',
#   'batsman',
#   'lara',
#   'captain',
#   'hooper',
#   'vice',
#   'captain'],
#  ['the',
#   'refused',
#   'travel',
#   'south',
#   'africa',
#   'demanding',
#   'better',
#   'pay',
#   'conditions',
#   'tour'],
#  ['team', 'members', 'insisted', 'lara', 'hooper', 'reinstated', 'settlement'],
#  ['jimmy',
#   'adams',
#   'treasurer',
#   'players',
#   'assocation',
#   'negotiated',
#   'behalf',
#   'players',
#   'monday',
#   'rousseau'],
#  ['ali',
#   'bacher',
#   'head',
#   'south',
#   'african',
#   'cricket',
#   'directly',
#   'involved',
#   'monday',
#   'talks',
#   'sitting',
#   'sidelines',
#   'sunday'],
#  ['west',
#   'indies',
#   'tour',
#   'manager',
#   'clive',
#   'lloyd',
#   'wicb',
#   'member',
#   'joel',
#   'garner',
#   'involved',
#   'talks',
#   'began',
#   'friday'],
#  ['progress',
#   'reported',
#   'weekend',
#   'announcement',
#   'sponsorship',
#   'deal',
#   'offered',
#   'south',
#   'african',
#   'wicketkeeper',
#   'david',
#   'richardson',
#   'runs',
#   'sports',
#   'marketing',
#   'firm',
#   'johannesburg'],
#  ['earnings',
#   'sponsorship',
#   'proposal',
#   'apparently',
#   'help',
#   'meet',
#   'players',
#   'demands',
#   'better',
#   'pay',
#   'reported',
#   'range',
#   'dlrs',
#   '000',
#   '000',
#   'south',
#   'african',
#   'tour'],
#  [],
#  ['airport',
#   'ready',
#   'operation',
#   'palestinians',
#   'await',
#   'word',
#   'israel',
#   'the',
#   'new',
#   'palestinian',
#   'airport',
#   'powerful',
#   'symbol',
#   'fledgling',
#   'independence',
#   'ready',
#   'open',
#   'head',
#   'palestinian',
#   'civil',
#   'aviation',
#   'authority',
#   'said',
#   'friday',
#   'operations',
#   'drill',
#   'israeli',
#   'officials'],
#  ['yasser',
#   'arafat',
#   'international',
#   'airport',
#   'southern',
#   'gaza',
#   'strip',
#   'opened',
#   'week',
#   'israeli',
#   'palestinian',
#   'peace',
#   'agreement'],
#  ['however',
#   'israel',
#   'fell',
#   'schedule',
#   'held',
#   'cabinet',
#   'ratification',
#   'accord',
#   'weeks'],
#  ['prime',
#   'minister',
#   'benjamin',
#   'netanyahu',
#   'said',
#   'airport',
#   'start',
#   'operating',
#   'week',
#   'set',
#   'date'],
#  ['thursday',
#   'israeli',
#   'palestinian',
#   'officials',
#   'staged',
#   'hour',
#   'drill',
#   'said',
#   'fayez',
#   'zeidan',
#   'head',
#   'palestinian',
#   'civil',
#   'aviation',
#   'authority'],
#  ['about',
#   '100',
#   'palestinian',
#   'airport',
#   'employees',
#   'israelis',
#   'share',
#   'security',
#   'duties',
#   'played',
#   'roles',
#   'passengers',
#   'airport',
#   'personnel'],
#  ['for', 'lack', 'plane', 'passengers', 'arrived', 'bus'],
#  ['zeidan',
#   'said',
#   'exercise',
#   'covered',
#   'arrival',
#   'departure',
#   'procedures',
#   'including',
#   'passport',
#   'checks',
#   'customs',
#   'luggage',
#   'inspection'],
#  ['said', 'airport', 'ready', 'operation'],
#  ['need', 'hear', 'israelis', 'zeidan', 'said'],
#  ['stolen',
#   'painting',
#   'new',
#   'zealand',
#   'recovered',
#   'man',
#   'arrested',
#   '19th',
#   'century',
#   'painting',
#   'worth',
#   'dlrs',
#   'million',
#   'stolen',
#   'auckland',
#   'art',
#   'gallery',
#   'days',
#   'ago',
#   'recovered',
#   'police',
#   'said',
#   'monday'],
#  ['senior', 'sgt'],
#  ['gary',
#   'allcock',
#   'said',
#   'understood',
#   'person',
#   'arrested',
#   'theft',
#   '1874',
#   'oil',
#   'still',
#   'top',
#   'french',
#   'born',
#   'artist',
#   'jacques',
#   'joseph',
#   'james',
#   'tissot',
#   'new',
#   'zealand',
#   'expensive',
#   'popular',
#   'european',
#   'works'],
#  ['said', 'details', 'disclosed', 'later'],
#  ['the',
#   'painting',
#   'valued',
#   'dlrs',
#   'million',
#   'stolen',
#   'aug',
#   'man',
#   'armed',
#   'shotgun',
#   'daring',
#   'robbery',
#   'auckland',
#   'art',
#   'gallery'],
#  ['the',
#   'man',
#   'clad',
#   'black',
#   'wearing',
#   'motorcycle',
#   'helmet',
#   'dark',
#   'visor',
#   'gloves',
#   'burst',
#   'main',
#   'door',
#   'sawed',
#   'shotgun',
#   'crowbar'],
#  ['museum',
#   'official',
#   'kate',
#   'darrow',
#   'said',
#   'man',
#   'ran',
#   'grey',
#   'gallery',
#   'waving',
#   'firearm',
#   'yelling',
#   'staff',
#   'patrons'],
#  ['she',
#   'said',
#   'man',
#   'appeared',
#   'know',
#   'going',
#   'went',
#   'lower',
#   'wellesley',
#   'gallery',
#   'painting',
#   'displayed'],
#  ['the', 'gunman', 'grabbed', 'painting', 'wall', 'dropped', 'ground'],
#  ['crowbar', 'remove', 'canvas', 'frame', 'backing', 'board'],
#  ['the',
#   'robber',
#   'left',
#   'main',
#   'entrance',
#   'skirted',
#   'gallery',
#   'albert',
#   'park',
#   'pursued',
#   'member',
#   'public'],
#  ['believed', 'climbed', 'motorcycle', 'escaped', 'nearby', 'highway'],
#  ['english',
#   'viravaidya',
#   'plan',
#   'set',
#   'watchdog',
#   'company',
#   'monitor',
#   'set',
#   'listed',
#   'companies',
#   'expose',
#   'possible',
#   'abuses',
#   'corporate',
#   'ethics'],
#  ['agree',
#   'heartedly',
#   'like',
#   'know',
#   'mail',
#   'checks',
#   'subscribe',
#   'company',
#   'shares'],
#  ['could', 'advise'],
#  ['also',
#   'fully',
#   'support',
#   'request',
#   'media',
#   'report',
#   'lifestyle',
#   'executives',
#   'failed',
#   'banks',
#   'finance',
#   'companies'],
#  ['know',
#   'people',
#   'punished',
#   'legally',
#   'inefficiency',
#   'bank',
#   'thailand',
#   'collecting',
#   'evidence',
#   'justice',
#   'delivering',
#   'timely',
#   'justice'],
#  ['media',
#   'job',
#   'discover',
#   'guys',
#   'better',
#   'destroying',
#   'country',
#   'thai',
#   'people',
#   'job',
#   'socially',
#   'punish'],
#  ['like',
#   'propose',
#   'newspapers',
#   'stations',
#   'play',
#   'issue',
#   'continued',
#   'luxurious',
#   'lifestyle',
#   'executives',
#   'attract',
#   'public',
#   'attention',
#   'bt20',
#   '000',
#   'hard',
#   'earned',
#   'salary',
#   'blessing'],
#  ['artit',
#   'krichphiphat',
#   'ordinary',
#   'thai',
#   'citizen',
#   'wants',
#   'right',
#   'things',
#   'editor',
#   'note',
#   'khun',
#   'mechai',
#   'organise',
#   'seminar',
#   'plan',
#   'june',
#   'telephone',
#   'organisation',
#   'thailand'],
#  ['the',
#   'media',
#   'duty',
#   'cover',
#   'issues',
#   'additional',
#   'financial',
#   'reward'],
#  ['iran',
#   'complain',
#   'radio',
#   'hague',
#   'tribunal',
#   'iran',
#   'protest',
#   'international',
#   'court',
#   'justice',
#   'hague',
#   'global',
#   'bodies',
#   'funded',
#   'radio',
#   'free',
#   'europe',
#   'iran',
#   'daily',
#   'reported',
#   'monday'],
#  ['quoted',
#   'foreign',
#   'minister',
#   'kamal',
#   'kharrazi',
#   'saying',
#   'radio',
#   'set',
#   'interfere',
#   'iran',
#   'internal',
#   'affairs'],
#  ['complaints', 'filed'],
#  ['the',
#   'english',
#   'language',
#   'daily',
#   'organizations',
#   'iran',
#   'approach',
#   'icj',
#   'netherlands'],
#  ['tuesday',
#   'iran',
#   'recalled',
#   'ambassador',
#   'prague',
#   'protest',
#   'czech',
#   'government',
#   'assistance',
#   'radio',
#   'said',
#   'reduce',
#   'level',
#   'economic',
#   'political',
#   'cooperation',
#   'prague'],
#  ['the',
#   'american',
#   'sponsored',
#   'station',
#   'began',
#   'broadcasts',
#   'directed',
#   'iraq',
#   'friday'],
#  ['trial',
#   'period',
#   'weeks',
#   'station',
#   'broadcast',
#   'minute',
#   'program',
#   'day',
#   'iran',
#   'iraq'],
#  ['the',
#   'farsi',
#   'language',
#   'service',
#   'iran',
#   'approved',
#   'czech',
#   'government',
#   'august'],
#  ['radio',
#   'free',
#   'europe',
#   'began',
#   'transmitting',
#   'munich',
#   'germany',
#   '1951',
#   'spreading',
#   'uncensored',
#   'news',
#   'soviet',
#   'controlled',
#   'countries',
#   'iron',
#   'curtain',
#   'cold',
#   'war',
#   'west',
#   'communist',
#   'east'],
#  ['moved',
#   'headquarters',
#   'prague',
#   '1995',
#   'following',
#   'collapse',
#   'communism',
#   'years',
#   'earlier'],
#  ['museum',
#   'return',
#   'stolen',
#   'works',
#   'los',
#   'angeles',
#   'the',
#   'paul',
#   'getty',
#   'museum',
#   'returning',
#   'ancient',
#   'works',
#   'art',
#   'italy',
#   'determining',
#   'stolen'],
#  ['one', 'sculpture', 'sat', 'collection', 'years'],
#  ['the',
#   'objects',
#   'flown',
#   'italy',
#   'week',
#   'pieces',
#   'loaned',
#   'museum',
#   'antiquities',
#   'exhibit',
#   'according',
#   'statement',
#   'issued',
#   'getty',
#   'monday'],
#  ['the', 'stolen', 'items', 'terra', 'cotta', 'drinking', 'cup', '480'],
#  ['illegally',
#   'excavated',
#   'archaeological',
#   'site',
#   'torso',
#   'god',
#   'mithras',
#   '2nd',
#   'century',
#   'stolen',
#   'private',
#   'italian',
#   'collection',
#   'sculpted',
#   'head',
#   'victorious',
#   'athlete',
#   '2nd',
#   'century',
#   'roman',
#   'copy',
#   'earlier',
#   'greek',
#   'work',
#   'apparently',
#   'taken',
#   'storeroom',
#   'scientific',
#   'excavation'],
#  ['for', 'security', 'reasons', 'museum', 'pieces', 'worth'],
#  ['although',
#   'claimed',
#   'works',
#   'getty',
#   'decided',
#   'return',
#   'based',
#   'information',
#   'supplied',
#   'experts',
#   'field',
#   'consultation',
#   'italian',
#   'officials'],
#  ['international',
#   'concern',
#   'growing',
#   'rampant',
#   'thefts',
#   'priceless',
#   'art',
#   'collections',
#   'looting',
#   'archaeological',
#   'sites'],
#  ['the',
#   'billion',
#   'dollar',
#   'museum',
#   'located',
#   'hill',
#   'brentwood',
#   'area',
#   'opened',
#   '1997'],
#  ['iraq',
#   'iran',
#   'sign',
#   'pact',
#   'resolve',
#   'pow',
#   'issue',
#   'iraq',
#   'iran',
#   'signed',
#   'deal',
#   'iraq',
#   'says',
#   'resolve',
#   'longstanding',
#   'dispute',
#   'prisoners',
#   'war'],
#  ['the',
#   'agreement',
#   'reached',
#   'following',
#   'week',
#   'talks',
#   'baghdad',
#   'senior',
#   'iraqi',
#   'officials',
#   'visiting',
#   'iranian',
#   'delegation',
#   'headed',
#   'abdullah',
#   'najafi',
#   'head',
#   'iran',
#   'pow',
#   'commission',
#   'official',
#   'iraqi',
#   'news',
#   'agency',
#   'reported',
#   'wednesday'],
#  ['but',
#   'agency',
#   'gave',
#   'details',
#   'najafi',
#   'left',
#   'baghdad',
#   'wednesday',
#   'declined',
#   'comment'],
#  ['najafi',
#   'arrived',
#   'baghdad',
#   'week',
#   'list',
#   'thousands',
#   'iranian',
#   'pows',
#   'tehran',
#   'claims',
#   'held',
#   'iraq'],
#  ['iraq',
#   'long',
#   'maintained',
#   'released',
#   'iranian',
#   'prisoners',
#   'reportedly',
#   'angered',
#   'new',
#   'list'],
#  ['april',
#   'iran',
#   'released',
#   '584',
#   'iraqi',
#   'pows',
#   'iraq',
#   'freed',
#   'pows',
#   '316',
#   'iranians',
#   'classified',
#   'civil',
#   'law',
#   'detainees'],
#  ['largest',
#   'repatriation',
#   'iranian',
#   'iraqi',
#   'pows',
#   '1990',
#   'said',
#   'international',
#   'committee',
#   'red',
#   'cross',
#   'supervised',
#   'swap'],
#  ['the',
#   'red',
#   'cross',
#   'says',
#   'knows',
#   'thousand',
#   'iraqis',
#   'iran',
#   'aware',
#   'iranian',
#   'pows',
#   'iraq'],
#  ['the',
#   'iran',
#   'iraq',
#   'war',
#   'million',
#   'people',
#   'killed',
#   'wounded',
#   'ended',
#   '1988'],
#  ['the', 'issue', 'pows', 'long', 'stood', 'way', 'better', 'ties'],
#  [],
#  ['hare',
#   'closes',
#   'terminal',
#   'security',
#   'chicago',
#   'united',
#   'airlines',
#   'shut',
#   'terminal',
#   'hours',
#   'authorities',
#   'search',
#   'passenger',
#   'ran',
#   'past',
#   'security',
#   'checkpoint',
#   'disappeared',
#   'crowd',
#   'hare',
#   'international',
#   'airport'],
#  ['united',
#   'spokeswoman',
#   'kristina',
#   'price',
#   'said',
#   '131',
#   'flights',
#   'canceled',
#   'thursday',
#   '100',
#   'delayed',
#   'nationwide',
#   'incident'],
#  ['about',
#   '000',
#   'passengers',
#   'cleared',
#   'terminal',
#   'search',
#   'airline',
#   'officials',
#   'said'],
#  ['eighty',
#   'flights',
#   'canceled',
#   'today',
#   'numerous',
#   'delayed',
#   'effects',
#   'shutdown',
#   'lingered',
#   'price',
#   'said',
#   'adding',
#   'carrier',
#   'hoped',
#   'normal',
#   'schedule',
#   'afternoon'],
#  ['the',
#   'man',
#   'chicago',
#   'police',
#   'said',
#   'officers',
#   'turned',
#   'suspicious'],
#  ['leaving',
#   'concourse',
#   'heading',
#   'baggage',
#   'claim',
#   'area',
#   'turned',
#   'ran',
#   'way',
#   'staircase',
#   'leading',
#   'concourse',
#   'united',
#   'spokesman',
#   'matthew',
#   'triaca',
#   'said'],
#  ['guards', 'stationed', 'staircase', 'man', 'ran', 'past'],
#  ['united',
#   'flights',
#   'left',
#   'terminal',
#   'search',
#   'landed',
#   'united',
#   'gates'],
#  ['some', 'flights', 'resumed', 'early', 'evening'],
#  ['iraqi',
#   'minister',
#   'arrives',
#   'iran',
#   'attend',
#   'trade',
#   'fair',
#   'iraq',
#   'trade',
#   'minister',
#   'arrived',
#   'wednesday',
#   'attend',
#   'international',
#   'trade',
#   'fair',
#   'hold',
#   'discussions',
#   'iranian',
#   'counterpart',
#   'islamic',
#   'republic',
#   'news',
#   'agency',
#   'reported'],
#  ['mohammed',
#   'mehdi',
#   'saleh',
#   'seven',
#   'member',
#   'delegation',
#   'traveled',
#   'land',
#   'crossed',
#   'iran',
#   'khosrawi',
#   'border',
#   'point',
#   'western',
#   'kermanshah',
#   'province',
#   'official',
#   'news',
#   'agency',
#   'said'],
#  ['quoted',
#   'saleh',
#   'saying',
#   'discuss',
#   'iran',
#   'trade',
#   'minister',
#   'mohammad',
#   'shariat',
#   'madari',
#   'ways',
#   'expanding',
#   'commercial',
#   'ties',
#   'countries'],
#  ['the', 'fair', 'scheduled', 'oct'],
#  ['this',
#   'second',
#   'consecutive',
#   'year',
#   'iraq',
#   'attending',
#   'tehran',
#   'international',
#   'trade',
#   'fair',
#   'points',
#   'need',
#   'neighbors',
#   'business',
#   'despite',
#   'traditional',
#   'animosity'],
#  ['iran', 'iraq', 'fought', 'year', 'war', 'ended', 'brokered', 'cease'],
#  ['iran',
#   'claims',
#   'iraq',
#   'holds',
#   '000',
#   'prisoners',
#   'war',
#   'iraq',
#   'says',
#   'iran',
#   'holding',
#   '000',
#   'prisoners'],
#  ['more', 'million', 'people', 'killed', 'wounded', 'sides', '1980', 'war'],
#  ['tehran',
#   'accuses',
#   'baghdad',
#   'helping',
#   'iranian',
#   'opposition',
#   'groups',
#   'sides',
#   'accuse',
#   'allowing',
#   'infiltrators',
#   'sneak',
#   'borders',
#   'acts',
#   'sabotage'],
#  ['december',
#   'iraqi',
#   'vice',
#   'president',
#   'taha',
#   'yassin',
#   'ramadan',
#   'highest',
#   'ranking',
#   'iraqi',
#   'visit',
#   'tehran',
#   '1991',
#   'gulf',
#   'war',
#   'attended',
#   'organization',
#   'islamic',
#   'conference',
#   'meeting'],
#  [],
#  ['actress',
#   'brooke',
#   'shields',
#   'accepts',
#   'libel',
#   'damages',
#   'apology',
#   'false',
#   'actress',
#   'brooke',
#   'shields',
#   'monday',
#   'accepted',
#   'substantial',
#   'libel',
#   'damages',
#   'public',
#   'apology',
#   'newspaper',
#   'article',
#   'alleging',
#   'questioned',
#   'police',
#   'hours',
#   'connection',
#   'drug',
#   'offenses',
#   'left',
#   'cannes',
#   'film',
#   'festival'],
#  ['the',
#   'mail',
#   'sunday',
#   'reported',
#   'may',
#   'exclusive',
#   'began',
#   'page',
#   'continued',
#   'page',
#   'miss',
#   'shields',
#   'luggage',
#   'searched',
#   'flight',
#   'nice',
#   'airport',
#   'delayed',
#   'french',
#   'police',
#   'quizzed'],
#  ['after',
#   'actress',
#   'filed',
#   'suit',
#   'associated',
#   'newspapers',
#   'ltd',
#   'publisher',
#   'mail',
#   'sunday',
#   'paper',
#   'editor',
#   'mail',
#   'journalists',
#   'mail',
#   'sunday',
#   'published',
#   'page',
#   'apology',
#   'retraction',
#   'may'],
#  ['the',
#   'retraction',
#   'said',
#   'story',
#   'totally',
#   'false',
#   'conceded',
#   'miss',
#   'shields',
#   'stopped',
#   'airport'],
#  ['the',
#   'defendants',
#   'recognize',
#   'miss',
#   'shields',
#   'staunch',
#   'committed',
#   'anti',
#   'drug',
#   'campaigner',
#   'spent',
#   'considerable',
#   'amounts',
#   'time',
#   'supporting',
#   'substance',
#   'abuse',
#   'programs',
#   'raising',
#   'needed',
#   'money',
#   'anti',
#   'drug',
#   'abuse',
#   'programs',
#   'said',
#   'claire',
#   'shields',
#   'defendants',
#   'attorney'],
#  ['the',
#   'newspaper',
#   'page',
#   'article',
#   'especially',
#   'hurtful',
#   'family',
#   'attorney',
#   'said'],
#  ['the',
#   'sunday',
#   'paper',
#   'editor',
#   'jonathan',
#   'holborow',
#   'written',
#   'actress',
#   'present',
#   'court',
#   'monday',
#   'personal',
#   'letter',
#   'apology'],
#  ['the', 'damages', 'disclosed'],
#  [],
#  ['hungarian',
#   'government',
#   'jewish',
#   'communities',
#   'agree',
#   'compensation',
#   'the',
#   'hungarian',
#   'government',
#   'federation',
#   'hungarian',
#   'jewish',
#   'communities',
#   'signed',
#   'agreement',
#   'thursday',
#   'collective',
#   'compensation',
#   'communist',
#   'era',
#   'confiscations',
#   'state',
#   'news',
#   'agency',
#   'mti',
#   'reported'],
#  ['the',
#   'financial',
#   'basis',
#   'funding',
#   'real',
#   'estate',
#   'belonged',
#   'jewish',
#   'communities',
#   'fell',
#   'victim',
#   'nationalization',
#   'communists'],
#  ['instead',
#   'getting',
#   'actual',
#   'property',
#   '152',
#   'schools',
#   'buildings',
#   'assessed',
#   'value',
#   '511',
#   '000',
#   '000',
#   'forints',
#   'dlrs',
#   'million',
#   'jewish',
#   'community',
#   'collectively',
#   'percentage',
#   'annually',
#   'starting',
#   'current',
#   'year',
#   '608',
#   'million',
#   'forints',
#   'dlrs',
#   'million',
#   'paid'],
#  ['the',
#   'money',
#   'mainly',
#   'education',
#   'religious',
#   'services',
#   'social',
#   'welfare',
#   'health',
#   'service',
#   'charity',
#   'ends',
#   'gusztav',
#   'zoltai',
#   'executive',
#   'director',
#   'federation',
#   'said'],
#  ['there', '000', '100', '000', 'jews', 'hungary'],
#  ['some', '600', '000', 'killed', 'holocaust'],
#  ['when',
#   'communists',
#   'assumed',
#   'power',
#   '1948',
#   'started',
#   'wave',
#   'nationalizations',
#   'spared',
#   'including',
#   'jewish',
#   'community'],
#  ['june',
#   '1997',
#   'similar',
#   'agreement',
#   'kind',
#   'signed',
#   'hungarian',
#   'government',
#   'vatican'],
#  [],
#  ['thailand',
#   'more',
#   'people',
#   'dying',
#   'suffering',
#   'fatal',
#   'diseases',
#   'brain',
#   'tumours',
#   'mammarian',
#   'breast',
#   'cancer',
#   'brain',
#   'haemorrhage',
#   'lack',
#   'proper',
#   'medical',
#   'care',
#   'however',
#   'things',
#   'change',
#   'srisiam',
#   'hospital',
#   'bangkok',
#   'established',
#   'radio',
#   'surgery',
#   'institute',
#   'thailand',
#   'presently',
#   '100',
#   'radio',
#   'surgery',
#   'centres',
#   'world'],
#  ['radio',
#   'surgery',
#   'modern',
#   'technique',
#   'require',
#   'surgery',
#   'order',
#   'remove',
#   'cancerous',
#   'growth',
#   'tissues'],
#  ['involves',
#   'dimensional',
#   'method',
#   'known',
#   'stereotaxic',
#   'surgery',
#   'conjunction',
#   'radiation',
#   'equipment',
#   'known',
#   'linear',
#   'accelerator'],
#  ['with',
#   'new',
#   'technology',
#   'doctors',
#   'able',
#   'removal',
#   'cancerous',
#   'tissues',
#   'embedded',
#   'deep',
#   'inside',
#   'brain',
#   'near',
#   'sensitive',
#   'organs',
#   'makes',
#   'normal',
#   'surgery',
#   'difficult',
#   'risky'],
#  ['with',
#   'radio',
#   'surgery',
#   'step',
#   'controlled',
#   'computers',
#   'patients',
#   'conscious',
#   'undergo',
#   'treatment'],
#  ['this',
#   'new',
#   'technique',
#   'capable',
#   'treating',
#   'diseases',
#   'artero',
#   'venous',
#   'malformation',
#   'clotting',
#   'veins',
#   'blood',
#   'capillaries',
#   'brain',
#   'far',
#   'ninety',
#   'cent',
#   'radio',
#   'surgery',
#   'treatments',
#   'successful',
#   'patients',
#   'remain',
#   'hospital',
#   'days'],
#  ['additionally',
#   'need',
#   'patients',
#   'shave',
#   'heads',
#   'radio',
#   'surgery',
#   'causes',
#   'scar',
#   'little',
#   'blood',
#   'loss',
#   'expensive',
#   'for',
#   'information',
#   'contact',
#   'hospital',
#   'srisiam',
#   'ksc',
#   'com'],
#  ['iranian',
#   'pow',
#   'negotiator',
#   'holds',
#   'talks',
#   'iraqi',
#   'ministers',
#   'the',
#   'head',
#   'iran',
#   'prisoner',
#   'war',
#   'commission',
#   'met',
#   'iraqi',
#   'cabinet',
#   'ministers',
#   'saturday',
#   'bid',
#   'glean',
#   'information',
#   'thousands',
#   'iranian',
#   'pows',
#   'allegedly',
#   'iraq',
#   'official',
#   'iraqi',
#   'news',
#   'agency',
#   'reported'],
#  ['iraqi',
#   'foreign',
#   'minister',
#   'mohammed',
#   'saeed',
#   'sahhaf',
#   'told',
#   'abdullah',
#   'najafi',
#   'states',
#   'needed',
#   'speed',
#   'closure',
#   'remains',
#   'pow',
#   'missing',
#   'action',
#   'file',
#   'ina',
#   'said'],
#  ['the',
#   'issue',
#   'pows',
#   'missing',
#   'persons',
#   'remains',
#   'stumbling',
#   'block',
#   'normalizing',
#   'relations',
#   'neighbors'],
#  ['iraq',
#   'long',
#   'maintained',
#   'released',
#   'iranian',
#   'prisoners',
#   'captured',
#   '1980',
#   'iran',
#   'iraq',
#   'war'],
#  ['the',
#   'countries',
#   'accuse',
#   'hiding',
#   'pows',
#   'preventing',
#   'visits',
#   'international',
#   'committee',
#   'red',
#   'cross',
#   'prisoner',
#   'camps'],
#  ['the',
#   'icrc',
#   'representative',
#   'baghdad',
#   'manuel',
#   'bessler',
#   'told',
#   'the',
#   'associated',
#   'press',
#   'organization',
#   'difficulty',
#   'visiting',
#   'pows',
#   'sides',
#   'regular',
#   'basis'],
#  ['april',
#   'iran',
#   'released',
#   '584',
#   'iraqi',
#   'pows',
#   'iraq',
#   'freed',
#   'pows',
#   '316',
#   'iranians',
#   'classified',
#   'civil',
#   'law',
#   'detainees',
#   'largest',
#   'exchange',
#   '1990'],
#  ['more', 'million', 'people', 'killed', 'wounded', 'iran', 'iraq', 'war'],
#  ['german',
#   'zoo',
#   'hopes',
#   'court',
#   'allow',
#   'accept',
#   'baby',
#   'elephants',
#   'the',
#   'dresden',
#   'zoo',
#   'went',
#   'court',
#   'tuesday',
#   'challenge',
#   'environment',
#   'minister',
#   'juergen',
#   'trittin',
#   'order',
#   'forbidding',
#   'import',
#   'baby',
#   'elephants',
#   'taken',
#   'wild',
#   'africa',
#   'abused'],
#  ['zoo',
#   'director',
#   'hubert',
#   'luecker',
#   'said',
#   'complaint',
#   'filed',
#   'administrative',
#   'court',
#   'cologne'],
#  ['the',
#   'elephants',
#   'sent',
#   'month',
#   'dresden',
#   'erfurt',
#   'zoos',
#   'eastern',
#   'germany',
#   'group',
#   'young',
#   'elephants',
#   'captured',
#   'august',
#   'herds',
#   'botswana',
#   'taken',
#   'south',
#   'african',
#   'farm'],
#  ['south',
#   'african',
#   'judge',
#   'ruled',
#   'early',
#   'month',
#   'animals',
#   'abused',
#   'deprived',
#   'water',
#   'farm'],
#  ['granted',
#   'temporary',
#   'custody',
#   'national',
#   'society',
#   'prevention',
#   'cruelty',
#   'animals'],
#  ['but',
#   'judge',
#   'approved',
#   'export',
#   'baby',
#   'elephants',
#   'germany',
#   'switzerland',
#   'trittin',
#   'week',
#   'said',
#   'germany',
#   'protest',
#   'abuse',
#   'animals',
#   'accepting',
#   'zoos'],
#  ['others', 'argue', 'elephants', 'face', 'worse', 'fate', 'come', 'germany'],
#  ['norbert',
#   'otto',
#   'federal',
#   'lawmaker',
#   'erfurt',
#   'demanded',
#   'parliament',
#   'tuesday',
#   'trittin',
#   'steps',
#   'prevent',
#   'animals',
#   'sleep',
#   'south',
#   'africa'],
#  ['addition',
#   'cultural',
#   'minister',
#   'saxony',
#   'dresden',
#   'capital',
#   'asked',
#   'state',
#   '740',
#   '000',
#   'school',
#   'children',
#   'write',
#   'letters',
#   'protest',
#   'urging',
#   'tritten',
#   'allow',
#   'elephants',
#   'germany'],
#  ['aet', 'pfg'],
#  ['malaysia',
#   'port',
#   'dickson',
#   'tues',
#   'federal',
#   'state',
#   'government',
#   'agencies',
#   'given',
#   'task',
#   'undertake',
#   'economic',
#   'projects',
#   'development',
#   'programme',
#   'hardcore',
#   'poor',
#   'pprt',
#   'ensure',
#   'successful',
#   'implementation'],
#  ['rural',
#   'development',
#   'minister',
#   'datuk',
#   'annuar',
#   'musa',
#   'said',
#   'yesterday',
#   'responsible',
#   'closely',
#   'monitor',
#   'implementation',
#   'projects',
#   'ensure',
#   'allocation',
#   'provided',
#   'ministry',
#   'benefit',
#   'hardcore',
#   'poor',
#   'participants'],
#  ['said',
#   'responsible',
#   'including',
#   'district',
#   'officers',
#   'personally',
#   'check',
#   'progress',
#   'projects',
#   'carried'],
#  ['want',
#   'projects',
#   'success',
#   'paper',
#   'inspection',
#   'desired',
#   'results',
#   'added'],
#  ['according',
#   'ministry',
#   'policy',
#   'minister',
#   'deputy',
#   'minister',
#   'parliamentary',
#   'secretary',
#   'director',
#   'general',
#   'senior',
#   'ministry',
#   'officials',
#   'visit',
#   'pprt',
#   'projects',
#   'happening',
#   'allocation',
#   'given',
#   'government'],
#  ['annuar',
#   'said',
#   'visiting',
#   'mussel',
#   'rearing',
#   'project',
#   'kuala',
#   'lukut',
#   'today',
#   'day',
#   'long',
#   'visit',
#   'pprt',
#   'projects',
#   'negri',
#   'sembilan'],
#  ['present',
#   'chembong',
#   'assemblyman',
#   'firdaus',
#   'harun',
#   'port',
#   'dickson',
#   'district',
#   'officer',
#   'hassan',
#   'nawawi',
#   'abdul',
#   'rahman'],
#  ['annuar',
#   'added',
#   'implementing',
#   'agencies',
#   'conduct',
#   'depth',
#   'studies',
#   'projects',
#   'proposed',
#   'ensure',
#   'viability'],
#  ['interpol',
#   'needs',
#   'revamp',
#   'strategy',
#   'abreast',
#   'crime',
#   'interpol',
#   'modernize',
#   'wants',
#   'effectively',
#   'fight',
#   'increasingly',
#   'sophisticated',
#   'crime',
#   'syndicates',
#   'century',
#   'police',
#   'organization',
#   'president',
#   'said',
#   'thursday'],
#  ['the',
#   'criminal',
#   'environment',
#   'changed',
#   'greater',
#   'pace',
#   'interpol',
#   'toshinori',
#   'kanemoto',
#   'told',
#   'opening',
#   'session',
#   '67th',
#   'general',
#   'assembly',
#   'international',
#   'criminal',
#   'police',
#   'organization'],
#  ['failure',
#   'modernize',
#   'interpol',
#   'mean',
#   'organization',
#   'risks',
#   'displaced',
#   'backdrop',
#   'international',
#   'organized',
#   'crime',
#   'said'],
#  ['kanemoto',
#   'said',
#   'new',
#   'interpol',
#   'strategy',
#   'discussed',
#   'day',
#   'assembly',
#   'adopted',
#   'effect',
#   'january'],
#  ['the',
#   'japanese',
#   'police',
#   'official',
#   'said',
#   'assembly',
#   'discuss',
#   'terrorism',
#   'called',
#   'new',
#   'forms',
#   'criminality',
#   'illegal',
#   'drug',
#   'trade',
#   'money',
#   'laundering'],
#  ['with',
#   'crime',
#   'increasingly',
#   'sophisticated',
#   'kanemoto',
#   'said',
#   'harder',
#   'police',
#   'officials',
#   'gather',
#   'evidence',
#   'prosecution'],
#  ['said',
#   'new',
#   'challenges',
#   'require',
#   'increased',
#   'cooperation',
#   'particularly',
#   'interpol'],
#  ['the',
#   'police',
#   'officials',
#   'expected',
#   'discuss',
#   'strategic',
#   'development',
#   'plan',
#   'aimed',
#   'making',
#   'interpol',
#   'proactive',
#   'examining',
#   'needs',
#   'group',
#   '177',
#   'member',
#   'states',
#   'kanemoto',
#   'said'],
#  ['details', 'graf', 'pvs'],
#  ['austrian',
#   'president',
#   'tells',
#   'albright',
#   'effort',
#   'identify',
#   'stolen',
#   'art',
#   'austria',
#   'president',
#   'told',
#   'secretary',
#   'state',
#   'madeleine',
#   'albright',
#   'thursday',
#   'government',
#   'establishing',
#   'commission',
#   'identify',
#   'art',
#   'stolen',
#   'holocaust',
#   'victims',
#   'nazis'],
#  ['austrian',
#   'officials',
#   'said',
#   'president',
#   'thomas',
#   'klestil',
#   'told',
#   'albright',
#   'paid',
#   'day',
#   'visit',
#   'vienna',
#   'moscow',
#   'summit',
#   'commission',
#   'determine',
#   'origin',
#   'art',
#   'works',
#   'owned',
#   'federal',
#   'museum'],
#  ['there', 'statement', 'art', 'issue', 'officials'],
#  ['albright',
#   'left',
#   'united',
#   'states',
#   'meetings',
#   'klestil',
#   'chancellor',
#   'viktor',
#   'klima',
#   'foreign',
#   'minister',
#   'wolfgang',
#   'schuessel'],
#  ['austria',
#   'united',
#   'states',
#   'nations',
#   'launched',
#   'drive',
#   'identify',
#   'billions',
#   'dollars',
#   'worth',
#   'art',
#   'stolen',
#   'holocaust',
#   'victims',
#   'europe'],
#  ['the',
#   'world',
#   'jewish',
#   'congress',
#   'estimates',
#   'current',
#   'value',
#   'stolen',
#   'art',
#   'dlrs',
#   'billion',
#   'dlrs',
#   '140',
#   'billion'],
#  ['june',
#   'association',
#   'art',
#   'museum',
#   'directors',
#   'united',
#   'states',
#   'recommended',
#   'american',
#   'art',
#   'museums',
#   'check',
#   'collections',
#   'determine',
#   'works',
#   'stolen',
#   'war',
#   'set',
#   'worldwide',
#   'database',
#   'tracking'],
#  ['austria',
#   'absorbed',
#   'adolf',
#   'hitler',
#   'germany',
#   '1938',
#   'restored',
#   'independent',
#   'nation',
#   'following',
#   'world',
#   'war'],
#  [],
#  ['lufthansa',
#   'german',
#   'railway',
#   'pledge',
#   'closer',
#   'cooperation',
#   'seeking',
#   'shift',
#   'domestic',
#   'travel',
#   'planes',
#   'trains',
#   'germany',
#   'flag',
#   'carrier',
#   'lufthansa',
#   'german',
#   'railway',
#   'signed',
#   'letter',
#   'intent',
#   'monday',
#   'work',
#   'coordinating',
#   'services',
#   'schedules'],
#  ['the',
#   'goal',
#   'easier',
#   'travel',
#   'train',
#   'lufthansa',
#   'main',
#   'hub',
#   'frankfurt',
#   'instead',
#   'flying'],
#  ['starting',
#   '2001',
#   'lufthansa',
#   'boss',
#   'juergen',
#   'weber',
#   'hopes',
#   'eliminate',
#   'short',
#   'hops',
#   'frankfurt',
#   'cologne',
#   'example',
#   'freeing',
#   'takeoff',
#   'landing',
#   'slots',
#   'lucrative',
#   'international',
#   'flights'],
#  ['lufthansa',
#   'deutsche',
#   'bahn',
#   'deal',
#   'passengers',
#   'check',
#   'luggage',
#   'train',
#   'station',
#   'lufthansa',
#   'flight',
#   'catch',
#   'frankfurt'],
#  ['the',
#   'service',
#   'place',
#   'saarbruecken',
#   'travelers',
#   'drop',
#   'bags',
#   'day'],
#  ['starting',
#   'september',
#   'service',
#   'extended',
#   'cities',
#   'duesseldorf',
#   'cologne',
#   'bonn',
#   'wuerzburg',
#   'nuremberg'],
#  ['passengers',
#   'flying',
#   'lufthansa',
#   'partners',
#   'united',
#   'sas',
#   'able',
#   'use',
#   'service',
#   'said'],
#  ['the',
#   'airline',
#   'railway',
#   'said',
#   'form',
#   'working',
#   'group',
#   'resolve',
#   'problems',
#   'security',
#   'checks',
#   'luggage',
#   'making',
#   'sure',
#   'bags',
#   'airport',
#   'train',
#   'station',
#   'time'],
#  ['deutsche',
#   'bahn',
#   'chief',
#   'johannes',
#   'ludewig',
#   'said',
#   'railway',
#   'work',
#   'coordinate',
#   'schedules',
#   'better',
#   'lufthansa',
#   'flights',
#   'connections',
#   'easier',
#   'allow',
#   'combined',
#   'train',
#   'plane',
#   'tickets'],
#  ['pfg', 'aet'],
#  ['repeating',
#   'protectively',
#   'iran',
#   'protest',
#   'international',
#   'court',
#   'justice',
#   'hague',
#   'global',
#   'bodies',
#   'funded',
#   'radio',
#   'free',
#   'europe',
#   'iran',
#   'daily',
#   'reported',
#   'monday'],
#  ['quoted',
#   'foreign',
#   'minister',
#   'kamal',
#   'kharrazi',
#   'saying',
#   'radio',
#   'set',
#   'interfere',
#   'iran',
#   'internal',
#   'affairs'],
#  ['complaints', 'filed'],
#  ['the',
#   'english',
#   'language',
#   'daily',
#   'organizations',
#   'iran',
#   'approach',
#   'icj',
#   'netherlands'],
#  ['tuesday',
#   'iran',
#   'recalled',
#   'ambassador',
#   'prague',
#   'protest',
#   'czech',
#   'government',
#   'assistance',
#   'radio',
#   'said',
#   'reduce',
#   'level',
#   'economic',
#   'political',
#   'cooperation',
#   'prague'],
#  ['the',
#   'american',
#   'sponsored',
#   'station',
#   'began',
#   'broadcast',
#   'directed',
#   'iraq',
#   'friday'],
#  ['trial',
#   'period',
#   'weeks',
#   'station',
#   'broadcast',
#   'minute',
#   'program',
#   'day',
#   'iran',
#   'iraq'],
#  ['the',
#   'farsi',
#   'language',
#   'service',
#   'iran',
#   'approved',
#   'czech',
#   'government',
#   'august'],
#  ['radio',
#   'free',
#   'europe',
#   'began',
#   'transmitting',
#   'munich',
#   'germany',
#   '1951',
#   'spreading',
#   'uncensored',
#   'news',
#   'soviet',
#   'controlled',
#   'countries',
#   'iron',
#   'curtain',
#   'cold',
#   'war',
#   'west',
#   'communist',
#   'east'],
#  ['moved',
#   'headquarters',
#   'prague',
#   '1995',
#   'following',
#   'collapse',
#   'communism',
#   'years',
#   'earlier'],
#  [],
#  ['this',
#   'dracula',
#   'kills',
#   'cattle',
#   'deer',
#   'giant',
#   'black',
#   'bear',
#   'peasants',
#   'nicknamed',
#   'dracula',
#   'creating',
#   'anxiety',
#   'western',
#   'romania',
#   'taste',
#   'cattle',
#   'sheep',
#   'official',
#   'said',
#   'thursday'],
#  ['peasants',
#   'livestock',
#   'devoured',
#   'hungry',
#   'bear',
#   'lodged',
#   'seven',
#   'complaints',
#   'past',
#   'weeks',
#   'said',
#   'nicolae',
#   'onetiu',
#   'head',
#   'state',
#   'hunting',
#   'fishing',
#   'reserves',
#   'western',
#   'romania'],
#  ['dracula',
#   'named',
#   'transylvania',
#   'vampire',
#   'count',
#   'legend',
#   'bloody',
#   'appetite',
#   'said',
#   'onetiu'],
#  ['the',
#   'male',
#   'bruin',
#   'weighs',
#   '300',
#   'kilograms',
#   '660',
#   'pounds',
#   'moved',
#   'closer',
#   'inhabited',
#   'areas',
#   'forested',
#   'regions',
#   'onset',
#   'cold',
#   'weather',
#   'apparently',
#   'ready',
#   'hibernate'],
#  ['dracula', 'killed', 'cows', 'seven', 'sheep', 'past', 'weeks'],
#  ['most',
#   'bears',
#   'omnivorous',
#   'romania',
#   'bears',
#   'weaned',
#   'meat',
#   'said',
#   'onetiu'],
#  ['nicolae',
#   'ceausescu',
#   'communist',
#   'dictator',
#   'toppled',
#   'executed',
#   'decade',
#   'ago',
#   'avid',
#   'hunter',
#   'hunting',
#   'reserve',
#   'cubs',
#   'fed',
#   'meat',
#   'grow',
#   'bigger',
#   'quicker',
#   'leaving',
#   'generations',
#   'partial',
#   'meat'],
#  ['state',
#   'rangers',
#   'count',
#   '135',
#   'bears',
#   'living',
#   'apuseni',
#   'mountains',
#   'western',
#   'romania',
#   'protected',
#   'law'],
#  ['str'],
#  ['norwegian',
#   'company',
#   'moves',
#   'ahead',
#   'clean',
#   'power',
#   'plant',
#   'the',
#   'norsk',
#   'hydro',
#   'asa',
#   'concern',
#   'announced',
#   'plans',
#   'friday',
#   'build',
#   'hydrogen',
#   'burning',
#   'power',
#   'plant',
#   'says',
#   'produce',
#   'electricity',
#   'virtually',
#   'climate',
#   'damaging',
#   'emissions'],
#  ['the',
#   'percent',
#   'state',
#   'owned',
#   'company',
#   'notified',
#   'norwegian',
#   'water',
#   'resources',
#   'energy',
#   'directorate',
#   'plans',
#   'build',
#   'plant',
#   'called',
#   'hydrokraft',
#   'pending',
#   'approval',
#   'government',
#   'agencies'],
#  ['the',
#   'company',
#   'said',
#   'receives',
#   'proper',
#   'approvals',
#   '1999',
#   'construction',
#   'plant',
#   'completed',
#   '2002',
#   'production',
#   'startup',
#   'occur',
#   'early',
#   '2003'],
#  ['earlier',
#   'year',
#   'company',
#   'announced',
#   'new',
#   'technology',
#   'allow',
#   'use',
#   'clean',
#   'burning',
#   'hydrogen',
#   'generate',
#   'electricity'],
#  ['the', 'hydrogen', 'plant', 'extracted', 'natural', 'gas'],
#  ['norsk',
#   'hydro',
#   'major',
#   'petroleum',
#   'producer',
#   'says',
#   'studies',
#   'shown',
#   'proposal',
#   'economically',
#   'viable'],
#  ['said',
#   'plant',
#   'carbon',
#   'dioxide',
#   'emissions',
#   'percent',
#   'lower',
#   'plants',
#   'natural',
#   'gas'],
#  ['norway',
#   'world',
#   'second',
#   'largest',
#   'oil',
#   'exporter',
#   'produces',
#   'vast',
#   'amounts',
#   'natural',
#   'gas',
#   'offshore',
#   'fields'],
#  ['virtually', 'country', 'electricity', 'comes', 'hydroelectric', 'plants'],
#  ['under',
#   'company',
#   'plans',
#   'natural',
#   'gas',
#   'air',
#   'water',
#   'mixed',
#   'produce',
#   'hydrogen',
#   'nitrogen',
#   'carbon',
#   'dioxide'],
#  ['norsk',
#   'hydro',
#   'wants',
#   'build',
#   'plant',
#   'karmoey',
#   'island',
#   '500',
#   'kilometers',
#   '300',
#   'miles',
#   'west',
#   'oslo'],
#  ['alaska',
#   'hiker',
#   'killed',
#   'bear',
#   'anchorage',
#   'alaska',
#   'man',
#   'day',
#   'hike',
#   'rural',
#   'area',
#   'killed',
#   'bear',
#   'bit',
#   'head',
#   'alaska',
#   'state',
#   'troopers',
#   'said',
#   'wednesday'],
#  ['kenneth',
#   'cates',
#   'wednesday',
#   'morning',
#   'horse',
#   'trail',
#   'heavily',
#   'wooded',
#   'area',
#   'kenai',
#   'national',
#   'wildlife',
#   'refuge',
#   'near',
#   'hometown',
#   'soldotna'],
#  ['the', 'attack', 'happened', 'miles', 'busy', 'road'],
#  ['the', 'area', 'miles', 'southwest', 'anchorage'],
#  ['the', 'fatal', 'mauling', 'thought', 'happened', 'tuesday'],
#  ['his',
#   'visible',
#   'wound',
#   'single',
#   'bite',
#   'head',
#   'said',
#   'bruce',
#   'bartley',
#   'spokesman',
#   'state',
#   'division',
#   'wildlife',
#   'conservation'],
#  ['state',
#   'federal',
#   'wildlife',
#   'officials',
#   'looking',
#   'bear',
#   'involved',
#   'attack'],
#  ['bear', 'judged', 'pose', 'continuing', 'threat', 'humans', 'killed'],
#  ['troopers',
#   'said',
#   'cates',
#   '280',
#   'caliber',
#   'rifle',
#   'spent',
#   'shell',
#   'casings',
#   'near',
#   'body',
#   'traces',
#   'blood',
#   'suggest',
#   'cates',
#   'wounded',
#   'animal'],
#  ['know', 'warning', 'shot', 'real', 'real', 'shots', 'bartley', 'said'],
#  ['cates',
#   'death',
#   'fatal',
#   'bear',
#   'mauling',
#   'alaska',
#   'feb',
#   '1998',
#   'audelio',
#   'luis',
#   'cortes',
#   'killed',
#   'working',
#   'seismic',
#   'crew',
#   'swanson',
#   'river',
#   'oil',
#   'field',
#   'near',
#   'kenai'],
#  ['cortes', 'died', 'single', 'head', 'bite'],
#  ['syria',
#   'opposes',
#   'attempt',
#   'overthrow',
#   'saddam',
#   'hussein',
#   'syria',
#   'opposes',
#   'attempts',
#   'united',
#   'states',
#   'britain',
#   'overthrow',
#   'iraqi',
#   'leader',
#   'saddam',
#   'hussein',
#   'syrian',
#   'vice',
#   'president',
#   'abdul',
#   'halim',
#   'khaddam',
#   'said',
#   'thursday'],
#  ['such',
#   'moves',
#   'serve',
#   'israel',
#   'design',
#   'disintegrate',
#   'arab',
#   'islamic',
#   'world',
#   'khaddam',
#   'said',
#   'receiving',
#   'iranian',
#   'counterpart',
#   'hassan',
#   'habibi',
#   'damascus',
#   'airport'],
#  ['the',
#   'united',
#   'states',
#   'granted',
#   'dlrs',
#   'million',
#   'iraqi',
#   'opposition',
#   'groups'],
#  ['british',
#   'american',
#   'officials',
#   'hosted',
#   'meetings',
#   'london',
#   'month',
#   'iraqi',
#   'dissident',
#   'groups',
#   'bid',
#   'promote',
#   'cooperation'],
#  ['this',
#   'dangerous',
#   'issue',
#   'state',
#   'world',
#   'right',
#   'interfere',
#   'internal',
#   'affairs',
#   'country',
#   'khaddam',
#   'said'],
#  ['habibi',
#   'said',
#   'iraqi',
#   'palestinian',
#   'questions',
#   'great',
#   'concern',
#   'iran',
#   'syria',
#   'there',
#   'coordination',
#   'countries',
#   'issues'],
#  ['the',
#   'official',
#   'iranian',
#   'news',
#   'agency',
#   'irma',
#   'said',
#   'iraqi',
#   'palestinian',
#   'issues',
#   'focus',
#   'talks',
#   'habibi',
#   'khaddam',
#   'meeting',
#   'syrian',
#   'iranian',
#   'supreme',
#   'committee'],
#  ['the',
#   'committee',
#   'meets',
#   'biannually',
#   'promote',
#   'cooperation',
#   'foreign',
#   'affairs',
#   'trade',
#   'technology'],
#  ['habibi',
#   'accompanied',
#   'iranian',
#   'foreign',
#   'minister',
#   'kamal',
#   'kharrazi',
#   'expected',
#   'meet',
#   'syrian',
#   'president',
#   'hafez',
#   'assad',
#   'day',
#   'visit'],
#  ['syria',
#   'iran',
#   'closest',
#   'arab',
#   'ally',
#   'supported',
#   'persian',
#   'state',
#   '1980',
#   'iran',
#   'iraq',
#   'war'],
#  ['str', 'jbm'],
#  ['portugal',
#   'spain',
#   'reach',
#   'agreement',
#   'common',
#   'water',
#   'supplies',
#   'portugal',
#   'spain',
#   'monday',
#   'reached',
#   'agreement',
#   'shared',
#   'water',
#   'resources',
#   'iberian',
#   'peninsula',
#   'wrapping',
#   'day',
#   'summit',
#   'premiers',
#   'called',
#   'historic'],
#  ['ambitious',
#   'modern',
#   'wide',
#   'ranging',
#   'efficient',
#   'agreement',
#   'portugal',
#   'prime',
#   'minister',
#   'antonio',
#   'guterres',
#   'said',
#   'end',
#   'summit',
#   'albufeira',
#   '200',
#   'kilometers',
#   '125',
#   'miles',
#   'south',
#   'lisbon'],
#  ['both',
#   'governments',
#   'worked',
#   'shared',
#   'management',
#   'plan',
#   'monitor',
#   'water',
#   'volume',
#   'rivers',
#   'supply',
#   'countries'],
#  ['spanish',
#   'premier',
#   'jose',
#   'maria',
#   'aznar',
#   'said',
#   'agreement',
#   'reflected',
#   'exceptional',
#   'moment',
#   'relations',
#   'iberian',
#   'countries'],
#  ['water',
#   'supply',
#   'southwest',
#   'european',
#   'peninsula',
#   'sticking',
#   'points',
#   'countries',
#   'strong',
#   'trade',
#   'links',
#   'close',
#   'political',
#   'ties'],
#  ['spanish',
#   'plans',
#   'develop',
#   'hydroelectric',
#   'projects',
#   'border',
#   'constant',
#   'threat',
#   'portugal',
#   'supply',
#   'comes',
#   'mainly',
#   'rivers',
#   'sources',
#   'neighboring',
#   'country'],
#  ['both',
#   'governments',
#   'reiterated',
#   'decision',
#   'jointly',
#   'campaign',
#   'continued',
#   'development',
#   'funds',
#   'provided',
#   'wealthier',
#   'european',
#   'union',
#   'nations'],
#  ['cabinet',
#   'members',
#   'agreed',
#   'build',
#   'new',
#   'road',
#   'railway',
#   'links',
#   'countries'],
#  ['the',
#   'albufeira',
#   'summit',
#   'produced',
#   'plan',
#   'increase',
#   'cooperation',
#   'police',
#   'border',
#   'order',
#   'curb',
#   'illegal',
#   'immigration',
#   'drug',
#   'trafficking'],
#  ['bank',
#   'fires',
#   'seven',
#   'mail',
#   'misuse',
#   'charlotte',
#   'first',
#   'union',
#   'corp',
#   'says',
#   'fired',
#   'seven',
#   'employees',
#   'week',
#   'sending',
#   'pornographic',
#   'inappropriate',
#   'mail'],
#  ['first',
#   'union',
#   'nation',
#   'sixth',
#   'largest',
#   'bank',
#   'confirmed',
#   'firings',
#   'friday',
#   'company',
#   'spokeswoman',
#   'sandy',
#   'deem',
#   'release',
#   'details'],
#  ['the',
#   'bank',
#   'tolerate',
#   'conduct',
#   'interferes',
#   'person',
#   'work',
#   'performance',
#   'creates',
#   'intimidating',
#   'offensive',
#   'hostile',
#   'environment',
#   'deem',
#   'said'],
#  ['the',
#   'charlotte',
#   'observer',
#   'reported',
#   'friday',
#   'employees',
#   'university',
#   'research',
#   'park',
#   'office',
#   'circulated',
#   'mail',
#   'included',
#   'videos',
#   'people',
#   'having',
#   'sex',
#   'material',
#   'sexual',
#   'nature'],
#  ['the',
#   'company',
#   'stumbled',
#   'mail',
#   'volume',
#   'messages',
#   'heavy',
#   'slowed',
#   'server'],
#  ['one',
#   'employee',
#   'fired',
#   'past',
#   'week',
#   'bank',
#   'home',
#   'equity',
#   'division',
#   'called',
#   'office',
#   'shown',
#   'stack',
#   'mail',
#   'fired',
#   'spot',
#   'employee',
#   'told',
#   'newspaper'],
#  ['first',
#   'union',
#   'fortune',
#   '100',
#   'corporation',
#   'joins',
#   'number',
#   'companies',
#   'taking',
#   'swift',
#   'severe',
#   'action',
#   'violations',
#   'company',
#   'mail',
#   'policy'],
#  ['companies',
#   'seeking',
#   'protect',
#   'legal',
#   'claims',
#   'work',
#   'environment',
#   'hostile'],
#  ['increasing',
#   'number',
#   'lawsuits',
#   'alleging',
#   'sexual',
#   'harassment',
#   'based',
# ...
#   'guru',
#   'accused',
#   'murder',
#   'nerve',
#   'gas',
#   'attack',
#   'tokyo',
#   'subways',
#   'denounced',
#   'trial',
#   'thursday',
#   'unfair',
#   'prosecutors',
#   'charges',
#   'contradicted',
#   'testimony',
#   'witnesses'],
#  ['shoko',
#   'asahara',
#   'leader',
#   'aum',
#   'shinri',
#   'kyo',
#   'cult',
#   'trial',
#   'charges',
#   'march',
#   '1995',
#   'sarin',
#   'attack',
#   'killed',
#   'people',
#   'sickened',
#   'thousands'],
#  ['other', 'cult', 'leaders', 'charged', 'gassing', 'slayings'],
#  ['osamu',
#   'watanabe',
#   'asahara',
#   'chief',
#   'defense',
#   'lawyer',
#   'said',
#   'trial',
#   'allowed'],
#  ['wonder', 'abnormal', 'unfair', 'proceedings', 'tolerated'],
#  ['the',
#   'court',
#   'negligent',
#   'watanabe',
#   'told',
#   'tokyo',
#   'district',
#   'court'],
#  ['the',
#   'prosecutors',
#   'asahara',
#   'accused',
#   'masterminding',
#   'subway',
#   'gassing',
#   'decided',
#   'attack',
#   'march',
#   '1995',
#   'riding',
#   'car',
#   'followers'],
#  ['but',
#   'watanabe',
#   'pointed',
#   'cultist',
#   'yoshihiro',
#   'inoue',
#   'key',
#   'witness',
#   'prosecution',
#   'told',
#   'court',
#   'asahara',
#   'undecided',
#   'timing',
#   'attack',
#   'time'],
#  ['inoue', 'quoted', 'asahara', 'saying', 'needed', 'meditate'],
#  ['last',
#   'april',
#   'defense',
#   'raised',
#   'similar',
#   'objections',
#   'prosecutors',
#   'refused',
#   'change',
#   'statement'],
#  [],
#  ['report',
#   'plane',
#   'robbed',
#   'gunmen',
#   'nigerian',
#   'airport',
#   'air',
#   'afrique',
#   'boeing',
#   '727',
#   'jet',
#   'passenger',
#   'liner',
#   'looted',
#   'past',
#   'month',
#   'armed',
#   'robbers',
#   'awaiting',
#   'takeoff',
#   'nigeria',
#   'largest',
#   'international',
#   'airport',
#   'lagos',
#   'guardian',
#   'newspaper',
#   'reported',
#   'thursday'],
#  ['the',
#   'thieves',
#   'broke',
#   'aircraft',
#   'luggage',
#   'compartment',
#   'escaped',
#   'large',
#   'quantity',
#   'baggage',
#   'plane',
#   'awaiting',
#   'permission',
#   'lagos',
#   'international',
#   'airport',
#   'control',
#   'tower',
#   'tuesday',
#   'night',
#   'guardian',
#   'said'],
#  ['clear', 'airliner', 'destined'],
#  ['there', 'immediate', 'confirmation', 'report'],
#  ['the',
#   'plane',
#   'captain',
#   'noticed',
#   'theft',
#   'sent',
#   'distress',
#   'went',
#   'unanswered',
#   'airport',
#   'officials'],
#  ['security',
#   'personnel',
#   'duty',
#   'later',
#   'said',
#   'said',
#   'unable',
#   'capture',
#   'culprits',
#   'security',
#   'vehicle',
#   'taken',
#   'away',
#   'routine',
#   'maintenance'],
#  ['incident',
#   'week',
#   'involving',
#   'unidentified',
#   'passenger',
#   'jet',
#   'landing',
#   'gear',
#   'worth',
#   'dlrs',
#   'million',
#   'stripped',
#   'plane',
#   'waiting',
#   'newspaper',
#   'said'],
#  ['may',
#   'cameroon',
#   'airlines',
#   'plane',
#   'robbed',
#   'luggage',
#   'armed',
#   'thieves',
#   'blocked',
#   'plane',
#   'tarmac',
#   'large',
#   'log'],
#  ['the',
#   'robberies',
#   'came',
#   'despite',
#   'orders',
#   'airport',
#   'security',
#   'officials',
#   'shoot',
#   'suspected',
#   'thieves',
#   'sight'],
#  ['nigeria',
#   'africa',
#   'populous',
#   'country',
#   'notoriously',
#   'high',
#   'rate',
#   'violent',
#   'crime',
#   'accompanied',
#   'breakdown',
#   'law',
#   'order',
#   'years',
#   'military',
#   'rule'],
#  ['gam'],
#  ['businessman',
#   'killed',
#   'siberian',
#   'town',
#   'russian',
#   'businessman',
#   'killed',
#   'way',
#   'work',
#   'wednesday',
#   'unidentified',
#   'gunman',
#   'appeared',
#   'organized',
#   'crime',
#   'killing',
#   'according',
#   'news',
#   'reports'],
#  ['yuri',
#   'zinin',
#   'head',
#   'sibneft',
#   'company',
#   'shot',
#   'walked',
#   'apartment',
#   'building',
#   'town',
#   'leninsk',
#   'kuzntesky',
#   'kemerovo',
#   'region',
#   'central',
#   'siberia',
#   'russian',
#   'news',
#   'agencies',
#   'quoted',
#   'local',
#   'police',
#   'saying'],
#  ['zinin',
#   'company',
#   'russia',
#   'largest',
#   'oil',
#   'producers',
#   'sibneft',
#   'controlled',
#   'controversial',
#   'business',
#   'mogul',
#   'boris',
#   'berezovsky'],
#  ['but', 'companies', 'separate'],
#  ['zinin',
#   'sibneft',
#   'locally',
#   'based',
#   'involved',
#   'selling',
#   'oil',
#   'products',
#   'coal'],
#  ['kemerovo', 'russia', 'main', 'coal', 'mining', 'regions'],
#  ['police', 'launched', 'search', 'killer', 'fled'],
#  ['officials', 'wouldn', 'comment', 'possible', 'motives', 'murder'],
#  ['there',
#   'hundreds',
#   'contract',
#   'murder',
#   'russia',
#   'year',
#   'mobsters',
#   'fight',
#   'control',
#   'profitable',
#   'businesses'],
#  ['only', 'small', 'number', 'killings', 'solved'],
#  ['the',
#   'small',
#   'town',
#   'leninsk',
#   'kuznetsky',
#   'known',
#   'nationwide',
#   'year',
#   'city',
#   'mayor',
#   'arrested',
#   'tax',
#   'fraud',
#   'embezzlement',
#   'charges'],
#  ['mayor',
#   'gennady',
#   'konyakhin',
#   'accused',
#   'linked',
#   'mob',
#   'custody',
#   'awaiting',
#   'trial'],
#  ['ren'],
#  ['astronomers',
#   'spot',
#   'storm',
#   'mars',
#   'washington',
#   'cyclone',
#   'times',
#   'size',
#   'texas',
#   'raged',
#   'northern',
#   'polar',
#   'region',
#   'planet',
#   'mars',
#   'month',
#   'according',
#   'space',
#   'telescope',
#   'views',
#   'red',
#   'planet'],
#  ['the',
#   'space',
#   'telescope',
#   'science',
#   'institute',
#   'announced',
#   'today',
#   'hubble',
#   'space',
#   'telescope',
#   'april',
#   'spotted',
#   'immense',
#   'martian',
#   'storm',
#   'cloud',
#   'water',
#   'ice',
#   '100',
#   'miles',
#   'long',
#   '900',
#   'wide'],
#  ['bands',
#   'clouds',
#   'spiraled',
#   'counterclockwise',
#   'motion',
#   '200',
#   'mile',
#   'wide',
#   'eye',
#   'center',
#   'storm',
#   'taking',
#   'shape',
#   'resembled',
#   'hurricanes',
#   'earth',
#   'astronomers',
#   'said'],
#  ['the', 'storm', 'occurred', 'summer', 'mars', 'northern', 'hemisphere'],
#  ['came',
#   'seasonal',
#   'warming',
#   'evaporated',
#   'carbon',
#   'dioxide',
#   'ice',
#   'sheet',
#   'caps',
#   'martian',
#   'north',
#   'pole',
#   'year'],
#  ['officials',
#   'said',
#   'storm',
#   'times',
#   'larger',
#   'storm',
#   'spotted',
#   'years',
#   'ago',
#   'viking',
#   'orbiter',
#   'spacecraft'],
#  ['astronomers',
#   'wide',
#   'field',
#   'planetary',
#   'camera',
#   'hubble',
#   'photograph',
#   'mars',
#   'planet',
#   'closest',
#   'approach',
#   'earth',
#   'nearly',
#   'years'],
#  ['two',
#   'pictures',
#   'taken',
#   'hours',
#   'apart',
#   'april',
#   'showed',
#   'storm',
#   'moved',
#   'slightly',
#   'eastward'],
#  ['second', 'picture', 'storm', 'appeared', 'process', 'breaking'],
#  ['later',
#   'pictures',
#   'hubble',
#   'camera',
#   'failed',
#   'storm',
#   'astronomers',
#   'said',
#   'short',
#   'lived',
#   'phenomenon'],
#  ['shepard',
#   'glenn',
#   'set',
#   'milestones',
#   'may',
#   '1961',
#   'alan',
#   'shepard',
#   'american',
#   'space'],
#  ['feb', '1962', 'john', 'glenn', 'american', 'orbit'],
#  ['jan',
#   '1967',
#   'gus',
#   'grissom',
#   'edward',
#   'white',
#   'roger',
#   'chaffee',
#   'die',
#   'apollo',
#   'spacecraft',
#   'launch',
#   'pad'],
#  ['july',
#   '1969',
#   'apollo',
#   'neil',
#   'armstrong',
#   'buzz',
#   'aldrin',
#   'land',
#   'moon'],
#  ['july',
#   '1975',
#   'american',
#   'apollo',
#   'soviet',
#   'soyuz',
#   'spacecraft',
#   'link',
#   'orbit'],
#  ['april', '1981', 'columbia', 'soars', 'space', 'shuttle', 'flight'],
#  ['june', '1983', 'sally', 'ride', 'american', 'woman', 'space'],
#  ['jan', '1986', 'challenger', 'explodes', 'killing', 'seven', 'board'],
#  ['april', '1990', 'hubble', 'space', 'telescope', 'released', 'orbit'],
#  ['dec', '1993', 'first', 'hubble', 'repair', 'mission', 'launched'],
#  ['march',
#   '1995',
#   'norman',
#   'thagard',
#   'american',
#   'launched',
#   'russian',
#   'rocket'],
#  ['two', 'days', 'later', 'american', 'visit', 'mir'],
#  ['june', '1995', 'atlantis', 'docks', 'mir', 'shuttle', 'station', 'hookup'],
#  ['sept',
#   '1996',
#   'shannon',
#   'lucid',
#   'returns',
#   'earth',
#   '188',
#   'day',
#   'mir',
#   'mission',
#   'space',
#   'endurance',
#   'record',
#   'world',
#   'record',
#   'women'],
#  ['nov', '1996', 'story', 'musgrave', 'age', 'oldest', 'man', 'space'],
#  ['oct',
#   '1998',
#   'discovery',
#   'scheduled',
#   'blast',
#   'carrying',
#   'year',
#   'old',
#   'john',
#   'glenn',
#   'orbit',
#   'making',
#   'oldest',
#   'man',
#   'space'],
#  ['the',
#   'nation',
#   'weather',
#   'severe',
#   'thunderstorms',
#   'forecast',
#   'gulf',
#   'coast',
#   'louisiana',
#   'georgia',
#   'northward',
#   'tennessee'],
#  ['rain', 'forecast', 'carolinas', 'tonight'],
#  ['lightning', 'large', 'hail', 'wind', 'mph', 'inches', 'rain', 'possible'],
#  ['lighter', 'amounts', 'expected', 'ohio', 'valley'],
#  ['the',
#   'storm',
#   'roared',
#   'texas',
#   'oklahoma',
#   'thursday',
#   'hitting',
#   'areas',
#   'wind',
#   'hail',
#   'heavy',
#   'rain'],
#  ['some',
#   'flights',
#   'dallas',
#   'fort',
#   'worth',
#   'international',
#   'airport',
#   'delayed',
#   'seven',
#   'hours'],
#  ['northeast',
#   'inches',
#   'sunnyow',
#   'possible',
#   'adirondack',
#   'green',
#   'mountains'],
#  ['sunnyow', 'forecast', 'northwesterain', 'pennsylvania', 'maine'],
#  ['gusty', 'winds', 'expected', 'wind', 'chill', 'readings', 'freezing'],
#  ['mostly',
#   'quiet',
#   'conditions',
#   'forecast',
#   'west',
#   'rockies',
#   'southeast',
#   'northerain',
#   'plains',
#   'today'],
#  ['showers',
#   'possible',
#   'southerain',
#   'califorainia',
#   'coasts',
#   'washington',
#   'oregon'],
#  ['highs',
#   'today',
#   'forecast',
#   'reach',
#   '30s',
#   'new',
#   'england',
#   '40s',
#   'northeast',
#   'midwest',
#   'great',
#   'lakes',
#   'northerain',
#   'rockies',
#   '50s',
#   'northwest',
#   'mid',
#   'atlantic',
#   'states',
#   'northerain',
#   'plains',
#   '60s',
#   '70s',
#   '80s',
#   'southeast',
#   'southwest',
#   'southerain',
#   'plains'],
#  ['the',
#   'highest',
#   'temperature',
#   'reported',
#   'continental',
#   'united',
#   'states',
#   'thursday',
#   'degrees',
#   'texas',
#   'communities',
#   'cotulla',
#   'alice'],
#  ['the', 'low', 'minus', 'grand', 'marais', 'minn'],
#  ['report',
#   'south',
#   'africa',
#   'truth',
#   'panel',
#   'condemn',
#   'anc',
#   'panel',
#   'probing',
#   'apartheid',
#   'era',
#   'abuses',
#   'accused',
#   'african',
#   'national',
#   'congress',
#   'human',
#   'rights',
#   'violations',
#   'including',
#   'torture',
#   'bomb',
#   'attacks',
#   'state',
#   'broadcaster',
#   'said',
#   'monday'],
#  ['the',
#   'anc',
#   'led',
#   'struggle',
#   'white',
#   'rule',
#   'power',
#   'previously',
#   'acknowledged',
#   'told',
#   'expect',
#   'implication',
#   'right',
#   'violations'],
#  ['the',
#   'truth',
#   'reconciliation',
#   'commission',
#   'release',
#   'final',
#   'report',
#   'years',
#   'investigation',
#   'thursday'],
#  ['the',
#   'report',
#   'expected',
#   'place',
#   'overwhelming',
#   'blame',
#   'era',
#   'abuses',
#   'white',
#   'governments',
#   'brutal',
#   'security',
#   'services'],
#  ['south',
#   'african',
#   'broadcasting',
#   'corp',
#   'radio',
#   'said',
#   'leaked',
#   'preliminary',
#   'document',
#   'condemns',
#   'anc',
#   'politically',
#   'morally',
#   'responsible',
#   'gross',
#   'human',
#   'rights',
#   'violations',
#   'fall',
#   'apartheid'],
#  ['anc',
#   'spokesman',
#   'thabo',
#   'masebe',
#   'said',
#   'believed',
#   'news',
#   'report',
#   'referred',
#   'commission',
#   'letter',
#   'sent',
#   'advance',
#   'informing',
#   'intention',
#   'implicate',
#   'anc',
#   'gross',
#   'human',
#   'rights',
#   'violations'],
#  ['commission', 'officials', 'immediately', 'reached', 'comment'],
#  ['the',
#   'anc',
#   'nervous',
#   'report',
#   'request',
#   'meeting',
#   'commissioners',
#   'earlier',
#   'month'],
#  ['the', 'panel', 'refused', 'avoid', 'appearing', 'embarrassed'],
#  ['the',
#   'party',
#   'says',
#   'accusations',
#   'likely',
#   'center',
#   'planting',
#   'land',
#   'mines',
#   'border',
#   'farms',
#   'abuses',
#   'military',
#   'camps',
#   'angola',
#   'bombings'],
#  ['djw'],
#  ['saddam',
#   'says',
#   'reap',
#   'urges',
#   'iran',
#   'normalize',
#   'ties',
#   'president',
#   'saddam',
#   'hussein',
#   'said',
#   'saturday',
#   'united',
#   'states',
#   'reap',
#   'harvest',
#   'thorns',
#   'campaign',
#   'iraq'],
#  ['addressing',
#   'nation',
#   'television',
#   'mark',
#   'anniversary',
#   'end',
#   '1980',
#   'iran',
#   'iraq',
#   'war',
#   'saddam',
#   'urged',
#   'iran',
#   'normalize',
#   'relations',
#   'iraq'],
#  ['saddam',
#   'refer',
#   'decision',
#   'wednesday',
#   'freeze',
#   'cooperation',
#   'arms',
#   'inspectors',
#   'said',
#   'united',
#   'states',
#   'allies',
#   'misled',
#   'thought',
#   'bring',
#   'iraq',
#   'knees'],
#  ['this',
#   'exactly',
#   'iranian',
#   'government',
#   'late',
#   'ayatollah',
#   'ruhollah',
#   'khomeini',
#   'thought',
#   'war',
#   'failed',
#   'saddam',
#   'said'],
#  ['those',
#   'imposing',
#   'aggression',
#   'iraq',
#   'unfair',
#   'embargo',
#   'neglect',
#   'fact',
#   'today',
#   'saddam',
#   'said',
#   'referring',
#   'sweeping',
#   'sanctions',
#   'united',
#   'nations',
#   'imposed',
#   'iraq',
#   '1990',
#   'invasion',
#   'kuwait'],
#  ['they', 'making', 'mistake'],
#  ['their', 'harvest', 'thorns', 'outcome', 'taste', 'bitterness'],
#  ['the', 'president', 'delivered', 'speech', 'black', 'suit'],
#  ['decreed',
#   'saturday',
#   'celebrated',
#   'day',
#   'victory',
#   'iran',
#   'artillery',
#   'salute',
#   '101',
#   'guns',
#   'boomed',
#   'baghdad',
#   'early',
#   'morning'],
#  ['national',
#   'radio',
#   'television',
#   'played',
#   'patriotic',
#   'songs',
#   'occasion'],
#  ['saddam', 'spoke', '7th', 'graf', 'pvs'],
#  ['international',
#   'police',
#   'seek',
#   'stymie',
#   'illegal',
#   'art',
#   'traffic',
#   'king',
#   'police',
#   'officers',
#   'countries',
#   'met',
#   'budapest',
#   'seek',
#   'efficient',
#   'ways',
#   'combat',
#   'illegal',
#   'traffic',
#   'art',
#   'treasures',
#   'police',
#   'official',
#   'said',
#   'thursday'],
#  ['held',
#   'auspices',
#   'interpol',
#   'international',
#   'police',
#   'organization',
#   'day',
#   'closed',
#   'meeting',
#   'allowed',
#   'officers',
#   'personal',
#   'contact',
#   'help',
#   'east',
#   'european',
#   'counterparts',
#   'catch'],
#  ['member',
#   'team',
#   'working',
#   'illegal',
#   'art',
#   'traffic',
#   'group',
#   'set',
#   'april',
#   'france',
#   'policemen',
#   'years',
#   'experience',
#   'hungarian',
#   'police',
#   'col',
#   'tamas',
#   'simon',
#   'said'],
#  ['illegal', 'art', 'traffic', 'growth', 'industry'],
#  ['1990',
#   'year',
#   'communism',
#   'collapsed',
#   '702',
#   'registered',
#   'cases',
#   'hungary',
#   'total',
#   'value',
#   'stolen',
#   'treasures',
#   'million',
#   'forints',
#   'dlrs',
#   '340',
#   '000',
#   'present',
#   'terms'],
#  ['1993',
#   '1996',
#   '025',
#   'cases',
#   'involving',
#   '430',
#   'million',
#   'forints',
#   'dlrs',
#   'million',
#   'worth',
#   'stolen',
#   'treasures'],
#  ['this',
#   'special',
#   'area',
#   'police',
#   'work',
#   'stolen',
#   'art',
#   'appear',
#   'years',
#   'market',
#   'said',
#   'jean',
#   'pierre',
#   'jouanny',
#   'director',
#   'french',
#   'national',
#   'bureau',
#   'interpol'],
#  ['hungary',
#   'largely',
#   'transit',
#   'country',
#   'stolen',
#   'art',
#   'line',
#   'traffic',
#   'moving',
#   'east',
#   'west'],
#  ['work',
#   'underway',
#   'cataloging',
#   'country',
#   'art',
#   'treasures',
#   'establishing',
#   'data',
#   'base',
#   'network',
#   'contacts',
#   'art',
#   'dealers',
#   'auctioneers',
#   'museums'],
#  [],
#  ['cohen',
#   'missile',
#   'defense',
#   'gulf',
#   'imperative',
#   'defense',
#   'secretary',
#   'william',
#   'cohen',
#   'said',
#   'saturday',
#   'imperative',
#   'allies',
#   'gulf',
#   'acquire',
#   'ballistic',
#   'missile',
#   'defense',
#   'counter',
#   'long',
#   'range',
#   'weapons',
#   'hands',
#   'countries',
#   'iran',
#   'iraq'],
#  ['cohen',
#   'said',
#   'united',
#   'states',
#   'defense',
#   'systems',
#   'research',
#   'development',
#   'hope',
#   'hope',
#   'share',
#   'technology',
#   'bahrain',
#   'gulf',
#   'countries'],
#  ['speaking',
#   'reporters',
#   'leaving',
#   'qatar',
#   'second',
#   'stop',
#   'nation',
#   'gulf',
#   'tour',
#   'includes',
#   'united',
#   'arab',
#   'emirates',
#   'oman',
#   'kuwait',
#   'saudi',
#   'arabia'],
#  ['because',
#   'proliferation',
#   'missile',
#   'technology',
#   'globally',
#   'especially',
#   'gulf',
#   'region',
#   'believe',
#   'important',
#   'look',
#   'ways',
#   'cooperate',
#   'allies',
#   'said',
#   'cohen'],
#  ['think',
#   'imperative',
#   'countries',
#   'cooperate',
#   'develop',
#   'theater',
#   'missile',
#   'protection',
#   'people',
#   'forces',
#   'said',
#   'cohen',
#   'citing',
#   'threats',
#   'iran',
#   'iraq'],
#  ['the',
#   'united',
#   'states',
#   'sees',
#   'iraq',
#   'iran',
#   'recently',
#   'tested',
#   'long',
#   'range',
#   'missile',
#   'major',
#   'threats',
#   'gulf',
#   'region'],
#  ['cohen',
#   'said',
#   'iraq',
#   'sanctions',
#   'continues',
#   'efforts',
#   'acquire',
#   'missile',
#   'technology',
#   'longer',
#   'permissible',
#   'range']]

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(tokenized_sent)]
tagged_data
# Out:
# [TaggedDocument(words=['london', 'nov'], tags=[0]),
#  TaggedDocument(words=['the', 'apparent', 'settlement', 'came', 'days', 'talks', 'involving', 'west', 'indies', 'players', 'officials', 'west', 'indies', 'south', 'africa', 'cricket', 'boards'], tags=[1]),
#  TaggedDocument(words=['the', 'crisis', 'came', 'head', 'wednesday', 'west', 'indies', 'cricket', 'board', 'fired', 'superstar', 'batsman', 'brian', 'lara', 'captain', 'carl', 'hooper', 'vice', 'captain'], tags=[2]),
#  TaggedDocument(words=['the', 'refused', 'travel', 'south', 'africa', 'demanding', 'better', 'pay', 'conditions', 'tour'], tags=[3]),
#  TaggedDocument(words=['team', 'members', 'insisted', 'lara', 'hooper', 'reinstated', 'settlement'], tags=[4]),
#  TaggedDocument(words=['jimmy', 'adams', 'treasurer', 'players', 'assocation', 'negotiated', 'behalf', 'players', 'monday', 'pat', 'rousseau', 'president', 'west', 'indies', 'cricket', 'board'], tags=[5]),
#  TaggedDocument(words=['ali', 'bacher', 'head', 'south', 'african', 'cricket', 'directly', 'involved', 'monday', 'talks', 'sitting', 'sidelines', 'sunday'], tags=[6]),
#  TaggedDocument(words=['west', 'indies', 'tour', 'manager', 'clive', 'lloyd', 'wicb', 'member', 'joel', 'garner', 'involved', 'talks', 'began', 'friday'], tags=[7]),
#  TaggedDocument(words=['progress', 'reported', 'weekend', 'announcement', 'sponsorship', 'deal', 'offered', 'south', 'african', 'wicketkeeper', 'david', 'richardson', 'runs', 'sports', 'marketing', 'firm', 'johannesburg'], tags=[8]),
#  TaggedDocument(words=['earnings', 'sponsorship', 'proposal', 'apparently', 'help', 'meet', 'players', 'demands', 'better', 'pay', 'reported', 'range', 'dlrs', '000', '000', 'south', 'african', 'tour'], tags=[9]),
#  TaggedDocument(words=[], tags=[10]),
#  TaggedDocument(words=['spirited', 'bidders', 'snap', 'art', 'seized', 'failed', 'finance', 'firms', 'paintings', 'art', 'objects', 'displayed', 'elegant', 'offices', 'snapped', 'weekend', 'thailand', 'auction', 'assets', 'collapsed', 'financial', 'firms', 'thai', 'media', 'reported', 'sunday'], tags=[11]),
#  TaggedDocument(words=['the', 'day', 'auction', '000', 'items', 'ended', 'sunday', 'expected', 'bring', 'initial', 'estimate', 'million', 'baht', 'dlrs', '697', '000'], tags=[12]),
#  TaggedDocument(words=['the', 'paintings', 'sculptures', 'art', 'related', 'objects', 'seized', 'thailand', 'financial', 'restructuring', 'authority', 'government', 'agency', 'set', 'liquidate', 'assets', 'finance', 'companies', 'shut', 'year'], tags=[13]),
#  TaggedDocument(words=['the', 'closings', 'required', 'international', 'monetary', 'fund', 'dlrs', 'billion', 'bailout', 'program', 'depressed', 'thai', 'economy'], tags=[14]),
#  TaggedDocument(words=['the', 'proceeds', 'auction', 'pay', 'debts', 'failed', 'companies'], tags=[15]),
#  TaggedDocument(words=['the', 'going', 'prices', 'high', 'higher', 'expected', 'art', 'gallery', 'owner', 'hongjorn', 'samae', 'ngamjaroen', 'quoted', 'saying', 'bangkok', 'post'], tags=[16]),
#  TaggedDocument(words=['untitled', 'painting', 'lotus', 'pond', 'late', 'thawee', 'nandakwang', 'sold', 'million', 'baht', 'dlrs', '000', 'way', 'starting', 'bid', '400', '000', 'baht', 'dlrs', '300'], tags=[17]),
#  TaggedDocument(words=['prime', 'minister', 'chuan', 'leekpai', 'donated', 'sketches', 'auction', 'handled', 'christies', 'british', 'auction', 'house'], tags=[18]),
#  TaggedDocument(words=['held', 'bangkok', 'queen', 'sirikit', 'natoinal', 'convention', 'center'], tags=[19]),
#  TaggedDocument(words=['repeating', 'protectively', 'iran', 'protest', 'international', 'court', 'justice', 'hague', 'global', 'bodies', 'funded', 'radio', 'free', 'europe', 'iran', 'daily', 'reported', 'monday'], tags=[20]),
#  TaggedDocument(words=['quoted', 'foreign', 'minister', 'kamal', 'kharrazi', 'saying', 'radio', 'set', 'interfere', 'iran', 'internal', 'affairs'], tags=[21]),
#  TaggedDocument(words=['complaints', 'filed'], tags=[22]),
#  TaggedDocument(words=['the', 'english', 'language', 'daily', 'organizations', 'iran', 'approach', 'icj', 'netherlands'], tags=[23]),
#  TaggedDocument(words=['tuesday', 'iran', 'recalled', 'ambassador', 'prague', 'protest', 'czech', 'government', 'assistance', 'radio', 'said', 'reduce', 'level', 'economic', 'political', 'cooperation', 'prague'], tags=[24]),
#  TaggedDocument(words=['the', 'american', 'sponsored', 'station', 'began', 'broadcasts', 'directed', 'iraq', 'friday'], tags=[25]),
#  TaggedDocument(words=['trial', 'period', 'weeks', 'station', 'broadcast', 'minute', 'program', 'day', 'iran', 'iraq'], tags=[26]),
#  TaggedDocument(words=['the', 'farsi', 'language', 'service', 'iran', 'approved', 'czech', 'government', 'august'], tags=[27]),
#  TaggedDocument(words=['radio', 'free', 'europe', 'began', 'transmitting', 'munich', 'germany', '1951', 'spreading', 'uncensored', 'news', 'soviet', 'controlled', 'countries', 'iron', 'curtain', 'cold', 'war', 'west', 'communist', 'east'], tags=[28]),
#  TaggedDocument(words=['moved', 'headquarters', 'prague', '1995', 'following', 'collapse', 'communism', 'years', 'earlier'], tags=[29]),
#  TaggedDocument(words=[], tags=[30]),
#  TaggedDocument(words=['vietnam', 'prime', 'minister', 'demands', 'improvements', 'state', 'monopoly', 'prime', 'minister', 'phan', 'van', 'khai', 'taken', 'state', 'electricity', 'monopoly', 'task', 'abuse', 'power', 'excessive', 'bureaucracy', 'accusing', 'overcharging', 'newspaper', 'dau', 'investment', 'reported', 'thursday'], tags=[31]),
#  TaggedDocument(words=['blunt', 'assessment', 'ordered', 'electricity', 'vietnam', 'help', 'cut', 'waste', 'driving', 'costs', 'spark', 'public', 'discontent'], tags=[32]),
#  TaggedDocument(words=['evn', 'work', 'corrective', 'measures', 'based', 'instructions', 'individual', 'leaders', 'self', 'criticisms'], tags=[33]),
#  TaggedDocument(words=['khai', 'said', 'utility', 'plenty', 'problems', 'particularly', 'tender', 'process', 'project', 'accounting', 'led', 'complaints', 'affect', 'vietnam', 'reputation', 'foreign', 'investors'], tags=[34]),
#  TaggedDocument(words=['march', 'president', 'duc', 'anh', 'article', 'army', 'newspaper', 'criticized', 'irregularities', 'bidding', 'process', 'country', 'largest', 'thermal', 'electric', 'plant'], tags=[35]),
#  TaggedDocument(words=['local', 'media', 'reported', 'company', 'overblown', 'costs', 'construction', 'repair', 'work', 'number', 'projects', 'justify', 'overcharging', 'electricity'], tags=[36]),
#  TaggedDocument(words=['vietnam', 'chronically', 'short', 'power', 'projects', 'raise', 'output', 'bogged', 'bureaucracy'], tags=[37]),
#  TaggedDocument(words=['evn', 'imposed', 'rotating', 'power', 'cuts', 'earlier', 'year', 'worst', 'drought', 'century', 'dropped', 'water', 'levels', 'critical', 'levels', 'reservoir', 'feed', 'key', 'hydroelectric', 'plants'], tags=[38]),
#  TaggedDocument(words=['swiss', 'government', 'eyes', 'shutting', 'nuclear', 'power', 'plants', 'the', 'swiss', 'government', 'thursday', 'announced', 'planning', 'country', 'eventual', 'exit', 'nuclear', 'power', 'saying', 'wants', 'support', 'instead', 'hydroelectric', 'plants'], tags=[39]),
#  TaggedDocument(words=['but', 'environmental', 'campaigners', 'criticized', 'lack', 'timeframe', 'closing', 'country', 'nuclear', 'power', 'plants'], tags=[40]),
#  TaggedDocument(words=['government', 'officials', 'work', 'representatives', 'power', 'industry', 'environmental', 'groups', 'local', 'governments', 'discuss', 'timetable', 'removal', 'nuclear', 'waste', 'government', 'statement', 'said'], tags=[41]),
#  TaggedDocument(words=['unrealistic', 'build', 'power', 'stations', 'environmental', 'concerns', 'government', 'said'], tags=[42]),
#  TaggedDocument(words=['should', 'discussions', 'concerned', 'parties', 'fail', 'produce', 'agreed', 'timetable', 'federal', 'cabinet', 'decision', 'said', 'statement'], tags=[43]),
#  TaggedDocument(words=['set', 'new', 'course', 'said', 'federal', 'energy', 'minister', 'moritz', 'leuenberger'], tags=[44]),
#  TaggedDocument(words=['details', 'decided'], tags=[45]),
#  TaggedDocument(words=['related', 'federal', 'cabinet', 'ordered', 'energy', 'officials', 'draw', 'discussion', 'paper', 'changing', 'laws', 'governing', 'domestic', 'electricity', 'market'], tags=[46]),
#  TaggedDocument(words=['the', 'government', 'envisages', 'creation', 'national', 'company', 'power', 'infrastructure'], tags=[47]),
#  TaggedDocument(words=['timeframe', 'carrying', 'liberalization', 'electricity', 'market', 'remains', 'determined', 'cabinet', 'said'], tags=[48]),
#  TaggedDocument(words=['the', 'cabinet', 'said', 'wants', 'support', 'hydroelectric', 'plants'], tags=[49]),
#  TaggedDocument(words=['ordered', 'study', 'possibility', 'tax', 'breaks', 'hydroelectric', 'plants', 'encourage', 'upgrades', 'plants'], tags=[50]),
#  TaggedDocument(words=['london', 'nov'], tags=[51]),
#  TaggedDocument(words=['word', 'agreement', 'leaked', 'captain', 'courtney', 'walsh', 'head', 'west', 'indies', 'players', 'association', 'told', 'caribbean', 'news', 'agency', 'lara', 'hooper', 'reinstated', 'tour', 'going', 'ahead'], tags=[52]),
#  TaggedDocument(words=['the', 'crisis', 'came', 'head', 'wednesday', 'west', 'indies', 'cricket', 'board', 'fired', 'superstar', 'batsman', 'lara', 'captain', 'hooper', 'vice', 'captain'], tags=[53]),
#  TaggedDocument(words=['the', 'refused', 'travel', 'south', 'africa', 'demanding', 'better', 'pay', 'conditions', 'tour'], tags=[54]),
#  TaggedDocument(words=['team', 'members', 'insisted', 'lara', 'hooper', 'reinstated', 'settlement'], tags=[55]),
#  TaggedDocument(words=['jimmy', 'adams', 'treasurer', 'players', 'assocation', 'negotiated', 'behalf', 'players', 'monday', 'rousseau'], tags=[56]),
#  TaggedDocument(words=['ali', 'bacher', 'head', 'south', 'african', 'cricket', 'directly', 'involved', 'monday', 'talks', 'sitting', 'sidelines', 'sunday'], tags=[57]),
#  TaggedDocument(words=['west', 'indies', 'tour', 'manager', 'clive', 'lloyd', 'wicb', 'member', 'joel', 'garner', 'involved', 'talks', 'began', 'friday'], tags=[58]),
#  TaggedDocument(words=['progress', 'reported', 'weekend', 'announcement', 'sponsorship', 'deal', 'offered', 'south', 'african', 'wicketkeeper', 'david', 'richardson', 'runs', 'sports', 'marketing', 'firm', 'johannesburg'], tags=[59]),
#  TaggedDocument(words=['earnings', 'sponsorship', 'proposal', 'apparently', 'help', 'meet', 'players', 'demands', 'better', 'pay', 'reported', 'range', 'dlrs', '000', '000', 'south', 'african', 'tour'], tags=[60]),
#  TaggedDocument(words=[], tags=[61]),
#  TaggedDocument(words=['airport', 'ready', 'operation', 'palestinians', 'await', 'word', 'israel', 'the', 'new', 'palestinian', 'airport', 'powerful', 'symbol', 'fledgling', 'independence', 'ready', 'open', 'head', 'palestinian', 'civil', 'aviation', 'authority', 'said', 'friday', 'operations', 'drill', 'israeli', 'officials'], tags=[62]),
#  TaggedDocument(words=['yasser', 'arafat', 'international', 'airport', 'southern', 'gaza', 'strip', 'opened', 'week', 'israeli', 'palestinian', 'peace', 'agreement'], tags=[63]),
#  TaggedDocument(words=['however', 'israel', 'fell', 'schedule', 'held', 'cabinet', 'ratification', 'accord', 'weeks'], tags=[64]),
#  TaggedDocument(words=['prime', 'minister', 'benjamin', 'netanyahu', 'said', 'airport', 'start', 'operating', 'week', 'set', 'date'], tags=[65]),
#  TaggedDocument(words=['thursday', 'israeli', 'palestinian', 'officials', 'staged', 'hour', 'drill', 'said', 'fayez', 'zeidan', 'head', 'palestinian', 'civil', 'aviation', 'authority'], tags=[66]),
#  TaggedDocument(words=['about', '100', 'palestinian', 'airport', 'employees', 'israelis', 'share', 'security', 'duties', 'played', 'roles', 'passengers', 'airport', 'personnel'], tags=[67]),
#  TaggedDocument(words=['for', 'lack', 'plane', 'passengers', 'arrived', 'bus'], tags=[68]),
#  TaggedDocument(words=['zeidan', 'said', 'exercise', 'covered', 'arrival', 'departure', 'procedures', 'including', 'passport', 'checks', 'customs', 'luggage', 'inspection'], tags=[69]),
#  TaggedDocument(words=['said', 'airport', 'ready', 'operation'], tags=[70]),
#  TaggedDocument(words=['need', 'hear', 'israelis', 'zeidan', 'said'], tags=[71]),
#  TaggedDocument(words=['stolen', 'painting', 'new', 'zealand', 'recovered', 'man', 'arrested', '19th', 'century', 'painting', 'worth', 'dlrs', 'million', 'stolen', 'auckland', 'art', 'gallery', 'days', 'ago', 'recovered', 'police', 'said', 'monday'], tags=[72]),
#  TaggedDocument(words=['senior', 'sgt'], tags=[73]),
#  TaggedDocument(words=['gary', 'allcock', 'said', 'understood', 'person', 'arrested', 'theft', '1874', 'oil', 'still', 'top', 'french', 'born', 'artist', 'jacques', 'joseph', 'james', 'tissot', 'new', 'zealand', 'expensive', 'popular', 'european', 'works'], tags=[74]),
#  TaggedDocument(words=['said', 'details', 'disclosed', 'later'], tags=[75]),
#  TaggedDocument(words=['the', 'painting', 'valued', 'dlrs', 'million', 'stolen', 'aug', 'man', 'armed', 'shotgun', 'daring', 'robbery', 'auckland', 'art', 'gallery'], tags=[76]),
#  TaggedDocument(words=['the', 'man', 'clad', 'black', 'wearing', 'motorcycle', 'helmet', 'dark', 'visor', 'gloves', 'burst', 'main', 'door', 'sawed', 'shotgun', 'crowbar'], tags=[77]),
#  TaggedDocument(words=['museum', 'official', 'kate', 'darrow', 'said', 'man', 'ran', 'grey', 'gallery', 'waving', 'firearm', 'yelling', 'staff', 'patrons'], tags=[78]),
#  TaggedDocument(words=['she', 'said', 'man', 'appeared', 'know', 'going', 'went', 'lower', 'wellesley', 'gallery', 'painting', 'displayed'], tags=[79]),
#  TaggedDocument(words=['the', 'gunman', 'grabbed', 'painting', 'wall', 'dropped', 'ground'], tags=[80]),
#  TaggedDocument(words=['crowbar', 'remove', 'canvas', 'frame', 'backing', 'board'], tags=[81]),
#  TaggedDocument(words=['the', 'robber', 'left', 'main', 'entrance', 'skirted', 'gallery', 'albert', 'park', 'pursued', 'member', 'public'], tags=[82]),
#  TaggedDocument(words=['believed', 'climbed', 'motorcycle', 'escaped', 'nearby', 'highway'], tags=[83]),
#  TaggedDocument(words=['english', 'viravaidya', 'plan', 'set', 'watchdog', 'company', 'monitor', 'set', 'listed', 'companies', 'expose', 'possible', 'abuses', 'corporate', 'ethics'], tags=[84]),
#  TaggedDocument(words=['agree', 'heartedly', 'like', 'know', 'mail', 'checks', 'subscribe', 'company', 'shares'], tags=[85]),
#  TaggedDocument(words=['could', 'advise'], tags=[86]),
#  TaggedDocument(words=['also', 'fully', 'support', 'request', 'media', 'report', 'lifestyle', 'executives', 'failed', 'banks', 'finance', 'companies'], tags=[87]),
#  TaggedDocument(words=['know', 'people', 'punished', 'legally', 'inefficiency', 'bank', 'thailand', 'collecting', 'evidence', 'justice', 'delivering', 'timely', 'justice'], tags=[88]),
#  TaggedDocument(words=['media', 'job', 'discover', 'guys', 'better', 'destroying', 'country', 'thai', 'people', 'job', 'socially', 'punish'], tags=[89]),
#  TaggedDocument(words=['like', 'propose', 'newspapers', 'stations', 'play', 'issue', 'continued', 'luxurious', 'lifestyle', 'executives', 'attract', 'public', 'attention', 'bt20', '000', 'hard', 'earned', 'salary', 'blessing'], tags=[90]),
#  TaggedDocument(words=['artit', 'krichphiphat', 'ordinary', 'thai', 'citizen', 'wants', 'right', 'things', 'editor', 'note', 'khun', 'mechai', 'organise', 'seminar', 'plan', 'june', 'telephone', 'organisation', 'thailand'], tags=[91]),
#  TaggedDocument(words=['the', 'media', 'duty', 'cover', 'issues', 'additional', 'financial', 'reward'], tags=[92]),
#  TaggedDocument(words=['iran', 'complain', 'radio', 'hague', 'tribunal', 'iran', 'protest', 'international', 'court', 'justice', 'hague', 'global', 'bodies', 'funded', 'radio', 'free', 'europe', 'iran', 'daily', 'reported', 'monday'], tags=[93]),
#  TaggedDocument(words=['quoted', 'foreign', 'minister', 'kamal', 'kharrazi', 'saying', 'radio', 'set', 'interfere', 'iran', 'internal', 'affairs'], tags=[94]),
#  TaggedDocument(words=['complaints', 'filed'], tags=[95]),
#  TaggedDocument(words=['the', 'english', 'language', 'daily', 'organizations', 'iran', 'approach', 'icj', 'netherlands'], tags=[96]),
#  TaggedDocument(words=['tuesday', 'iran', 'recalled', 'ambassador', 'prague', 'protest', 'czech', 'government', 'assistance', 'radio', 'said', 'reduce', 'level', 'economic', 'political', 'cooperation', 'prague'], tags=[97]),
#  TaggedDocument(words=['the', 'american', 'sponsored', 'station', 'began', 'broadcasts', 'directed', 'iraq', 'friday'], tags=[98]),
#  TaggedDocument(words=['trial', 'period', 'weeks', 'station', 'broadcast', 'minute', 'program', 'day', 'iran', 'iraq'], tags=[99]),
#  TaggedDocument(words=['the', 'farsi', 'language', 'service', 'iran', 'approved', 'czech', 'government', 'august'], tags=[100]),
#  TaggedDocument(words=['radio', 'free', 'europe', 'began', 'transmitting', 'munich', 'germany', '1951', 'spreading', 'uncensored', 'news', 'soviet', 'controlled', 'countries', 'iron', 'curtain', 'cold', 'war', 'west', 'communist', 'east'], tags=[101]),
#  TaggedDocument(words=['moved', 'headquarters', 'prague', '1995', 'following', 'collapse', 'communism', 'years', 'earlier'], tags=[102]),
#  TaggedDocument(words=['museum', 'return', 'stolen', 'works', 'los', 'angeles', 'the', 'paul', 'getty', 'museum', 'returning', 'ancient', 'works', 'art', 'italy', 'determining', 'stolen'], tags=[103]),
#  TaggedDocument(words=['one', 'sculpture', 'sat', 'collection', 'years'], tags=[104]),
#  TaggedDocument(words=['the', 'objects', 'flown', 'italy', 'week', 'pieces', 'loaned', 'museum', 'antiquities', 'exhibit', 'according', 'statement', 'issued', 'getty', 'monday'], tags=[105]),
#  TaggedDocument(words=['the', 'stolen', 'items', 'terra', 'cotta', 'drinking', 'cup', '480'], tags=[106]),
#  TaggedDocument(words=['illegally', 'excavated', 'archaeological', 'site', 'torso', 'god', 'mithras', '2nd', 'century', 'stolen', 'private', 'italian', 'collection', 'sculpted', 'head', 'victorious', 'athlete', '2nd', 'century', 'roman', 'copy', 'earlier', 'greek', 'work', 'apparently', 'taken', 'storeroom', 'scientific', 'excavation'], tags=[107]),
#  TaggedDocument(words=['for', 'security', 'reasons', 'museum', 'pieces', 'worth'], tags=[108]),
#  TaggedDocument(words=['although', 'claimed', 'works', 'getty', 'decided', 'return', 'based', 'information', 'supplied', 'experts', 'field', 'consultation', 'italian', 'officials'], tags=[109]),
#  TaggedDocument(words=['international', 'concern', 'growing', 'rampant', 'thefts', 'priceless', 'art', 'collections', 'looting', 'archaeological', 'sites'], tags=[110]),
#  TaggedDocument(words=['the', 'billion', 'dollar', 'museum', 'located', 'hill', 'brentwood', 'area', 'opened', '1997'], tags=[111]),
#  TaggedDocument(words=['iraq', 'iran', 'sign', 'pact', 'resolve', 'pow', 'issue', 'iraq', 'iran', 'signed', 'deal', 'iraq', 'says', 'resolve', 'longstanding', 'dispute', 'prisoners', 'war'], tags=[112]),
#  TaggedDocument(words=['the', 'agreement', 'reached', 'following', 'week', 'talks', 'baghdad', 'senior', 'iraqi', 'officials', 'visiting', 'iranian', 'delegation', 'headed', 'abdullah', 'najafi', 'head', 'iran', 'pow', 'commission', 'official', 'iraqi', 'news', 'agency', 'reported', 'wednesday'], tags=[113]),
#  TaggedDocument(words=['but', 'agency', 'gave', 'details', 'najafi', 'left', 'baghdad', 'wednesday', 'declined', 'comment'], tags=[114]),
#  TaggedDocument(words=['najafi', 'arrived', 'baghdad', 'week', 'list', 'thousands', 'iranian', 'pows', 'tehran', 'claims', 'held', 'iraq'], tags=[115]),
#  TaggedDocument(words=['iraq', 'long', 'maintained', 'released', 'iranian', 'prisoners', 'reportedly', 'angered', 'new', 'list'], tags=[116]),
#  TaggedDocument(words=['april', 'iran', 'released', '584', 'iraqi', 'pows', 'iraq', 'freed', 'pows', '316', 'iranians', 'classified', 'civil', 'law', 'detainees'], tags=[117]),
#  TaggedDocument(words=['largest', 'repatriation', 'iranian', 'iraqi', 'pows', '1990', 'said', 'international', 'committee', 'red', 'cross', 'supervised', 'swap'], tags=[118]),
#  TaggedDocument(words=['the', 'red', 'cross', 'says', 'knows', 'thousand', 'iraqis', 'iran', 'aware', 'iranian', 'pows', 'iraq'], tags=[119]),
#  TaggedDocument(words=['the', 'iran', 'iraq', 'war', 'million', 'people', 'killed', 'wounded', 'ended', '1988'], tags=[120]),
#  TaggedDocument(words=['the', 'issue', 'pows', 'long', 'stood', 'way', 'better', 'ties'], tags=[121]),
#  TaggedDocument(words=[], tags=[122]),
#  TaggedDocument(words=['hare', 'closes', 'terminal', 'security', 'chicago', 'united', 'airlines', 'shut', 'terminal', 'hours', 'authorities', 'search', 'passenger', 'ran', 'past', 'security', 'checkpoint', 'disappeared', 'crowd', 'hare', 'international', 'airport'], tags=[123]),
#  TaggedDocument(words=['united', 'spokeswoman', 'kristina', 'price', 'said', '131', 'flights', 'canceled', 'thursday', '100', 'delayed', 'nationwide', 'incident'], tags=[124]),
#  TaggedDocument(words=['about', '000', 'passengers', 'cleared', 'terminal', 'search', 'airline', 'officials', 'said'], tags=[125]),
#  TaggedDocument(words=['eighty', 'flights', 'canceled', 'today', 'numerous', 'delayed', 'effects', 'shutdown', 'lingered', 'price', 'said', 'adding', 'carrier', 'hoped', 'normal', 'schedule', 'afternoon'], tags=[126]),
#  TaggedDocument(words=['the', 'man', 'chicago', 'police', 'said', 'officers', 'turned', 'suspicious'], tags=[127]),
#  TaggedDocument(words=['leaving', 'concourse', 'heading', 'baggage', 'claim', 'area', 'turned', 'ran', 'way', 'staircase', 'leading', 'concourse', 'united', 'spokesman', 'matthew', 'triaca', 'said'], tags=[128]),
#  TaggedDocument(words=['guards', 'stationed', 'staircase', 'man', 'ran', 'past'], tags=[129]),
#  TaggedDocument(words=['united', 'flights', 'left', 'terminal', 'search', 'landed', 'united', 'gates'], tags=[130]),
#  TaggedDocument(words=['some', 'flights', 'resumed', 'early', 'evening'], tags=[131]),
#  TaggedDocument(words=['iraqi', 'minister', 'arrives', 'iran', 'attend', 'trade', 'fair', 'iraq', 'trade', 'minister', 'arrived', 'wednesday', 'attend', 'international', 'trade', 'fair', 'hold', 'discussions', 'iranian', 'counterpart', 'islamic', 'republic', 'news', 'agency', 'reported'], tags=[132]),
#  TaggedDocument(words=['mohammed', 'mehdi', 'saleh', 'seven', 'member', 'delegation', 'traveled', 'land', 'crossed', 'iran', 'khosrawi', 'border', 'point', 'western', 'kermanshah', 'province', 'official', 'news', 'agency', 'said'], tags=[133]),
#  TaggedDocument(words=['quoted', 'saleh', 'saying', 'discuss', 'iran', 'trade', 'minister', 'mohammad', 'shariat', 'madari', 'ways', 'expanding', 'commercial', 'ties', 'countries'], tags=[134]),
#  TaggedDocument(words=['the', 'fair', 'scheduled', 'oct'], tags=[135]),
#  TaggedDocument(words=['this', 'second', 'consecutive', 'year', 'iraq', 'attending', 'tehran', 'international', 'trade', 'fair', 'points', 'need', 'neighbors', 'business', 'despite', 'traditional', 'animosity'], tags=[136]),
#  TaggedDocument(words=['iran', 'iraq', 'fought', 'year', 'war', 'ended', 'brokered', 'cease'], tags=[137]),
#  TaggedDocument(words=['iran', 'claims', 'iraq', 'holds', '000', 'prisoners', 'war', 'iraq', 'says', 'iran', 'holding', '000', 'prisoners'], tags=[138]),
#  TaggedDocument(words=['more', 'million', 'people', 'killed', 'wounded', 'sides', '1980', 'war'], tags=[139]),
#  TaggedDocument(words=['tehran', 'accuses', 'baghdad', 'helping', 'iranian', 'opposition', 'groups', 'sides', 'accuse', 'allowing', 'infiltrators', 'sneak', 'borders', 'acts', 'sabotage'], tags=[140]),
#  TaggedDocument(words=['december', 'iraqi', 'vice', 'president', 'taha', 'yassin', 'ramadan', 'highest', 'ranking', 'iraqi', 'visit', 'tehran', '1991', 'gulf', 'war', 'attended', 'organization', 'islamic', 'conference', 'meeting'], tags=[141]),
#  TaggedDocument(words=[], tags=[142]),
#  TaggedDocument(words=['actress', 'brooke', 'shields', 'accepts', 'libel', 'damages', 'apology', 'false', 'actress', 'brooke', 'shields', 'monday', 'accepted', 'substantial', 'libel', 'damages', 'public', 'apology', 'newspaper', 'article', 'alleging', 'questioned', 'police', 'hours', 'connection', 'drug', 'offenses', 'left', 'cannes', 'film', 'festival'], tags=[143]),
#  TaggedDocument(words=['the', 'mail', 'sunday', 'reported', 'may', 'exclusive', 'began', 'page', 'continued', 'page', 'miss', 'shields', 'luggage', 'searched', 'flight', 'nice', 'airport', 'delayed', 'french', 'police', 'quizzed'], tags=[144]),
#  TaggedDocument(words=['after', 'actress', 'filed', 'suit', 'associated', 'newspapers', 'ltd', 'publisher', 'mail', 'sunday', 'paper', 'editor', 'mail', 'journalists', 'mail', 'sunday', 'published', 'page', 'apology', 'retraction', 'may'], tags=[145]),
#  TaggedDocument(words=['the', 'retraction', 'said', 'story', 'totally', 'false', 'conceded', 'miss', 'shields', 'stopped', 'airport'], tags=[146]),
#  TaggedDocument(words=['the', 'defendants', 'recognize', 'miss', 'shields', 'staunch', 'committed', 'anti', 'drug', 'campaigner', 'spent', 'considerable', 'amounts', 'time', 'supporting', 'substance', 'abuse', 'programs', 'raising', 'needed', 'money', 'anti', 'drug', 'abuse', 'programs', 'said', 'claire', 'shields', 'defendants', 'attorney'], tags=[147]),
#  TaggedDocument(words=['the', 'newspaper', 'page', 'article', 'especially', 'hurtful', 'family', 'attorney', 'said'], tags=[148]),
#  TaggedDocument(words=['the', 'sunday', 'paper', 'editor', 'jonathan', 'holborow', 'written', 'actress', 'present', 'court', 'monday', 'personal', 'letter', 'apology'], tags=[149]),
#  TaggedDocument(words=['the', 'damages', 'disclosed'], tags=[150]),
#  TaggedDocument(words=[], tags=[151]),
#  TaggedDocument(words=['hungarian', 'government', 'jewish', 'communities', 'agree', 'compensation', 'the', 'hungarian', 'government', 'federation', 'hungarian', 'jewish', 'communities', 'signed', 'agreement', 'thursday', 'collective', 'compensation', 'communist', 'era', 'confiscations', 'state', 'news', 'agency', 'mti', 'reported'], tags=[152]),
#  TaggedDocument(words=['the', 'financial', 'basis', 'funding', 'real', 'estate', 'belonged', 'jewish', 'communities', 'fell', 'victim', 'nationalization', 'communists'], tags=[153]),
#  TaggedDocument(words=['instead', 'getting', 'actual', 'property', '152', 'schools', 'buildings', 'assessed', 'value', '511', '000', '000', 'forints', 'dlrs', 'million', 'jewish', 'community', 'collectively', 'percentage', 'annually', 'starting', 'current', 'year', '608', 'million', 'forints', 'dlrs', 'million', 'paid'], tags=[154]),
#  TaggedDocument(words=['the', 'money', 'mainly', 'education', 'religious', 'services', 'social', 'welfare', 'health', 'service', 'charity', 'ends', 'gusztav', 'zoltai', 'executive', 'director', 'federation', 'said'], tags=[155]),
#  TaggedDocument(words=['there', '000', '100', '000', 'jews', 'hungary'], tags=[156]),
#  TaggedDocument(words=['some', '600', '000', 'killed', 'holocaust'], tags=[157]),
#  TaggedDocument(words=['when', 'communists', 'assumed', 'power', '1948', 'started', 'wave', 'nationalizations', 'spared', 'including', 'jewish', 'community'], tags=[158]),
#  TaggedDocument(words=['june', '1997', 'similar', 'agreement', 'kind', 'signed', 'hungarian', 'government', 'vatican'], tags=[159]),
#  TaggedDocument(words=[], tags=[160]),
#  TaggedDocument(words=['thailand', 'more', 'people', 'dying', 'suffering', 'fatal', 'diseases', 'brain', 'tumours', 'mammarian', 'breast', 'cancer', 'brain', 'haemorrhage', 'lack', 'proper', 'medical', 'care', 'however', 'things', 'change', 'srisiam', 'hospital', 'bangkok', 'established', 'radio', 'surgery', 'institute', 'thailand', 'presently', '100', 'radio', 'surgery', 'centres', 'world'], tags=[161]),
#  TaggedDocument(words=['radio', 'surgery', 'modern', 'technique', 'require', 'surgery', 'order', 'remove', 'cancerous', 'growth', 'tissues'], tags=[162]),
#  TaggedDocument(words=['involves', 'dimensional', 'method', 'known', 'stereotaxic', 'surgery', 'conjunction', 'radiation', 'equipment', 'known', 'linear', 'accelerator'], tags=[163]),
#  TaggedDocument(words=['with', 'new', 'technology', 'doctors', 'able', 'removal', 'cancerous', 'tissues', 'embedded', 'deep', 'inside', 'brain', 'near', 'sensitive', 'organs', 'makes', 'normal', 'surgery', 'difficult', 'risky'], tags=[164]),
#  TaggedDocument(words=['with', 'radio', 'surgery', 'step', 'controlled', 'computers', 'patients', 'conscious', 'undergo', 'treatment'], tags=[165]),
#  TaggedDocument(words=['this', 'new', 'technique', 'capable', 'treating', 'diseases', 'artero', 'venous', 'malformation', 'clotting', 'veins', 'blood', 'capillaries', 'brain', 'far', 'ninety', 'cent', 'radio', 'surgery', 'treatments', 'successful', 'patients', 'remain', 'hospital', 'days'], tags=[166]),
#  TaggedDocument(words=['additionally', 'need', 'patients', 'shave', 'heads', 'radio', 'surgery', 'causes', 'scar', 'little', 'blood', 'loss', 'expensive', 'for', 'information', 'contact', 'hospital', 'srisiam', 'ksc', 'com'], tags=[167]),
#  TaggedDocument(words=['iranian', 'pow', 'negotiator', 'holds', 'talks', 'iraqi', 'ministers', 'the', 'head', 'iran', 'prisoner', 'war', 'commission', 'met', 'iraqi', 'cabinet', 'ministers', 'saturday', 'bid', 'glean', 'information', 'thousands', 'iranian', 'pows', 'allegedly', 'iraq', 'official', 'iraqi', 'news', 'agency', 'reported'], tags=[168]),
#  TaggedDocument(words=['iraqi', 'foreign', 'minister', 'mohammed', 'saeed', 'sahhaf', 'told', 'abdullah', 'najafi', 'states', 'needed', 'speed', 'closure', 'remains', 'pow', 'missing', 'action', 'file', 'ina', 'said'], tags=[169]),
#  TaggedDocument(words=['the', 'issue', 'pows', 'missing', 'persons', 'remains', 'stumbling', 'block', 'normalizing', 'relations', 'neighbors'], tags=[170]),
#  TaggedDocument(words=['iraq', 'long', 'maintained', 'released', 'iranian', 'prisoners', 'captured', '1980', 'iran', 'iraq', 'war'], tags=[171]),
#  TaggedDocument(words=['the', 'countries', 'accuse', 'hiding', 'pows', 'preventing', 'visits', 'international', 'committee', 'red', 'cross', 'prisoner', 'camps'], tags=[172]),
#  TaggedDocument(words=['the', 'icrc', 'representative', 'baghdad', 'manuel', 'bessler', 'told', 'the', 'associated', 'press', 'organization', 'difficulty', 'visiting', 'pows', 'sides', 'regular', 'basis'], tags=[173]),
#  TaggedDocument(words=['april', 'iran', 'released', '584', 'iraqi', 'pows', 'iraq', 'freed', 'pows', '316', 'iranians', 'classified', 'civil', 'law', 'detainees', 'largest', 'exchange', '1990'], tags=[174]),
#  TaggedDocument(words=['more', 'million', 'people', 'killed', 'wounded', 'iran', 'iraq', 'war'], tags=[175]),
#  TaggedDocument(words=['german', 'zoo', 'hopes', 'court', 'allow', 'accept', 'baby', 'elephants', 'the', 'dresden', 'zoo', 'went', 'court', 'tuesday', 'challenge', 'environment', 'minister', 'juergen', 'trittin', 'order', 'forbidding', 'import', 'baby', 'elephants', 'taken', 'wild', 'africa', 'abused'], tags=[176]),
#  TaggedDocument(words=['zoo', 'director', 'hubert', 'luecker', 'said', 'complaint', 'filed', 'administrative', 'court', 'cologne'], tags=[177]),
#  TaggedDocument(words=['the', 'elephants', 'sent', 'month', 'dresden', 'erfurt', 'zoos', 'eastern', 'germany', 'group', 'young', 'elephants', 'captured', 'august', 'herds', 'botswana', 'taken', 'south', 'african', 'farm'], tags=[178]),
#  TaggedDocument(words=['south', 'african', 'judge', 'ruled', 'early', 'month', 'animals', 'abused', 'deprived', 'water', 'farm'], tags=[179]),
#  TaggedDocument(words=['granted', 'temporary', 'custody', 'national', 'society', 'prevention', 'cruelty', 'animals'], tags=[180]),
#  TaggedDocument(words=['but', 'judge', 'approved', 'export', 'baby', 'elephants', 'germany', 'switzerland', 'trittin', 'week', 'said', 'germany', 'protest', 'abuse', 'animals', 'accepting', 'zoos'], tags=[181]),
#  TaggedDocument(words=['others', 'argue', 'elephants', 'face', 'worse', 'fate', 'come', 'germany'], tags=[182]),
#  TaggedDocument(words=['norbert', 'otto', 'federal', 'lawmaker', 'erfurt', 'demanded', 'parliament', 'tuesday', 'trittin', 'steps', 'prevent', 'animals', 'sleep', 'south', 'africa'], tags=[183]),
#  TaggedDocument(words=['addition', 'cultural', 'minister', 'saxony', 'dresden', 'capital', 'asked', 'state', '740', '000', 'school', 'children', 'write', 'letters', 'protest', 'urging', 'tritten', 'allow', 'elephants', 'germany'], tags=[184]),
#  TaggedDocument(words=['aet', 'pfg'], tags=[185]),
#  TaggedDocument(words=['malaysia', 'port', 'dickson', 'tues', 'federal', 'state', 'government', 'agencies', 'given', 'task', 'undertake', 'economic', 'projects', 'development', 'programme', 'hardcore', 'poor', 'pprt', 'ensure', 'successful', 'implementation'], tags=[186]),
#  TaggedDocument(words=['rural', 'development', 'minister', 'datuk', 'annuar', 'musa', 'said', 'yesterday', 'responsible', 'closely', 'monitor', 'implementation', 'projects', 'ensure', 'allocation', 'provided', 'ministry', 'benefit', 'hardcore', 'poor', 'participants'], tags=[187]),
#  TaggedDocument(words=['said', 'responsible', 'including', 'district', 'officers', 'personally', 'check', 'progress', 'projects', 'carried'], tags=[188]),
#  TaggedDocument(words=['want', 'projects', 'success', 'paper', 'inspection', 'desired', 'results', 'added'], tags=[189]),
#  TaggedDocument(words=['according', 'ministry', 'policy', 'minister', 'deputy', 'minister', 'parliamentary', 'secretary', 'director', 'general', 'senior', 'ministry', 'officials', 'visit', 'pprt', 'projects', 'happening', 'allocation', 'given', 'government'], tags=[190]),
#  TaggedDocument(words=['annuar', 'said', 'visiting', 'mussel', 'rearing', 'project', 'kuala', 'lukut', 'today', 'day', 'long', 'visit', 'pprt', 'projects', 'negri', 'sembilan'], tags=[191]),
#  TaggedDocument(words=['present', 'chembong', 'assemblyman', 'firdaus', 'harun', 'port', 'dickson', 'district', 'officer', 'hassan', 'nawawi', 'abdul', 'rahman'], tags=[192]),
#  TaggedDocument(words=['annuar', 'added', 'implementing', 'agencies', 'conduct', 'depth', 'studies', 'projects', 'proposed', 'ensure', 'viability'], tags=[193]),
#  TaggedDocument(words=['interpol', 'needs', 'revamp', 'strategy', 'abreast', 'crime', 'interpol', 'modernize', 'wants', 'effectively', 'fight', 'increasingly', 'sophisticated', 'crime', 'syndicates', 'century', 'police', 'organization', 'president', 'said', 'thursday'], tags=[194]),
#  TaggedDocument(words=['the', 'criminal', 'environment', 'changed', 'greater', 'pace', 'interpol', 'toshinori', 'kanemoto', 'told', 'opening', 'session', '67th', 'general', 'assembly', 'international', 'criminal', 'police', 'organization'], tags=[195]),
#  TaggedDocument(words=['failure', 'modernize', 'interpol', 'mean', 'organization', 'risks', 'displaced', 'backdrop', 'international', 'organized', 'crime', 'said'], tags=[196]),
#  TaggedDocument(words=['kanemoto', 'said', 'new', 'interpol', 'strategy', 'discussed', 'day', 'assembly', 'adopted', 'effect', 'january'], tags=[197]),
#  TaggedDocument(words=['the', 'japanese', 'police', 'official', 'said', 'assembly', 'discuss', 'terrorism', 'called', 'new', 'forms', 'criminality', 'illegal', 'drug', 'trade', 'money', 'laundering'], tags=[198]),
#  TaggedDocument(words=['with', 'crime', 'increasingly', 'sophisticated', 'kanemoto', 'said', 'harder', 'police', 'officials', 'gather', 'evidence', 'prosecution'], tags=[199]),
#  TaggedDocument(words=['said', 'new', 'challenges', 'require', 'increased', 'cooperation', 'particularly', 'interpol'], tags=[200]),
#  TaggedDocument(words=['the', 'police', 'officials', 'expected', 'discuss', 'strategic', 'development', 'plan', 'aimed', 'making', 'interpol', 'proactive', 'examining', 'needs', 'group', '177', 'member', 'states', 'kanemoto', 'said'], tags=[201]),
#  TaggedDocument(words=['details', 'graf', 'pvs'], tags=[202]),
#  TaggedDocument(words=['austrian', 'president', 'tells', 'albright', 'effort', 'identify', 'stolen', 'art', 'austria', 'president', 'told', 'secretary', 'state', 'madeleine', 'albright', 'thursday', 'government', 'establishing', 'commission', 'identify', 'art', 'stolen', 'holocaust', 'victims', 'nazis'], tags=[203]),
#  TaggedDocument(words=['austrian', 'officials', 'said', 'president', 'thomas', 'klestil', 'told', 'albright', 'paid', 'day', 'visit', 'vienna', 'moscow', 'summit', 'commission', 'determine', 'origin', 'art', 'works', 'owned', 'federal', 'museum'], tags=[204]),
#  TaggedDocument(words=['there', 'statement', 'art', 'issue', 'officials'], tags=[205]),
#  TaggedDocument(words=['albright', 'left', 'united', 'states', 'meetings', 'klestil', 'chancellor', 'viktor', 'klima', 'foreign', 'minister', 'wolfgang', 'schuessel'], tags=[206]),
#  TaggedDocument(words=['austria', 'united', 'states', 'nations', 'launched', 'drive', 'identify', 'billions', 'dollars', 'worth', 'art', 'stolen', 'holocaust', 'victims', 'europe'], tags=[207]),
#  TaggedDocument(words=['the', 'world', 'jewish', 'congress', 'estimates', 'current', 'value', 'stolen', 'art', 'dlrs', 'billion', 'dlrs', '140', 'billion'], tags=[208]),
#  TaggedDocument(words=['june', 'association', 'art', 'museum', 'directors', 'united', 'states', 'recommended', 'american', 'art', 'museums', 'check', 'collections', 'determine', 'works', 'stolen', 'war', 'set', 'worldwide', 'database', 'tracking'], tags=[209]),
#  TaggedDocument(words=['austria', 'absorbed', 'adolf', 'hitler', 'germany', '1938', 'restored', 'independent', 'nation', 'following', 'world', 'war'], tags=[210]),
#  TaggedDocument(words=[], tags=[211]),
#  TaggedDocument(words=['lufthansa', 'german', 'railway', 'pledge', 'closer', 'cooperation', 'seeking', 'shift', 'domestic', 'travel', 'planes', 'trains', 'germany', 'flag', 'carrier', 'lufthansa', 'german', 'railway', 'signed', 'letter', 'intent', 'monday', 'work', 'coordinating', 'services', 'schedules'], tags=[212]),
#  TaggedDocument(words=['the', 'goal', 'easier', 'travel', 'train', 'lufthansa', 'main', 'hub', 'frankfurt', 'instead', 'flying'], tags=[213]),
#  TaggedDocument(words=['starting', '2001', 'lufthansa', 'boss', 'juergen', 'weber', 'hopes', 'eliminate', 'short', 'hops', 'frankfurt', 'cologne', 'example', 'freeing', 'takeoff', 'landing', 'slots', 'lucrative', 'international', 'flights'], tags=[214]),
#  TaggedDocument(words=['lufthansa', 'deutsche', 'bahn', 'deal', 'passengers', 'check', 'luggage', 'train', 'station', 'lufthansa', 'flight', 'catch', 'frankfurt'], tags=[215]),
#  TaggedDocument(words=['the', 'service', 'place', 'saarbruecken', 'travelers', 'drop', 'bags', 'day'], tags=[216]),
#  TaggedDocument(words=['starting', 'september', 'service', 'extended', 'cities', 'duesseldorf', 'cologne', 'bonn', 'wuerzburg', 'nuremberg'], tags=[217]),
#  TaggedDocument(words=['passengers', 'flying', 'lufthansa', 'partners', 'united', 'sas', 'able', 'use', 'service', 'said'], tags=[218]),
#  TaggedDocument(words=['the', 'airline', 'railway', 'said', 'form', 'working', 'group', 'resolve', 'problems', 'security', 'checks', 'luggage', 'making', 'sure', 'bags', 'airport', 'train', 'station', 'time'], tags=[219]),
#  TaggedDocument(words=['deutsche', 'bahn', 'chief', 'johannes', 'ludewig', 'said', 'railway', 'work', 'coordinate', 'schedules', 'better', 'lufthansa', 'flights', 'connections', 'easier', 'allow', 'combined', 'train', 'plane', 'tickets'], tags=[220]),
#  TaggedDocument(words=['pfg', 'aet'], tags=[221]),
#  TaggedDocument(words=['repeating', 'protectively', 'iran', 'protest', 'international', 'court', 'justice', 'hague', 'global', 'bodies', 'funded', 'radio', 'free', 'europe', 'iran', 'daily', 'reported', 'monday'], tags=[222]),
#  TaggedDocument(words=['quoted', 'foreign', 'minister', 'kamal', 'kharrazi', 'saying', 'radio', 'set', 'interfere', 'iran', 'internal', 'affairs'], tags=[223]),
#  TaggedDocument(words=['complaints', 'filed'], tags=[224]),
#  TaggedDocument(words=['the', 'english', 'language', 'daily', 'organizations', 'iran', 'approach', 'icj', 'netherlands'], tags=[225]),
#  TaggedDocument(words=['tuesday', 'iran', 'recalled', 'ambassador', 'prague', 'protest', 'czech', 'government', 'assistance', 'radio', 'said', 'reduce', 'level', 'economic', 'political', 'cooperation', 'prague'], tags=[226]),
#  TaggedDocument(words=['the', 'american', 'sponsored', 'station', 'began', 'broadcast', 'directed', 'iraq', 'friday'], tags=[227]),
#  TaggedDocument(words=['trial', 'period', 'weeks', 'station', 'broadcast', 'minute', 'program', 'day', 'iran', 'iraq'], tags=[228]),
#  TaggedDocument(words=['the', 'farsi', 'language', 'service', 'iran', 'approved', 'czech', 'government', 'august'], tags=[229]),
#  TaggedDocument(words=['radio', 'free', 'europe', 'began', 'transmitting', 'munich', 'germany', '1951', 'spreading', 'uncensored', 'news', 'soviet', 'controlled', 'countries', 'iron', 'curtain', 'cold', 'war', 'west', 'communist', 'east'], tags=[230]),
#  TaggedDocument(words=['moved', 'headquarters', 'prague', '1995', 'following', 'collapse', 'communism', 'years', 'earlier'], tags=[231]),
#  TaggedDocument(words=[], tags=[232]),
#  TaggedDocument(words=['this', 'dracula', 'kills', 'cattle', 'deer', 'giant', 'black', 'bear', 'peasants', 'nicknamed', 'dracula', 'creating', 'anxiety', 'western', 'romania', 'taste', 'cattle', 'sheep', 'official', 'said', 'thursday'], tags=[233]),
#  TaggedDocument(words=['peasants', 'livestock', 'devoured', 'hungry', 'bear', 'lodged', 'seven', 'complaints', 'past', 'weeks', 'said', 'nicolae', 'onetiu', 'head', 'state', 'hunting', 'fishing', 'reserves', 'western', 'romania'], tags=[234]),
#  TaggedDocument(words=['dracula', 'named', 'transylvania', 'vampire', 'count', 'legend', 'bloody', 'appetite', 'said', 'onetiu'], tags=[235]),
#  TaggedDocument(words=['the', 'male', 'bruin', 'weighs', '300', 'kilograms', '660', 'pounds', 'moved', 'closer', 'inhabited', 'areas', 'forested', 'regions', 'onset', 'cold', 'weather', 'apparently', 'ready', 'hibernate'], tags=[236]),
#  TaggedDocument(words=['dracula', 'killed', 'cows', 'seven', 'sheep', 'past', 'weeks'], tags=[237]),
#  TaggedDocument(words=['most', 'bears', 'omnivorous', 'romania', 'bears', 'weaned', 'meat', 'said', 'onetiu'], tags=[238]),
#  TaggedDocument(words=['nicolae', 'ceausescu', 'communist', 'dictator', 'toppled', 'executed', 'decade', 'ago', 'avid', 'hunter', 'hunting', 'reserve', 'cubs', 'fed', 'meat', 'grow', 'bigger', 'quicker', 'leaving', 'generations', 'partial', 'meat'], tags=[239]),
#  TaggedDocument(words=['state', 'rangers', 'count', '135', 'bears', 'living', 'apuseni', 'mountains', 'western', 'romania', 'protected', 'law'], tags=[240]),
#  TaggedDocument(words=['str'], tags=[241]),
#  TaggedDocument(words=['norwegian', 'company', 'moves', 'ahead', 'clean', 'power', 'plant', 'the', 'norsk', 'hydro', 'asa', 'concern', 'announced', 'plans', 'friday', 'build', 'hydrogen', 'burning', 'power', 'plant', 'says', 'produce', 'electricity', 'virtually', 'climate', 'damaging', 'emissions'], tags=[242]),
#  TaggedDocument(words=['the', 'percent', 'state', 'owned', 'company', 'notified', 'norwegian', 'water', 'resources', 'energy', 'directorate', 'plans', 'build', 'plant', 'called', 'hydrokraft', 'pending', 'approval', 'government', 'agencies'], tags=[243]),
#  TaggedDocument(words=['the', 'company', 'said', 'receives', 'proper', 'approvals', '1999', 'construction', 'plant', 'completed', '2002', 'production', 'startup', 'occur', 'early', '2003'], tags=[244]),
#  TaggedDocument(words=['earlier', 'year', 'company', 'announced', 'new', 'technology', 'allow', 'use', 'clean', 'burning', 'hydrogen', 'generate', 'electricity'], tags=[245]),
#  TaggedDocument(words=['the', 'hydrogen', 'plant', 'extracted', 'natural', 'gas'], tags=[246]),
#  TaggedDocument(words=['norsk', 'hydro', 'major', 'petroleum', 'producer', 'says', 'studies', 'shown', 'proposal', 'economically', 'viable'], tags=[247]),
#  TaggedDocument(words=['said', 'plant', 'carbon', 'dioxide', 'emissions', 'percent', 'lower', 'plants', 'natural', 'gas'], tags=[248]),
#  TaggedDocument(words=['norway', 'world', 'second', 'largest', 'oil', 'exporter', 'produces', 'vast', 'amounts', 'natural', 'gas', 'offshore', 'fields'], tags=[249]),
#  TaggedDocument(words=['virtually', 'country', 'electricity', 'comes', 'hydroelectric', 'plants'], tags=[250]),
#  TaggedDocument(words=['under', 'company', 'plans', 'natural', 'gas', 'air', 'water', 'mixed', 'produce', 'hydrogen', 'nitrogen', 'carbon', 'dioxide'], tags=[251]),
#  TaggedDocument(words=['norsk', 'hydro', 'wants', 'build', 'plant', 'karmoey', 'island', '500', 'kilometers', '300', 'miles', 'west', 'oslo'], tags=[252]),
#  TaggedDocument(words=['alaska', 'hiker', 'killed', 'bear', 'anchorage', 'alaska', 'man', 'day', 'hike', 'rural', 'area', 'killed', 'bear', 'bit', 'head', 'alaska', 'state', 'troopers', 'said', 'wednesday'], tags=[253]),
#  TaggedDocument(words=['kenneth', 'cates', 'wednesday', 'morning', 'horse', 'trail', 'heavily', 'wooded', 'area', 'kenai', 'national', 'wildlife', 'refuge', 'near', 'hometown', 'soldotna'], tags=[254]),
#  TaggedDocument(words=['the', 'attack', 'happened', 'miles', 'busy', 'road'], tags=[255]),
#  TaggedDocument(words=['the', 'area', 'miles', 'southwest', 'anchorage'], tags=[256]),
#  TaggedDocument(words=['the', 'fatal', 'mauling', 'thought', 'happened', 'tuesday'], tags=[257]),
#  TaggedDocument(words=['his', 'visible', 'wound', 'single', 'bite', 'head', 'said', 'bruce', 'bartley', 'spokesman', 'state', 'division', 'wildlife', 'conservation'], tags=[258]),
#  TaggedDocument(words=['state', 'federal', 'wildlife', 'officials', 'looking', 'bear', 'involved', 'attack'], tags=[259]),
#  TaggedDocument(words=['bear', 'judged', 'pose', 'continuing', 'threat', 'humans', 'killed'], tags=[260]),
#  TaggedDocument(words=['troopers', 'said', 'cates', '280', 'caliber', 'rifle', 'spent', 'shell', 'casings', 'near', 'body', 'traces', 'blood', 'suggest', 'cates', 'wounded', 'animal'], tags=[261]),
#  TaggedDocument(words=['know', 'warning', 'shot', 'real', 'real', 'shots', 'bartley', 'said'], tags=[262]),
#  TaggedDocument(words=['cates', 'death', 'fatal', 'bear', 'mauling', 'alaska', 'feb', '1998', 'audelio', 'luis', 'cortes', 'killed', 'working', 'seismic', 'crew', 'swanson', 'river', 'oil', 'field', 'near', 'kenai'], tags=[263]),
#  TaggedDocument(words=['cortes', 'died', 'single', 'head', 'bite'], tags=[264]),
#  TaggedDocument(words=['syria', 'opposes', 'attempt', 'overthrow', 'saddam', 'hussein', 'syria', 'opposes', 'attempts', 'united', 'states', 'britain', 'overthrow', 'iraqi', 'leader', 'saddam', 'hussein', 'syrian', 'vice', 'president', 'abdul', 'halim', 'khaddam', 'said', 'thursday'], tags=[265]),
#  TaggedDocument(words=['such', 'moves', 'serve', 'israel', 'design', 'disintegrate', 'arab', 'islamic', 'world', 'khaddam', 'said', 'receiving', 'iranian', 'counterpart', 'hassan', 'habibi', 'damascus', 'airport'], tags=[266]),
#  TaggedDocument(words=['the', 'united', 'states', 'granted', 'dlrs', 'million', 'iraqi', 'opposition', 'groups'], tags=[267]),
#  TaggedDocument(words=['british', 'american', 'officials', 'hosted', 'meetings', 'london', 'month', 'iraqi', 'dissident', 'groups', 'bid', 'promote', 'cooperation'], tags=[268]),
#  TaggedDocument(words=['this', 'dangerous', 'issue', 'state', 'world', 'right', 'interfere', 'internal', 'affairs', 'country', 'khaddam', 'said'], tags=[269]),
#  TaggedDocument(words=['habibi', 'said', 'iraqi', 'palestinian', 'questions', 'great', 'concern', 'iran', 'syria', 'there', 'coordination', 'countries', 'issues'], tags=[270]),
#  TaggedDocument(words=['the', 'official', 'iranian', 'news', 'agency', 'irma', 'said', 'iraqi', 'palestinian', 'issues', 'focus', 'talks', 'habibi', 'khaddam', 'meeting', 'syrian', 'iranian', 'supreme', 'committee'], tags=[271]),
#  TaggedDocument(words=['the', 'committee', 'meets', 'biannually', 'promote', 'cooperation', 'foreign', 'affairs', 'trade', 'technology'], tags=[272]),
#  TaggedDocument(words=['habibi', 'accompanied', 'iranian', 'foreign', 'minister', 'kamal', 'kharrazi', 'expected', 'meet', 'syrian', 'president', 'hafez', 'assad', 'day', 'visit'], tags=[273]),
#  TaggedDocument(words=['syria', 'iran', 'closest', 'arab', 'ally', 'supported', 'persian', 'state', '1980', 'iran', 'iraq', 'war'], tags=[274]),
#  TaggedDocument(words=['str', 'jbm'], tags=[275]),
#  TaggedDocument(words=['portugal', 'spain', 'reach', 'agreement', 'common', 'water', 'supplies', 'portugal', 'spain', 'monday', 'reached', 'agreement', 'shared', 'water', 'resources', 'iberian', 'peninsula', 'wrapping', 'day', 'summit', 'premiers', 'called', 'historic'], tags=[276]),
# ...
#  TaggedDocument(words=['the', 'thieves', 'broke', 'aircraft', 'luggage', 'compartment', 'escaped', 'large', 'quantity', 'baggage', 'plane', 'awaiting', 'permission', 'lagos', 'international', 'airport', 'control', 'tower', 'tuesday', 'night', 'guardian', 'said'], tags=[415]),
#  TaggedDocument(words=['clear', 'airliner', 'destined'], tags=[416]),
#  TaggedDocument(words=['there', 'immediate', 'confirmation', 'report'], tags=[417]),
#  TaggedDocument(words=['the', 'plane', 'captain', 'noticed', 'theft', 'sent', 'distress', 'went', 'unanswered', 'airport', 'officials'], tags=[418]),
#  TaggedDocument(words=['security', 'personnel', 'duty', 'later', 'said', 'said', 'unable', 'capture', 'culprits', 'security', 'vehicle', 'taken', 'away', 'routine', 'maintenance'], tags=[419]),
#  TaggedDocument(words=['incident', 'week', 'involving', 'unidentified', 'passenger', 'jet', 'landing', 'gear', 'worth', 'dlrs', 'million', 'stripped', 'plane', 'waiting', 'newspaper', 'said'], tags=[420]),
#  TaggedDocument(words=['may', 'cameroon', 'airlines', 'plane', 'robbed', 'luggage', 'armed', 'thieves', 'blocked', 'plane', 'tarmac', 'large', 'log'], tags=[421]),
#  TaggedDocument(words=['the', 'robberies', 'came', 'despite', 'orders', 'airport', 'security', 'officials', 'shoot', 'suspected', 'thieves', 'sight'], tags=[422]),
#  TaggedDocument(words=['nigeria', 'africa', 'populous', 'country', 'notoriously', 'high', 'rate', 'violent', 'crime', 'accompanied', 'breakdown', 'law', 'order', 'years', 'military', 'rule'], tags=[423]),
#  TaggedDocument(words=['gam'], tags=[424]),
#  TaggedDocument(words=['businessman', 'killed', 'siberian', 'town', 'russian', 'businessman', 'killed', 'way', 'work', 'wednesday', 'unidentified', 'gunman', 'appeared', 'organized', 'crime', 'killing', 'according', 'news', 'reports'], tags=[425]),
#  TaggedDocument(words=['yuri', 'zinin', 'head', 'sibneft', 'company', 'shot', 'walked', 'apartment', 'building', 'town', 'leninsk', 'kuzntesky', 'kemerovo', 'region', 'central', 'siberia', 'russian', 'news', 'agencies', 'quoted', 'local', 'police', 'saying'], tags=[426]),
#  TaggedDocument(words=['zinin', 'company', 'russia', 'largest', 'oil', 'producers', 'sibneft', 'controlled', 'controversial', 'business', 'mogul', 'boris', 'berezovsky'], tags=[427]),
#  TaggedDocument(words=['but', 'companies', 'separate'], tags=[428]),
#  TaggedDocument(words=['zinin', 'sibneft', 'locally', 'based', 'involved', 'selling', 'oil', 'products', 'coal'], tags=[429]),
#  TaggedDocument(words=['kemerovo', 'russia', 'main', 'coal', 'mining', 'regions'], tags=[430]),
#  TaggedDocument(words=['police', 'launched', 'search', 'killer', 'fled'], tags=[431]),
#  TaggedDocument(words=['officials', 'wouldn', 'comment', 'possible', 'motives', 'murder'], tags=[432]),
#  TaggedDocument(words=['there', 'hundreds', 'contract', 'murder', 'russia', 'year', 'mobsters', 'fight', 'control', 'profitable', 'businesses'], tags=[433]),
#  TaggedDocument(words=['only', 'small', 'number', 'killings', 'solved'], tags=[434]),
#  TaggedDocument(words=['the', 'small', 'town', 'leninsk', 'kuznetsky', 'known', 'nationwide', 'year', 'city', 'mayor', 'arrested', 'tax', 'fraud', 'embezzlement', 'charges'], tags=[435]),
#  TaggedDocument(words=['mayor', 'gennady', 'konyakhin', 'accused', 'linked', 'mob', 'custody', 'awaiting', 'trial'], tags=[436]),
#  TaggedDocument(words=['ren'], tags=[437]),
#  TaggedDocument(words=['astronomers', 'spot', 'storm', 'mars', 'washington', 'cyclone', 'times', 'size', 'texas', 'raged', 'northern', 'polar', 'region', 'planet', 'mars', 'month', 'according', 'space', 'telescope', 'views', 'red', 'planet'], tags=[438]),
#  TaggedDocument(words=['the', 'space', 'telescope', 'science', 'institute', 'announced', 'today', 'hubble', 'space', 'telescope', 'april', 'spotted', 'immense', 'martian', 'storm', 'cloud', 'water', 'ice', '100', 'miles', 'long', '900', 'wide'], tags=[439]),
#  TaggedDocument(words=['bands', 'clouds', 'spiraled', 'counterclockwise', 'motion', '200', 'mile', 'wide', 'eye', 'center', 'storm', 'taking', 'shape', 'resembled', 'hurricanes', 'earth', 'astronomers', 'said'], tags=[440]),
#  TaggedDocument(words=['the', 'storm', 'occurred', 'summer', 'mars', 'northern', 'hemisphere'], tags=[441]),
#  TaggedDocument(words=['came', 'seasonal', 'warming', 'evaporated', 'carbon', 'dioxide', 'ice', 'sheet', 'caps', 'martian', 'north', 'pole', 'year'], tags=[442]),
#  TaggedDocument(words=['officials', 'said', 'storm', 'times', 'larger', 'storm', 'spotted', 'years', 'ago', 'viking', 'orbiter', 'spacecraft'], tags=[443]),
#  TaggedDocument(words=['astronomers', 'wide', 'field', 'planetary', 'camera', 'hubble', 'photograph', 'mars', 'planet', 'closest', 'approach', 'earth', 'nearly', 'years'], tags=[444]),
#  TaggedDocument(words=['two', 'pictures', 'taken', 'hours', 'apart', 'april', 'showed', 'storm', 'moved', 'slightly', 'eastward'], tags=[445]),
#  TaggedDocument(words=['second', 'picture', 'storm', 'appeared', 'process', 'breaking'], tags=[446]),
#  TaggedDocument(words=['later', 'pictures', 'hubble', 'camera', 'failed', 'storm', 'astronomers', 'said', 'short', 'lived', 'phenomenon'], tags=[447]),
#  TaggedDocument(words=['shepard', 'glenn', 'set', 'milestones', 'may', '1961', 'alan', 'shepard', 'american', 'space'], tags=[448]),
#  TaggedDocument(words=['feb', '1962', 'john', 'glenn', 'american', 'orbit'], tags=[449]),
#  TaggedDocument(words=['jan', '1967', 'gus', 'grissom', 'edward', 'white', 'roger', 'chaffee', 'die', 'apollo', 'spacecraft', 'launch', 'pad'], tags=[450]),
#  TaggedDocument(words=['july', '1969', 'apollo', 'neil', 'armstrong', 'buzz', 'aldrin', 'land', 'moon'], tags=[451]),
#  TaggedDocument(words=['july', '1975', 'american', 'apollo', 'soviet', 'soyuz', 'spacecraft', 'link', 'orbit'], tags=[452]),
#  TaggedDocument(words=['april', '1981', 'columbia', 'soars', 'space', 'shuttle', 'flight'], tags=[453]),
#  TaggedDocument(words=['june', '1983', 'sally', 'ride', 'american', 'woman', 'space'], tags=[454]),
#  TaggedDocument(words=['jan', '1986', 'challenger', 'explodes', 'killing', 'seven', 'board'], tags=[455]),
#  TaggedDocument(words=['april', '1990', 'hubble', 'space', 'telescope', 'released', 'orbit'], tags=[456]),
#  TaggedDocument(words=['dec', '1993', 'first', 'hubble', 'repair', 'mission', 'launched'], tags=[457]),
#  TaggedDocument(words=['march', '1995', 'norman', 'thagard', 'american', 'launched', 'russian', 'rocket'], tags=[458]),
#  TaggedDocument(words=['two', 'days', 'later', 'american', 'visit', 'mir'], tags=[459]),
#  TaggedDocument(words=['june', '1995', 'atlantis', 'docks', 'mir', 'shuttle', 'station', 'hookup'], tags=[460]),
#  TaggedDocument(words=['sept', '1996', 'shannon', 'lucid', 'returns', 'earth', '188', 'day', 'mir', 'mission', 'space', 'endurance', 'record', 'world', 'record', 'women'], tags=[461]),
#  TaggedDocument(words=['nov', '1996', 'story', 'musgrave', 'age', 'oldest', 'man', 'space'], tags=[462]),
#  TaggedDocument(words=['oct', '1998', 'discovery', 'scheduled', 'blast', 'carrying', 'year', 'old', 'john', 'glenn', 'orbit', 'making', 'oldest', 'man', 'space'], tags=[463]),
#  TaggedDocument(words=['the', 'nation', 'weather', 'severe', 'thunderstorms', 'forecast', 'gulf', 'coast', 'louisiana', 'georgia', 'northward', 'tennessee'], tags=[464]),
#  TaggedDocument(words=['rain', 'forecast', 'carolinas', 'tonight'], tags=[465]),
#  TaggedDocument(words=['lightning', 'large', 'hail', 'wind', 'mph', 'inches', 'rain', 'possible'], tags=[466]),
#  TaggedDocument(words=['lighter', 'amounts', 'expected', 'ohio', 'valley'], tags=[467]),
#  TaggedDocument(words=['the', 'storm', 'roared', 'texas', 'oklahoma', 'thursday', 'hitting', 'areas', 'wind', 'hail', 'heavy', 'rain'], tags=[468]),
#  TaggedDocument(words=['some', 'flights', 'dallas', 'fort', 'worth', 'international', 'airport', 'delayed', 'seven', 'hours'], tags=[469]),
#  TaggedDocument(words=['northeast', 'inches', 'sunnyow', 'possible', 'adirondack', 'green', 'mountains'], tags=[470]),
#  TaggedDocument(words=['sunnyow', 'forecast', 'northwesterain', 'pennsylvania', 'maine'], tags=[471]),
#  TaggedDocument(words=['gusty', 'winds', 'expected', 'wind', 'chill', 'readings', 'freezing'], tags=[472]),
#  TaggedDocument(words=['mostly', 'quiet', 'conditions', 'forecast', 'west', 'rockies', 'southeast', 'northerain', 'plains', 'today'], tags=[473]),
#  TaggedDocument(words=['showers', 'possible', 'southerain', 'califorainia', 'coasts', 'washington', 'oregon'], tags=[474]),
#  TaggedDocument(words=['highs', 'today', 'forecast', 'reach', '30s', 'new', 'england', '40s', 'northeast', 'midwest', 'great', 'lakes', 'northerain', 'rockies', '50s', 'northwest', 'mid', 'atlantic', 'states', 'northerain', 'plains', '60s', '70s', '80s', 'southeast', 'southwest', 'southerain', 'plains'], tags=[475]),
#  TaggedDocument(words=['the', 'highest', 'temperature', 'reported', 'continental', 'united', 'states', 'thursday', 'degrees', 'texas', 'communities', 'cotulla', 'alice'], tags=[476]),
#  TaggedDocument(words=['the', 'low', 'minus', 'grand', 'marais', 'minn'], tags=[477]),
#  TaggedDocument(words=['report', 'south', 'africa', 'truth', 'panel', 'condemn', 'anc', 'panel', 'probing', 'apartheid', 'era', 'abuses', 'accused', 'african', 'national', 'congress', 'human', 'rights', 'violations', 'including', 'torture', 'bomb', 'attacks', 'state', 'broadcaster', 'said', 'monday'], tags=[478]),
#  TaggedDocument(words=['the', 'anc', 'led', 'struggle', 'white', 'rule', 'power', 'previously', 'acknowledged', 'told', 'expect', 'implication', 'right', 'violations'], tags=[479]),
#  TaggedDocument(words=['the', 'truth', 'reconciliation', 'commission', 'release', 'final', 'report', 'years', 'investigation', 'thursday'], tags=[480]),
#  TaggedDocument(words=['the', 'report', 'expected', 'place', 'overwhelming', 'blame', 'era', 'abuses', 'white', 'governments', 'brutal', 'security', 'services'], tags=[481]),
#  TaggedDocument(words=['south', 'african', 'broadcasting', 'corp', 'radio', 'said', 'leaked', 'preliminary', 'document', 'condemns', 'anc', 'politically', 'morally', 'responsible', 'gross', 'human', 'rights', 'violations', 'fall', 'apartheid'], tags=[482]),
#  TaggedDocument(words=['anc', 'spokesman', 'thabo', 'masebe', 'said', 'believed', 'news', 'report', 'referred', 'commission', 'letter', 'sent', 'advance', 'informing', 'intention', 'implicate', 'anc', 'gross', 'human', 'rights', 'violations'], tags=[483]),
#  TaggedDocument(words=['commission', 'officials', 'immediately', 'reached', 'comment'], tags=[484]),
#  TaggedDocument(words=['the', 'anc', 'nervous', 'report', 'request', 'meeting', 'commissioners', 'earlier', 'month'], tags=[485]),
#  TaggedDocument(words=['the', 'panel', 'refused', 'avoid', 'appearing', 'embarrassed'], tags=[486]),
#  TaggedDocument(words=['the', 'party', 'says', 'accusations', 'likely', 'center', 'planting', 'land', 'mines', 'border', 'farms', 'abuses', 'military', 'camps', 'angola', 'bombings'], tags=[487]),
#  TaggedDocument(words=['djw'], tags=[488]),
#  TaggedDocument(words=['saddam', 'says', 'reap', 'urges', 'iran', 'normalize', 'ties', 'president', 'saddam', 'hussein', 'said', 'saturday', 'united', 'states', 'reap', 'harvest', 'thorns', 'campaign', 'iraq'], tags=[489]),
#  TaggedDocument(words=['addressing', 'nation', 'television', 'mark', 'anniversary', 'end', '1980', 'iran', 'iraq', 'war', 'saddam', 'urged', 'iran', 'normalize', 'relations', 'iraq'], tags=[490]),
#  TaggedDocument(words=['saddam', 'refer', 'decision', 'wednesday', 'freeze', 'cooperation', 'arms', 'inspectors', 'said', 'united', 'states', 'allies', 'misled', 'thought', 'bring', 'iraq', 'knees'], tags=[491]),
#  TaggedDocument(words=['this', 'exactly', 'iranian', 'government', 'late', 'ayatollah', 'ruhollah', 'khomeini', 'thought', 'war', 'failed', 'saddam', 'said'], tags=[492]),
#  TaggedDocument(words=['those', 'imposing', 'aggression', 'iraq', 'unfair', 'embargo', 'neglect', 'fact', 'today', 'saddam', 'said', 'referring', 'sweeping', 'sanctions', 'united', 'nations', 'imposed', 'iraq', '1990', 'invasion', 'kuwait'], tags=[493]),
#  TaggedDocument(words=['they', 'making', 'mistake'], tags=[494]),
#  TaggedDocument(words=['their', 'harvest', 'thorns', 'outcome', 'taste', 'bitterness'], tags=[495]),
#  TaggedDocument(words=['the', 'president', 'delivered', 'speech', 'black', 'suit'], tags=[496]),
#  TaggedDocument(words=['decreed', 'saturday', 'celebrated', 'day', 'victory', 'iran', 'artillery', 'salute', '101', 'guns', 'boomed', 'baghdad', 'early', 'morning'], tags=[497]),
#  TaggedDocument(words=['national', 'radio', 'television', 'played', 'patriotic', 'songs', 'occasion'], tags=[498]),
#  TaggedDocument(words=['saddam', 'spoke', '7th', 'graf', 'pvs'], tags=[499]),
#  TaggedDocument(words=['international', 'police', 'seek', 'stymie', 'illegal', 'art', 'traffic', 'king', 'police', 'officers', 'countries', 'met', 'budapest', 'seek', 'efficient', 'ways', 'combat', 'illegal', 'traffic', 'art', 'treasures', 'police', 'official', 'said', 'thursday'], tags=[500]),
#  TaggedDocument(words=['held', 'auspices', 'interpol', 'international', 'police', 'organization', 'day', 'closed', 'meeting', 'allowed', 'officers', 'personal', 'contact', 'help', 'east', 'european', 'counterparts', 'catch'], tags=[501]),
#  TaggedDocument(words=['member', 'team', 'working', 'illegal', 'art', 'traffic', 'group', 'set', 'april', 'france', 'policemen', 'years', 'experience', 'hungarian', 'police', 'col', 'tamas', 'simon', 'said'], tags=[502]),
#  TaggedDocument(words=['illegal', 'art', 'traffic', 'growth', 'industry'], tags=[503]),
#  TaggedDocument(words=['1990', 'year', 'communism', 'collapsed', '702', 'registered', 'cases', 'hungary', 'total', 'value', 'stolen', 'treasures', 'million', 'forints', 'dlrs', '340', '000', 'present', 'terms'], tags=[504]),
#  TaggedDocument(words=['1993', '1996', '025', 'cases', 'involving', '430', 'million', 'forints', 'dlrs', 'million', 'worth', 'stolen', 'treasures'], tags=[505]),
#  TaggedDocument(words=['this', 'special', 'area', 'police', 'work', 'stolen', 'art', 'appear', 'years', 'market', 'said', 'jean', 'pierre', 'jouanny', 'director', 'french', 'national', 'bureau', 'interpol'], tags=[506]),
#  TaggedDocument(words=['hungary', 'largely', 'transit', 'country', 'stolen', 'art', 'line', 'traffic', 'moving', 'east', 'west'], tags=[507]),
#  TaggedDocument(words=['work', 'underway', 'cataloging', 'country', 'art', 'treasures', 'establishing', 'data', 'base', 'network', 'contacts', 'art', 'dealers', 'auctioneers', 'museums'], tags=[508]),
#  TaggedDocument(words=[], tags=[509]),
#  TaggedDocument(words=['cohen', 'missile', 'defense', 'gulf', 'imperative', 'defense', 'secretary', 'william', 'cohen', 'said', 'saturday', 'imperative', 'allies', 'gulf', 'acquire', 'ballistic', 'missile', 'defense', 'counter', 'long', 'range', 'weapons', 'hands', 'countries', 'iran', 'iraq'], tags=[510]),
#  TaggedDocument(words=['cohen', 'said', 'united', 'states', 'defense', 'systems', 'research', 'development', 'hope', 'hope', 'share', 'technology', 'bahrain', 'gulf', 'countries'], tags=[511]),
#  TaggedDocument(words=['speaking', 'reporters', 'leaving', 'qatar', 'second', 'stop', 'nation', 'gulf', 'tour', 'includes', 'united', 'arab', 'emirates', 'oman', 'kuwait', 'saudi', 'arabia'], tags=[512]),
#  TaggedDocument(words=['because', 'proliferation', 'missile', 'technology', 'globally', 'especially', 'gulf', 'region', 'believe', 'important', 'look', 'ways', 'cooperate', 'allies', 'said', 'cohen'], tags=[513]),
#  TaggedDocument(words=['think', 'imperative', 'countries', 'cooperate', 'develop', 'theater', 'missile', 'protection', 'people', 'forces', 'said', 'cohen', 'citing', 'threats', 'iran', 'iraq'], tags=[514]),
#  TaggedDocument(words=['the', 'united', 'states', 'sees', 'iraq', 'iran', 'recently', 'tested', 'long', 'range', 'missile', 'major', 'threats', 'gulf', 'region'], tags=[515]),
#  TaggedDocument(words=['cohen', 'said', 'iraq', 'sanctions', 'continues', 'efforts', 'acquire', 'missile', 'technology', 'longer', 'permissible', 'range'], tags=[516])]

# %%
model = Doc2Vec(tagged_data, vector_size = 20, window = 2, min_count = 1, epochs = 100)

'''
vector_size = Dimensionality of the feature vectors.
window = The maximum distance between the current and predicted word within a sentence.
min_count = Ignores all words with total frequency lower than this.
alpha = The initial learning rate.
'''

## Print model vocabulary
model.wv.vocab
test_doc = word_tokenize("We t want projects success paper inspection t desired results added".lower())
test_doc_vector = model.infer_vector(test_doc)
model.docvecs.most_similar(positive = [test_doc_vector])
# Out:
# [(37, 0.9260163307189941),
#  (248, 0.9185295104980469),
#  (251, 0.9144531488418579),
#  (145, 0.9140121936798096),
#  (40, 0.9136689901351929),
#  (250, 0.9120262861251831),
#  (189, 0.9083396196365356),
#  (50, 0.9077826738357544),
#  (36, 0.9055702686309814),
#  (38, 0.9051133394241333)]

# %%
## for deep learning
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
## for bert language model
import transformers
## for data
import json
import pandas as pd
import numpy as np

# %%
txt = list_txt
## bert tokenizer
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
## bert model
nlp = transformers.TFBertModel.from_pretrained('bert-base-uncased')
## return hidden layer with embeddings
input_ids = np.array(tokenizer.encode(txt))[None,:100]  
embedding = nlp(input_ids)
embedding[0][0]
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Token indices sequence length is longer than the specified maximum sequence length for this model (519 > 512). Running this sequence through the model will result in indexing errors
# <tf.Tensor: shape=(100, 768), dtype=float32, numpy=
# array([[ 0.219636  , -0.12243392,  0.14102589, ...,  0.18106887,
#          0.08625853,  0.236384  ],
#        [ 0.32774457,  0.37399426, -0.42987996, ..., -0.19647591,
#          0.30718687,  0.03426552],
#        [ 0.29034925,  0.4144443 , -0.44861224, ..., -0.2566859 ,
#          0.28809124,  0.08427162],
#        ...,
#        [ 0.40355682,  0.43134704, -0.05328133, ..., -0.21294558,
#          0.32230303, -0.01735931],
#        [ 0.37071842,  0.46634302, -0.05253001, ..., -0.21740773,
#          0.297198  , -0.03735596],
#        [ 0.34018013,  0.51572216, -0.0599245 , ..., -0.22152145,
#          0.25309065, -0.06348572]], dtype=float32)>

# %%
## distil-bert tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained('distilbert-base-uncased', do_lower_case=True)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
lst_dics = tagged_data

## print the first one
lst_dics[0]
## create dtf
dtf = pd.DataFrame(lst_dics)
## filter categories
# dtf = dtf[ dtf["category"].isin(['ENTERTAINMENT','POLITICS','TECH']) ][["category","headline"]]
## rename columns
dtf = dtf.rename(columns={"category":"y", "headline":"text"})
## print 10 random rows
dtf.sample(10)
# Out:
#                                                  words   tags
# 39   [swiss, government, eyes, shutting, nuclear, p...   [39]
# 111  [the, billion, dollar, museum, located, hill, ...  [111]
# 129     [guards, stationed, staircase, man, ran, past]  [129]
# 183  [norbert, otto, federal, lawmaker, erfurt, dem...  [183]
# 84   [english, viravaidya, plan, set, watchdog, com...   [84]
# 40   [but, environmental, campaigners, criticized, ...   [40]
# 171  [iraq, long, maintained, released, iranian, pr...  [171]
# 8    [progress, reported, weekend, announcement, sp...    [8]
# 5    [jimmy, adams, treasurer, players, assocation,...    [5]
# 231  [moved, headquarters, prague, 1995, following,...  [231]

# %%
## inputs
idx = layers.Input((50), dtype="int32", name="input_idx")
masks = layers.Input((50), dtype="int32", name="input_masks")
## pre-trained bert with config
config = transformers.DistilBertConfig(dropout=0.2, 
           attention_dropout=0.2)
config.output_hidden_states = False
nlp = transformers.TFDistilBertModel.from_pretrained('distilbert-base-uncased', config=config)
bert_out = nlp(idx, attention_mask=masks)[0]
## fine-tuning
x = layers.GlobalAveragePooling1D()(bert_out)
x = layers.Dense(64, activation="relu")(x)
y_out = layers.Dense(len(np.unique(list_txt)), 
                     activation='softmax')(x)
## compile
model = models.Model([idx, masks], y_out)
for layer in model.layers[:3]:
    layer.trainable = False
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertModel: ['vocab_transform', 'activation_13', 'vocab_layer_norm', 'vocab_projector']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# Model: "model_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_idx (InputLayer)          [(None, 50)]         0
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, 50)]         0
# __________________________________________________________________________________________________
# tf_distil_bert_model_19 (TFDist TFBaseModelOutput(la 66362880    input_idx[0][0]
#                                                                  input_masks[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_20 (Gl (None, 768)          0           tf_distil_bert_model_19[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 64)           49216       global_average_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 448)          29120       dense_35[0][0]
# ==================================================================================================
# Total params: 66,441,216
# Trainable params: 78,336
# Non-trainable params: 66,362,880
# __________________________________________________________________________________________________

# %% [markdown]
# Collect the **resault** from the last unworkable part!!
# ////*Help in this* ///

# %%
## encode y
dic_y_mapping = {n:label for n,label in 
                 enumerate(np.unique(y_train))}
inverse_dic = {v:k for k,v in dic_y_mapping.items()}
y_train = np.array([inverse_dic[y] for y in y_train])
## train
training = model.fit(x=X_train, y=y_train, batch_size=64, 
                     epochs=1, shuffle=True, verbose=1, 
                     validation_split=0.3)
## test
predicted_prob = model.predict(X_test)
predicted = [dic_y_mapping[np.argmax(pred)] for pred in 
             predicted_prob]
